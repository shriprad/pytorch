# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import os 
import random
import time
from dataclasses import dataclass

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets, models
from torchvision.transforms import functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.tensorboard import SummaryWriter


from matplotlib import pyplot as plt
from PIL import Image

# %%
 data_root = './'
#data_root = '/kaggle/input/pytorch-opencv-course-classification/'

image_root = os.path.join(data_root, 'images/images')
data_csv_path = os.path.join(data_root, 'train.csv')
test_csv_path = os.path.join(data_root, 'test.csv')
train_csv='train.csv'
val_csv='validation.csv'
valid_fraction=0.2

# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load in 

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the "../input/" directory.
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # Any results you write to the current directory are saved as output.

# %%
def split_train_validation(csv_path, valid_fraction=0.2, train_csv='train.csv', val_csv='validation.csv', print_info=True):
    """
    It takes .csv file that have two column: ['id', 'class'] and create two .csv file for traing and validation. Return a list of classes
    Parms:
    csv_path (str): path of data csv
    valid_fraction (float): fraction for validation data (0 to 1). 
    train_csv (str): train data file path
    val_csv (str): validation data file path
    print_info (boolean): True for print data overview else False
    
    return (list): List of classes 
    """
    data_df = pd.read_csv(csv_path)

    classes = list(data_df['class'].unique())
    
    if print_info:
        print('There is {} classes and its names are the following:\n{}\n'.format(len(classes), classes))
        
    f_val = open(val_csv, 'w')
    f_train = open(train_csv, 'w')
    
    f_val.write('{},{}\n'.format('id', 'class'))
    f_train.write('{},{}\n'.format('id', 'class'))
        
    for i, cls in enumerate(classes):
        cls_data = data_df[data_df['class']==cls]['id'].to_list()
        val_count = int(len(cls_data) * valid_fraction)
        val_data = random.sample(cls_data, k=val_count)
        
        if print_info:
            print('{}.\tCLASS NAME: {}\tTRAIN COUNT: {}\tVALIDATION COUNT: {}'.format(i, cls, len(cls_data)-len(val_data), len(val_data)))
        for img_id in cls_data:
            if img_id in val_data:
                f_val.write('{},{}\n'.format(img_id, cls))
            else:
                f_train.write('{},{}\n'.format(img_id, cls))
    f_val.close()
    f_train.close()
    
    return classes

# %%
class_names = split_train_validation(csv_path=data_csv_path, 
                                     valid_fraction=valid_fraction, 
                                     train_csv=train_csv, 
                                     val_csv=val_csv, 
                                     print_info=True)
# Out:
# There is 13 classes and its names are the following:
# ['githeri', 'ugali', 'kachumbari', 'matoke', 'sukumawiki', 'bhaji', 'mandazi', 'kukuchoma', 'nyamachoma', 'pilau', 'chapati', 'masalachips', 'mukimo']
#
# 0.	CLASS NAME: githeri	TRAIN COUNT: 198	VALIDATION COUNT: 49
# 1.	CLASS NAME: ugali	TRAIN COUNT: 259	VALIDATION COUNT: 64
# 2.	CLASS NAME: kachumbari	TRAIN COUNT: 204	VALIDATION COUNT: 50
# 3.	CLASS NAME: matoke	TRAIN COUNT: 199	VALIDATION COUNT: 49
# 4.	CLASS NAME: sukumawiki	TRAIN COUNT: 166	VALIDATION COUNT: 41
# 5.	CLASS NAME: bhaji	TRAIN COUNT: 260	VALIDATION COUNT: 64
# 6.	CLASS NAME: mandazi	TRAIN COUNT: 255	VALIDATION COUNT: 63
# 7.	CLASS NAME: kukuchoma	TRAIN COUNT: 72	VALIDATION COUNT: 18
# 8.	CLASS NAME: nyamachoma	TRAIN COUNT: 323	VALIDATION COUNT: 80
# 9.	CLASS NAME: pilau	TRAIN COUNT: 136	VALIDATION COUNT: 34
# 10.	CLASS NAME: chapati	TRAIN COUNT: 354	VALIDATION COUNT: 88
# 11.	CLASS NAME: masalachips	TRAIN COUNT: 180	VALIDATION COUNT: 45
# 12.	CLASS NAME: mukimo	TRAIN COUNT: 88	VALIDATION COUNT: 21

# %%
df = pd.read_csv(val_csv)
print(df.head())
print(df.tail())
# Out:
#                      id    class
# 0  10526888018530471027  githeri
# 1  10229702182160656293  githeri
# 2  13962925923858718920  githeri
# 3  10425864454214045915  githeri
# 4  17507957776151987213  githeri
#                        id   class
# 661  17372228205727909634  mukimo
# 662  16268647503888352513  mukimo
# 663  13527298696421690551  mukimo
# 664  15026848279814809079  mukimo
# 665   8487223720219722157  mukimo

# %%
class KenyanFood13Dataset(Dataset):
    """
    This custom dataset class take root image directory and csv path
    and return dataset
    """
    
    def __init__(self, image_root, csv_path, classes, image_shape=None, transform=None):
        
        """
        init method of the class.
        
         Parameters:
         
         image_root (string): path of image directory.
         
         csv_path (string): path of train, val or test csv
         
         classes (list): a list of classes 
         
         image_shape (int or tuple or list): [optional] (height, width) int or tuple or list. Defaut is None. 
                                             It is not None image will resize to the given shape.
                                 
         transform (method): method that will take PIL image and transforms it.
         
        """
        
        self.image_root = image_root
        
        data_df = pd.read_csv(csv_path)
        
        self.classes = classes
        
        
        # set image_resize attribute
        if image_shape is not None:
            if isinstance(image_shape, int):
                self.image_shape = (image_shape, image_shape)
            
            elif isinstance(image_shape, tuple) or isinstance(image_shape, list):
                assert len(image_shape) == 1 or len(image_shape) == 2, 'Invalid image_shape tuple size'
                if len(image_shape) == 1:
                    self.image_shape = (image_shape[0], image_shape[0])
                else:
                    self.image_shape = image_shape
            else:
                raise NotImplementedError
        else:
            self.image_shape = image_shape
            
        # set transform attribute
        self.transform = transform
                
        
        # initialize the data dictionary
        self.data_dict = {
            'image_path': [],
            'label': []
        }
        
        cols = data_df.columns
        for i in range(len(data_df)):
            img_id = data_df['id'][i]
            image_path = os.path.join(image_root, '{}.jpg'.format(img_id))
            
            # making compatible with test data also
            if 'class' in cols:
                cls = data_df['class'][i]
                cls_idx = self.classes.index(cls)
                assert 0 <= cls_idx <= 12
            else: 
                cls_idx = None
                
            self.data_dict['image_path'].append(image_path)
            self.data_dict['label'].append(cls_idx)
        
                    
    def __len__(self):
        """
        return length of the dataset
        """
        return len(self.data_dict['label'])
    
    
    def __getitem__(self, idx):
        """
        For given index, return images with resize and preprocessing.
        """
        
        image = Image.open(self.data_dict['image_path'][idx]).convert("RGB")
        
        if self.image_shape is not None:
            height, width = self.image_shape
            image = F.resize(image, self.image_shape)
            
        if self.transform is not None:
            image = self.transform(image)
            
        target = self.data_dict['label'][idx]
        
        return image, target            
                
        
    def classes(self, label):
        """
        Get class names
        """
        return self.classes
    
    def class_to_index(self, class_name):
        """
        Get index of the class
        """
        return self.classes.index(class_name)
    
    def index_to_class(self, class_index):
        """
        Get class name for the class index
        """
        
        return self.classes[class_index]

# %%
val_dataset =  KenyanFood13Dataset(image_root=image_root, csv_path=val_csv, classes=class_names, image_shape=(256, 400))

print('Length of the dataset: {}'.format(len(val_dataset)))

img, trgt = val_dataset[300]

print('Label: {}, Class name: {}'.format(trgt, val_dataset.index_to_class(trgt)))
plt.imshow(img)
plt.show()
# Out:
# Length of the dataset: 666
# Label: 5, Class name: bhaji

# %%
preprocess = transforms.Compose([
    transforms.Resize(299),
    transforms.CenterCrop(299),
    transforms.ToTensor()
    ])

val_dataset =  KenyanFood13Dataset(image_root=image_root, csv_path=val_csv, classes=class_names, image_shape=None, transform=preprocess)

# dataloader with dataset
val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=15,
    shuffle=True,
    num_workers=2
    )


# Plot few images
plt.rcParams["figure.figsize"] = (15, 9)
plt.figure
for images, labels in val_loader:
    for i in range(len(labels)):
        plt.subplot(3, 5, i+1)
        img = F.to_pil_image(images[i])
        plt.imshow(img)
        plt.gca().set_title('{}: {}'.format(val_dataset.index_to_class(labels[i]), labels[i]))
    plt.show()
    break

# %%
def image_common_transforms(mean, std):
    
    preprocess = transforms.Compose([
        transforms.Resize(299,299),
        transforms.CenterCrop(299),
        transforms.ToTensor()
        ])
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %%
def data_augmentation_preprocess(mean, std):
    
    initail_transoform = transforms.RandomChoice([
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(90),
        ])
    
    preprocess = transforms.Compose([
        transforms.RandomAffine(degrees=120, translate=(0.2, 0.2), scale=(0.8, 1.2), 
                                shear=(-20, 20, -20, 20), resample=False, fillcolor=(0, 0,0)),
        transforms.RandomErasing(p=0.2, scale=(0.02, 0.2), ratio=(0.3, 3.3), 
                                 value='random', inplace=False),
        transforms.Resize(299,299),
        transforms.RandomCrop(299),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0, hue=0),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
        ])
                
    aug_transforms = transforms.Compose([
        initail_transoform,
        transforms.RandomGrayscale(p=0.1),
        preprocess
        ])
    
    return aug_transforms

# %%
def data_loader(image_root, csv_path, classes, transform, batch_size=4, shuffle=False, num_workers=2):
    dataset =  KenyanFood13Dataset(image_root, csv_path, classes, transform=preprocess)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %%
def get_mean_std():
    
    mean = [0.485, 0.456, 0.406] 
    std = [0.229, 0.224, 0.225]
    
    return mean, std

# %%
def get_data(batch_size, num_workers=4, data_augmentation=True):
           
    mean, std = get_mean_std()
    
    common_transforms = image_common_transforms(mean, std)
        
   
    # if data_augmentation is true 
    # data augmentation implementation
    if data_augmentation:    
        train_transforms = data_augmentation_preprocess(mean, std)
    # else do common transforms
    else:
        train_transforms = common_transforms
        
        
    # train dataloader
    train_loader = data_loader(image_root, 
                               train_csv, 
                               class_names, 
                               train_transforms, 
                               batch_size=batch_size, 
                               shuffle=True, 
                               num_workers=num_workers)
    
    # test dataloader
    test_loader = data_loader(image_root,
                              val_csv,
                              class_names,
                              common_transforms, 
                              batch_size=batch_size, 
                              shuffle=False, 
                              num_workers=num_workers)
    
    
    return train_loader, test_loader

# %%
# %load_ext tensorboard
# # %reload_ext tensorboard

# %tensorboard --logdir logs/resnet18

# %% [markdown]
# ## <font style="color:green">System Configuration</font>

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ## <font style="color:green">Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 4 
    epochs_count: int = 20 
    init_learning_rate: float = 0.001  # initial learning rate for lr scheduler
    decay_rate: float = 0.1  
    log_interval: int = 20  
    test_interval: int = 1  
    num_workers: int = 16 
    device: str = 'cuda'

# %% [markdown]
# ## <font style="color:green">System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:green">Training Function</font>
#
# We are familiar with the training pipeline used in PyTorch.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int, tb_writer: SummaryWriter
) -> None:
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is mandatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = nn.functional.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = nn.functional.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])

        if batch_idx % train_config.log_interval == 0 and batch_idx > 0:
            
            total_batch = epoch_idx * len(train_loader.dataset)/train_config.batch_size + batch_idx
            tb_writer.add_scalar('Loss/train-batch', loss.item(), total_batch)
            tb_writer.add_scalar('Accuracy/train-batch', acc, total_batch)
            print('Batch: {0}\tTrain Loss: {1:.4f}\tAccuracy: {2:.3f}'.format(int(total_batch), loss.item(), acc))
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:green">Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader
) -> float:
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        output = model(data)
        # add loss for each mini batch
        test_loss += nn.functional.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = nn.functional.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='final_model.pt'):
    
    train_config = TrainingConfiguration()
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device[:4] == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device[:4] == 'cuda':
        model.to(device)
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='final_model.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:green">Main Function for Training and Validation</font>
#
# In this section of code, we use the configuration parameters defined above and start the training. Here are the important actions being taken in the code below:
#
# 1. Set up system parameters like CPU/GPU, number of threads etc
# 1. Load the data using dataloaders
# 1. For each epoch, call train function, and for every test interval, call validation function.
# 1. Do `scheduler.step()` to update learning rate for next epoch.
# 1. Set up variables to track loss and accuracy and start training.

# %%
def main(model, optimizer, tb_writer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=False, model_name='final_model1.pt'):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = training_configuration.device
    else:
        device = "cpu"
        batch_size_to_set = 4
        num_workers_to_set = 2

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, init_val_accuracy*100))
    
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch, tb_writer)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])
        
        # add scalar (loss/accuracy) to tensorboard
        tb_writer.add_scalar('Loss/Train',train_loss, epoch)
        tb_writer.add_scalar('Accuracy/Train', train_acc, epoch)

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )
        
        # add time metadata to tensorboard
        tb_writer.add_scalar('Time/elapsed_time', elapsed_time, epoch)
        tb_writer.add_scalar('Time/speed_epoch', speed_epoch, epoch)
        tb_writer.add_scalar('Time/speed_batch', speed_batch, epoch)
        tb_writer.add_scalar('Time/eta', eta, epoch)
        

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            # add scalar (loss/accuracy) to tensorboard
            tb_writer.add_scalar('Loss/Validation', current_loss, epoch)
            tb_writer.add_scalar('Accuracy/Validation', current_accuracy, epoch)
            
            # add scalars (loss/accuracy) to tensorboard
            tb_writer.add_scalars('Loss/train-val', {'train': train_loss, 
                                           'validation': current_loss}, epoch)
            tb_writer.add_scalars('Accuracy/train-val', {'train': train_acc, 
                                               'validation': current_accuracy}, epoch)
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device, model_file_name=model_name)
                
        
        # scheduler step/ update learning rate
        # scheduler step/ update learning rate
        if scheduler is not None:
            if isinstance(scheduler, lr_scheduler.ReduceLROnPlateau):
                scheduler.step(train_loss)
                print("Bad Epochs:{}".format(scheduler.num_bad_epochs))
                print("last LR = {}".format(scheduler._last_lr))
            else:
                scheduler.step()
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:green">Optimizer and Scheduler</font>
#
# Let's write optimizer and scheduler as a method because we have to use it in all training experiments.

# %%
def get_optimizer_and_scheduler(model):
    train_config = TrainingConfiguration()

    init_learning_rate = train_config.init_learning_rate

    # optimizer
    optimizer = optim.SGD(
        model.parameters(),
        lr = init_learning_rate,
        momentum = 0.9
    )
    
    factor = 0.5  # reduce by factor 0.5
    patience = 2  # epochs
    verbose = True
    
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, factor=factor, patience=patience, verbose=verbose)
    
    return optimizer, scheduler

# %% [markdown]
# # <font style="color:blue">ResNet Model</font>
# We will load the resnet18 model with its pretrained weights.
#
# The layers are configured such that if you pass the transfer_learning flag, it just replaces the last layers of the network. Otherwise, it will retrain all layers, but with the pretrained weights, not from scratch.

# %%
# def pretrained_resnet18(transfer_learning=True, num_class=3):
#     resnet = models.resnet18(pretrained=True)
    
#     if transfer_learning:
#         for param in resnet.parameters():
#             param.requires_grad = False
            
#     last_layer_in = resnet.fc.in_features
#     resnet.fc = nn.Linear(last_layer_in, num_class)
    
#     return resnet

# def pretrained_inception_v3(transfer_learning=True, num_class=3):
#     inception_v3 = models.inception_v3(pretrained=True)
    
#     if transfer_learning:
#         for param in inception_v3.parameters():

#             param.requires_grad = False
            
#     last_layer_in = inception_v3.fc.in_features
#     inception_v3.fc = nn.Linear(last_layer_in, num_class)
    
#     return inception_v3



def pretrained_inception_v3(transfer_learning=True, num_class=3):
  inception_v3 = models.inception_v3(pretrained=True)

  if transfer_learning:
    for param in inception_v3.parameters():
      param.required_grad = False

  last_layer_in = inception_v3.fc.in_features
  inception_v3.fc = nn.Linear(last_layer_in,num_class)

  return inception_v3

# %%
#####################################################################
def inception_v3(feature_extract= True, num_class=13):
  model =models.inception_v3(pretrained=True,aux_logits=False)

  if feature_extract:
    for param in model.parameters():
      param.requires_grad = False

    for param in model.Mixed_7a.parameters():
      
      param.requires_grad=True

    for param in model.Mixed_7b.parameters():
      
      param.requires_grad=True


    for param in model.Mixed_7c.parameters():
      
      param.requires_grad=True
      


    # for param in model.parameters():
    #   param.aux_logits = False




    last_layer_in = model.fc.in_features

    model.fc = nn.Linear(last_layer_in , num_class)


  return model


################################################
# def inception_v3(feature_extract=True, num_class=13):
#     model = models.inception_v3(pretrained=True)

    
#     if feature_extract:
#         for param in model.parameters():

#             param.requires_grad = False

#         for param in model.parameters():
#           param.aux_logits = False



            
            
# #         for param in model.layer3.parameters():
# #             param.requires_grad = True
            
#         # for param in model.Mixed_7c.parameters():
#         #     param.requires_grad = True
            
            
    

                              
#     last_layer_in = model.fc.in_features
#     model.fc = nn.Linear(last_layer_in, num_class)
    
#     return model









# def inception_v3(pretrained=False, progress=True, **kwargs):
#     r"""Inception v3 model architecture from
#     `"Rethinking the Inception Architecture for Computer Vision" <http://arxiv.org/abs/1512.00567>`_.
#     .. note::
#         **Important**: In contrast to the other models the inception_v3 expects tensors with a size of
#         N x 3 x 299 x 299, so ensure your images are sized accordingly.
#     Args:
#         pretrained (bool): If True, returns a model pre-trained on ImageNet
#         progress (bool): If True, displays a progress bar of the download to stderr
#         aux_logits (bool): If True, add an auxiliary branch that can improve training.
#             Default: *True*
#         transform_input (bool): If True, preprocesses the input according to the method with which it
#             was trained on ImageNet. Default: *False*
#     """
#     if pretrained:
#         if 'transform_input' not in kwargs:
#             kwargs['transform_input'] = True
#         if 'aux_logits' in kwargs:
#             original_aux_logits = kwargs['aux_logits']
#             kwargs['aux_logits'] = True
#         else:
#             original_aux_logits = True
#         model = Inception3(**kwargs)
#         state_dict = load_state_dict_from_url(model_urls['inception_v3_google'],
#                                               progress=progress)
#         model.load_state_dict(state_dict)
#         if not original_aux_logits:
#             model.aux_logits = False
#             del model.AuxLogits
#         return model

#     return Inception3(**kwargs)

# %%
def resnext50_32x4d(transfer_learning=True, num_class=13):
    model = models.resnext50_32x4d(pretrained=True)
    
    if transfer_learning:
        for param in model.parameters():
          
            param.requires_grad = False
            

            
        for param in model.layer4.parameters():
            param.requires_grad = True
            
            
    

                              
    last_layer_in = model.fc.in_features
    model.fc = nn.Linear(last_layer_in, num_class)
    
    return model

# %%
class PreTrainedModel(nn.Module):
    def __init__(self, model_name, freeze_layers, num_class):
        super().__init__()

        # convolution layers
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )
        
        mod = getattr(models, model_name)(pretrained=True)
        
        self.features = mod.features
        
        for name, param in self.features.named_parameters():
            
            if int(name.split('.')[0]) == freeze_layers:
                break
                
            if param.requires_grad:
                param.requires_grad = False
                
        self.avgpool = mod.avgpool
            
        
        # Fully connected layers
        self.classifier = nn.Sequential(
            
            nn.Linear(in_features=25088, out_features=4096), 
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            
            nn.Linear(in_features=4096, out_features=1024), 
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            
            nn.Linear(in_features=1024, out_features=num_class)
        )

    def forward(self, x):
        x = self.features(x)
        
        x = self.avgpool(x)
        
        x = x.view(x.size()[0], -1)
        
        x = self.classifier(x)
        return x

# %% [markdown]
# # <font style="color:blue">Transfer Learning</font>

# %%
model_name = 'inception_v3_with_4thlayer'

freeze_layers = 20

num_class = len(class_names)

#model = PreTrainedModel(model_name, freeze_layers, num_class)
#model = resnext50_32x4d()
model = inception_v3()
#model = torch.hub.load('pytorch/vision:v0.5.0', 'inception_v3', pretrained=True,aux_logits=False,feature_extracting = True,requires_grad=False)
 
#model=Inception_v3(.../,weights='imagenet',include_top=False)


print(model)
# get optimizer and scheduler
optimizer, scheduler = get_optimizer_and_scheduler(model)

# Tensorboard summary writer
logs = 'pretrained2/{}_{}'.format(model_name, freeze_layers)
transfer_learning_sw = SummaryWriter(logs)  

model_name = '{}_{}.pt'.format(model_name, freeze_layers)
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc): Linear(in_features=2048, out_features=13, bias=True)
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, 
                                                       optimizer,
                                                       transfer_learning_sw,
                                                       scheduler,
                                                       data_augmentation=True,
                                                       model_name=model_name)
transfer_learning_sw.close()
# Out:
# Test set: Average loss: 2.6232, Accuracy: 28/666 (4%)
#
# Initial Test Loss : 2.623182,
# Initial Test Accuracy : 4.204%
#
# Batch: 20	Train Loss: 2.9933	Accuracy: 0.000
# Batch: 40	Train Loss: 2.5709	Accuracy: 0.250
# Batch: 60	Train Loss: 2.5448	Accuracy: 0.000
# Batch: 80	Train Loss: 2.6194	Accuracy: 0.250
# Batch: 100	Train Loss: 2.5048	Accuracy: 0.000
# Batch: 120	Train Loss: 2.2541	Accuracy: 0.250
# Batch: 140	Train Loss: 2.4853	Accuracy: 0.000
# Batch: 160	Train Loss: 2.1577	Accuracy: 0.250
# Batch: 180	Train Loss: 2.5947	Accuracy: 0.000
# Batch: 200	Train Loss: 1.9976	Accuracy: 0.500
# Batch: 220	Train Loss: 1.6772	Accuracy: 0.500
# Batch: 240	Train Loss: 2.6684	Accuracy: 0.250
# Batch: 260	Train Loss: 1.1349	Accuracy: 0.750
# Batch: 280	Train Loss: 1.7774	Accuracy: 0.500
# Batch: 300	Train Loss: 2.6925	Accuracy: 0.000
# Batch: 320	Train Loss: 2.0863	Accuracy: 0.250
# Batch: 340	Train Loss: 1.4625	Accuracy: 0.750
# Batch: 360	Train Loss: 2.9017	Accuracy: 0.000
# Batch: 380	Train Loss: 1.8437	Accuracy: 0.500
# Batch: 400	Train Loss: 1.2836	Accuracy: 0.500
# Batch: 420	Train Loss: 1.1109	Accuracy: 0.500
# Batch: 440	Train Loss: 2.6248	Accuracy: 0.000
# Batch: 460	Train Loss: 1.5457	Accuracy: 0.250
# Batch: 480	Train Loss: 1.1850	Accuracy: 0.500
# Batch: 500	Train Loss: 2.5009	Accuracy: 0.250
# Batch: 520	Train Loss: 2.1859	Accuracy: 0.500
# Batch: 540	Train Loss: 1.6842	Accuracy: 0.500
# Batch: 560	Train Loss: 0.3614	Accuracy: 0.750
# Batch: 580	Train Loss: 1.8705	Accuracy: 0.250
# Batch: 600	Train Loss: 1.8756	Accuracy: 0.500
# Batch: 620	Train Loss: 1.8179	Accuracy: 0.500
# Batch: 640	Train Loss: 2.0893	Accuracy: 0.250
# Batch: 660	Train Loss: 0.8325	Accuracy: 0.750
# Epoch: 0
# Train Loss: 2.009187 Acc: 0.3457
# Elapsed 74.44s, 74.44 s/epoch, 0.11 s/batch, ets 1414.39s
#
# Test set: Average loss: 1.3826, Accuracy: 394/666 (59%)
#
# Model Improved. Saving the Model...
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 693	Train Loss: 1.7720	Accuracy: 0.250
# Batch: 713	Train Loss: 1.3216	Accuracy: 0.750
# Batch: 733	Train Loss: 1.0177	Accuracy: 0.750
# Batch: 753	Train Loss: 2.5771	Accuracy: 0.250
# Batch: 773	Train Loss: 0.5707	Accuracy: 1.000
# Batch: 793	Train Loss: 2.0949	Accuracy: 0.500
# Batch: 813	Train Loss: 2.3929	Accuracy: 0.250
# Batch: 833	Train Loss: 1.3697	Accuracy: 0.500
# Batch: 853	Train Loss: 0.8903	Accuracy: 0.750
# Batch: 873	Train Loss: 2.1620	Accuracy: 0.500
# Batch: 893	Train Loss: 1.7884	Accuracy: 0.500
# Batch: 913	Train Loss: 0.7178	Accuracy: 0.750
# Batch: 933	Train Loss: 0.6847	Accuracy: 1.000
# Batch: 953	Train Loss: 0.8554	Accuracy: 0.750
# Batch: 973	Train Loss: 0.8822	Accuracy: 0.750
# Batch: 993	Train Loss: 0.8547	Accuracy: 0.750
# Batch: 1013	Train Loss: 2.1988	Accuracy: 0.500
# Batch: 1033	Train Loss: 1.8219	Accuracy: 0.500
# Batch: 1053	Train Loss: 0.4522	Accuracy: 1.000
# Batch: 1073	Train Loss: 2.2836	Accuracy: 0.250
# Batch: 1093	Train Loss: 0.8046	Accuracy: 0.750
# Batch: 1113	Train Loss: 1.7584	Accuracy: 0.500
# Batch: 1133	Train Loss: 1.5740	Accuracy: 0.500
# Batch: 1153	Train Loss: 1.7303	Accuracy: 0.500
# Batch: 1173	Train Loss: 2.1874	Accuracy: 0.250
# Batch: 1193	Train Loss: 0.6268	Accuracy: 0.750
# Batch: 1213	Train Loss: 1.7903	Accuracy: 0.500
# Batch: 1233	Train Loss: 0.2692	Accuracy: 1.000
# Batch: 1253	Train Loss: 1.2389	Accuracy: 0.500
# Batch: 1273	Train Loss: 1.3357	Accuracy: 0.250
# Batch: 1293	Train Loss: 1.0715	Accuracy: 1.000
# Batch: 1313	Train Loss: 3.7961	Accuracy: 0.250
# Batch: 1333	Train Loss: 2.0425	Accuracy: 0.500
# Epoch: 1
# Train Loss: 1.503095 Acc: 0.5230
# Elapsed 167.49s, 83.75 s/epoch, 0.12 s/batch, ets 1507.42s
#
# Test set: Average loss: 1.4768, Accuracy: 391/666 (59%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 1367	Train Loss: 1.6726	Accuracy: 0.500
# Batch: 1387	Train Loss: 2.2595	Accuracy: 0.250
# Batch: 1407	Train Loss: 0.2446	Accuracy: 1.000
# Batch: 1427	Train Loss: 0.9250	Accuracy: 0.500
# Batch: 1447	Train Loss: 1.4136	Accuracy: 0.500
# Batch: 1467	Train Loss: 1.0539	Accuracy: 0.500
# Batch: 1487	Train Loss: 0.9670	Accuracy: 0.500
# Batch: 1507	Train Loss: 1.0249	Accuracy: 0.750
# Batch: 1527	Train Loss: 0.7047	Accuracy: 0.750
# Batch: 1547	Train Loss: 2.5106	Accuracy: 0.250
# Batch: 1567	Train Loss: 0.7837	Accuracy: 0.500
# Batch: 1587	Train Loss: 1.7467	Accuracy: 0.500
# Batch: 1607	Train Loss: 2.2671	Accuracy: 0.250
# Batch: 1627	Train Loss: 0.9399	Accuracy: 0.750
# Batch: 1647	Train Loss: 1.3114	Accuracy: 0.750
# Batch: 1667	Train Loss: 1.1191	Accuracy: 0.750
# Batch: 1687	Train Loss: 1.0978	Accuracy: 0.750
# Batch: 1707	Train Loss: 1.4217	Accuracy: 0.500
# Batch: 1727	Train Loss: 1.1916	Accuracy: 0.500
# Batch: 1747	Train Loss: 2.8488	Accuracy: 0.500
# Batch: 1767	Train Loss: 0.2233	Accuracy: 1.000
# Batch: 1787	Train Loss: 1.0043	Accuracy: 0.500
# Batch: 1807	Train Loss: 0.9319	Accuracy: 0.500
# Batch: 1827	Train Loss: 1.4563	Accuracy: 0.750
# Batch: 1847	Train Loss: 1.0403	Accuracy: 0.750
# Batch: 1867	Train Loss: 1.5417	Accuracy: 0.500
# Batch: 1887	Train Loss: 0.9047	Accuracy: 0.750
# Batch: 1907	Train Loss: 1.3957	Accuracy: 0.500
# Batch: 1927	Train Loss: 1.9133	Accuracy: 0.500
# Batch: 1947	Train Loss: 1.4945	Accuracy: 0.500
# Batch: 1967	Train Loss: 0.9224	Accuracy: 0.500
# Batch: 1987	Train Loss: 1.2498	Accuracy: 0.750
# Batch: 2007	Train Loss: 1.9485	Accuracy: 0.500
# Epoch: 2
# Train Loss: 1.212955 Acc: 0.6157
# Elapsed 259.83s, 86.61 s/epoch, 0.13 s/batch, ets 1472.35s
#
# Test set: Average loss: 1.2668, Accuracy: 438/666 (66%)
#
# Model Improved. Saving the Model...
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 2040	Train Loss: 0.8751	Accuracy: 0.750
# Batch: 2060	Train Loss: 1.7390	Accuracy: 0.500
# Batch: 2080	Train Loss: 1.9910	Accuracy: 0.500
# Batch: 2100	Train Loss: 1.3178	Accuracy: 0.500
# Batch: 2120	Train Loss: 1.3123	Accuracy: 0.750
# Batch: 2140	Train Loss: 0.3854	Accuracy: 0.750
# Batch: 2160	Train Loss: 0.2328	Accuracy: 1.000
# Batch: 2180	Train Loss: 0.2670	Accuracy: 1.000
# Batch: 2200	Train Loss: 0.3750	Accuracy: 1.000
# Batch: 2220	Train Loss: 0.4087	Accuracy: 1.000
# Batch: 2240	Train Loss: 0.4291	Accuracy: 0.750
# Batch: 2260	Train Loss: 1.4422	Accuracy: 0.500
# Batch: 2280	Train Loss: 0.6557	Accuracy: 0.750
# Batch: 2300	Train Loss: 0.8193	Accuracy: 0.750
# Batch: 2320	Train Loss: 1.1964	Accuracy: 0.500
# Batch: 2340	Train Loss: 2.3100	Accuracy: 0.250
# Batch: 2360	Train Loss: 1.3354	Accuracy: 0.250
# Batch: 2380	Train Loss: 0.6664	Accuracy: 0.750
# Batch: 2400	Train Loss: 1.2658	Accuracy: 0.750
# Batch: 2420	Train Loss: 1.7942	Accuracy: 0.500
# Batch: 2440	Train Loss: 0.2331	Accuracy: 1.000
# Batch: 2460	Train Loss: 1.2998	Accuracy: 0.750
# Batch: 2480	Train Loss: 0.5477	Accuracy: 1.000
# Batch: 2500	Train Loss: 1.0753	Accuracy: 0.500
# Batch: 2520	Train Loss: 0.5574	Accuracy: 0.750
# Batch: 2540	Train Loss: 1.6527	Accuracy: 0.500
# Batch: 2560	Train Loss: 1.7043	Accuracy: 0.750
# Batch: 2580	Train Loss: 0.8155	Accuracy: 0.500
# Batch: 2600	Train Loss: 1.7676	Accuracy: 0.500
# Batch: 2620	Train Loss: 0.5921	Accuracy: 0.750
# Batch: 2640	Train Loss: 0.8886	Accuracy: 0.750
# Batch: 2660	Train Loss: 0.8437	Accuracy: 0.750
# Batch: 2680	Train Loss: 1.4692	Accuracy: 0.500
# Epoch: 3
# Train Loss: 1.071841 Acc: 0.6610
# Elapsed 351.94s, 87.99 s/epoch, 0.13 s/batch, ets 1407.76s
#
# Test set: Average loss: 1.3916, Accuracy: 422/666 (63%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 2714	Train Loss: 0.6941	Accuracy: 0.750
# Batch: 2734	Train Loss: 0.2922	Accuracy: 0.750
# Batch: 2754	Train Loss: 0.8271	Accuracy: 0.500
# Batch: 2774	Train Loss: 1.0296	Accuracy: 0.500
# Batch: 2794	Train Loss: 1.0929	Accuracy: 0.750
# Batch: 2814	Train Loss: 0.4192	Accuracy: 1.000
# Batch: 2834	Train Loss: 1.9125	Accuracy: 0.500
# Batch: 2854	Train Loss: 2.5993	Accuracy: 0.500
# Batch: 2874	Train Loss: 0.7689	Accuracy: 0.750
# Batch: 2894	Train Loss: 0.2231	Accuracy: 1.000
# Batch: 2914	Train Loss: 0.3528	Accuracy: 1.000
# Batch: 2934	Train Loss: 0.7619	Accuracy: 0.750
# Batch: 2954	Train Loss: 0.1687	Accuracy: 1.000
# Batch: 2974	Train Loss: 1.2376	Accuracy: 0.500
# Batch: 2994	Train Loss: 1.4294	Accuracy: 0.750
# Batch: 3014	Train Loss: 1.8366	Accuracy: 0.250
# Batch: 3034	Train Loss: 0.0397	Accuracy: 1.000
# Batch: 3054	Train Loss: 0.6024	Accuracy: 0.750
# Batch: 3074	Train Loss: 0.8653	Accuracy: 0.750
# Batch: 3094	Train Loss: 0.5380	Accuracy: 0.750
# Batch: 3114	Train Loss: 1.2456	Accuracy: 0.750
# Batch: 3134	Train Loss: 2.9074	Accuracy: 0.250
# Batch: 3154	Train Loss: 0.3822	Accuracy: 1.000
# Batch: 3174	Train Loss: 0.4377	Accuracy: 0.750
# Batch: 3194	Train Loss: 0.2710	Accuracy: 1.000
# Batch: 3214	Train Loss: 0.9376	Accuracy: 0.750
# Batch: 3234	Train Loss: 1.6623	Accuracy: 0.250
# Batch: 3254	Train Loss: 0.7888	Accuracy: 0.750
# Batch: 3274	Train Loss: 0.2233	Accuracy: 1.000
# Batch: 3294	Train Loss: 0.5854	Accuracy: 0.750
# Batch: 3314	Train Loss: 0.7288	Accuracy: 0.500
# Batch: 3334	Train Loss: 0.7495	Accuracy: 0.750
# Batch: 3354	Train Loss: 2.4788	Accuracy: 0.500
# Epoch: 4
# Train Loss: 0.954229 Acc: 0.6877
# Elapsed 444.58s, 88.92 s/epoch, 0.13 s/batch, ets 1333.74s
#
# Test set: Average loss: 1.4417, Accuracy: 443/666 (67%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 3387	Train Loss: 0.3551	Accuracy: 0.750
# Batch: 3407	Train Loss: 0.8537	Accuracy: 0.750
# Batch: 3427	Train Loss: 0.3950	Accuracy: 0.750
# Batch: 3447	Train Loss: 0.7291	Accuracy: 0.750
# Batch: 3467	Train Loss: 2.5178	Accuracy: 0.250
# Batch: 3487	Train Loss: 0.9373	Accuracy: 0.750
# Batch: 3507	Train Loss: 0.1672	Accuracy: 1.000
# Batch: 3527	Train Loss: 1.2192	Accuracy: 0.500
# Batch: 3547	Train Loss: 0.1436	Accuracy: 1.000
# Batch: 3567	Train Loss: 0.8656	Accuracy: 0.500
# Batch: 3587	Train Loss: 0.3531	Accuracy: 1.000
# Batch: 3607	Train Loss: 0.4594	Accuracy: 0.750
# Batch: 3627	Train Loss: 1.4144	Accuracy: 0.500
# Batch: 3647	Train Loss: 1.7674	Accuracy: 0.500
# Batch: 3667	Train Loss: 1.1348	Accuracy: 0.500
# Batch: 3687	Train Loss: 0.1358	Accuracy: 1.000
# Batch: 3707	Train Loss: 0.4321	Accuracy: 1.000
# Batch: 3727	Train Loss: 0.5604	Accuracy: 0.750
# Batch: 3747	Train Loss: 1.9327	Accuracy: 0.750
# Batch: 3767	Train Loss: 0.9280	Accuracy: 0.500
# Batch: 3787	Train Loss: 0.2491	Accuracy: 1.000
# Batch: 3807	Train Loss: 0.7171	Accuracy: 0.750
# Batch: 3827	Train Loss: 0.2830	Accuracy: 1.000
# Batch: 3847	Train Loss: 0.5972	Accuracy: 0.750
# Batch: 3867	Train Loss: 0.7611	Accuracy: 0.500
# Batch: 3887	Train Loss: 0.5194	Accuracy: 1.000
# Batch: 3907	Train Loss: 0.4562	Accuracy: 1.000
# Batch: 3927	Train Loss: 0.3907	Accuracy: 1.000
# Batch: 3947	Train Loss: 0.3393	Accuracy: 1.000
# Batch: 3967	Train Loss: 0.3120	Accuracy: 1.000
# Batch: 3987	Train Loss: 2.6327	Accuracy: 0.500
# Batch: 4007	Train Loss: 0.6669	Accuracy: 1.000
# Batch: 4027	Train Loss: 0.1195	Accuracy: 1.000
# Epoch: 5
# Train Loss: 0.784782 Acc: 0.7552
# Elapsed 536.02s, 89.34 s/epoch, 0.13 s/batch, ets 1250.72s
#
# Test set: Average loss: 1.4543, Accuracy: 435/666 (65%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 4061	Train Loss: 1.3819	Accuracy: 0.750
# Batch: 4081	Train Loss: 0.6159	Accuracy: 0.500
# Batch: 4101	Train Loss: 0.7232	Accuracy: 0.750
# Batch: 4121	Train Loss: 0.0084	Accuracy: 1.000
# Batch: 4141	Train Loss: 0.2968	Accuracy: 1.000
# Batch: 4161	Train Loss: 0.6389	Accuracy: 0.750
# Batch: 4181	Train Loss: 0.0295	Accuracy: 1.000
# Batch: 4201	Train Loss: 0.6294	Accuracy: 0.750
# Batch: 4221	Train Loss: 0.2689	Accuracy: 1.000
# Batch: 4241	Train Loss: 0.3509	Accuracy: 0.750
# Batch: 4261	Train Loss: 0.5137	Accuracy: 0.750
# Batch: 4281	Train Loss: 1.6863	Accuracy: 0.500
# Batch: 4301	Train Loss: 1.3643	Accuracy: 0.250
# Batch: 4321	Train Loss: 1.0440	Accuracy: 0.500
# Batch: 4341	Train Loss: 0.0874	Accuracy: 1.000
# Batch: 4361	Train Loss: 0.5781	Accuracy: 0.750
# Batch: 4381	Train Loss: 1.1790	Accuracy: 0.500
# Batch: 4401	Train Loss: 0.0404	Accuracy: 1.000
# Batch: 4421	Train Loss: 2.7219	Accuracy: 0.500
# Batch: 4441	Train Loss: 1.5512	Accuracy: 0.500
# Batch: 4461	Train Loss: 0.2492	Accuracy: 1.000
# Batch: 4481	Train Loss: 0.9445	Accuracy: 0.750
# Batch: 4501	Train Loss: 1.2979	Accuracy: 0.750
# Batch: 4521	Train Loss: 1.7571	Accuracy: 0.750
# Batch: 4541	Train Loss: 0.4386	Accuracy: 1.000
# Batch: 4561	Train Loss: 1.0934	Accuracy: 0.750
# Batch: 4581	Train Loss: 0.8046	Accuracy: 0.500
# Batch: 4601	Train Loss: 0.6510	Accuracy: 0.750
# Batch: 4621	Train Loss: 1.3376	Accuracy: 0.500
# Batch: 4641	Train Loss: 1.0948	Accuracy: 0.500
# Batch: 4661	Train Loss: 0.9846	Accuracy: 0.500
# Batch: 4681	Train Loss: 0.1982	Accuracy: 1.000
# Batch: 4701	Train Loss: 0.7940	Accuracy: 0.750
# Epoch: 6
# Train Loss: 0.685617 Acc: 0.7841
# Elapsed 626.74s, 89.53 s/epoch, 0.13 s/batch, ets 1163.95s
#
# Test set: Average loss: 1.4786, Accuracy: 431/666 (65%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 4734	Train Loss: 0.1827	Accuracy: 1.000
# Batch: 4754	Train Loss: 0.0839	Accuracy: 1.000
# Batch: 4774	Train Loss: 0.3281	Accuracy: 1.000
# Batch: 4794	Train Loss: 0.6577	Accuracy: 0.750
# Batch: 4814	Train Loss: 0.2702	Accuracy: 0.750
# Batch: 4834	Train Loss: 2.4905	Accuracy: 0.500
# Batch: 4854	Train Loss: 0.6852	Accuracy: 0.750
# Batch: 4874	Train Loss: 0.8197	Accuracy: 0.750
# Batch: 4894	Train Loss: 1.1692	Accuracy: 0.500
# Batch: 4914	Train Loss: 1.0630	Accuracy: 0.750
# Batch: 4934	Train Loss: 0.6810	Accuracy: 0.750
# Batch: 4954	Train Loss: 0.5197	Accuracy: 1.000
# Batch: 4974	Train Loss: 0.7227	Accuracy: 0.750
# Batch: 4994	Train Loss: 1.6768	Accuracy: 0.750
# Batch: 5014	Train Loss: 0.2384	Accuracy: 1.000
# Batch: 5034	Train Loss: 0.5716	Accuracy: 0.750
# Batch: 5054	Train Loss: 1.3723	Accuracy: 0.500
# Batch: 5074	Train Loss: 0.1639	Accuracy: 1.000
# Batch: 5094	Train Loss: 0.6350	Accuracy: 1.000
# Batch: 5114	Train Loss: 0.3235	Accuracy: 0.750
# Batch: 5134	Train Loss: 0.4095	Accuracy: 0.750
# Batch: 5154	Train Loss: 1.1404	Accuracy: 0.750
# Batch: 5174	Train Loss: 0.5420	Accuracy: 1.000
# Batch: 5194	Train Loss: 0.1778	Accuracy: 1.000
# Batch: 5214	Train Loss: 0.3829	Accuracy: 1.000
# Batch: 5234	Train Loss: 0.2691	Accuracy: 1.000
# Batch: 5254	Train Loss: 0.0772	Accuracy: 1.000
# Batch: 5274	Train Loss: 0.0894	Accuracy: 1.000
# Batch: 5294	Train Loss: 1.3992	Accuracy: 0.750
# Batch: 5314	Train Loss: 0.4814	Accuracy: 1.000
# Batch: 5334	Train Loss: 1.0176	Accuracy: 0.750
# Batch: 5354	Train Loss: 1.8650	Accuracy: 0.750
# Batch: 5374	Train Loss: 0.2371	Accuracy: 1.000
# Epoch: 7
# Train Loss: 0.612998 Acc: 0.8164
# Elapsed 716.42s, 89.55 s/epoch, 0.13 s/batch, ets 1074.63s
#
# Test set: Average loss: 1.8754, Accuracy: 401/666 (60%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 5408	Train Loss: 0.2285	Accuracy: 1.000
# Batch: 5428	Train Loss: 0.2828	Accuracy: 1.000
# Batch: 5448	Train Loss: 0.1094	Accuracy: 1.000
# Batch: 5468	Train Loss: 0.0303	Accuracy: 1.000
# Batch: 5488	Train Loss: 0.6598	Accuracy: 0.750
# Batch: 5508	Train Loss: 0.1758	Accuracy: 1.000
# Batch: 5528	Train Loss: 0.8173	Accuracy: 0.750
# Batch: 5548	Train Loss: 0.1529	Accuracy: 1.000
# Batch: 5568	Train Loss: 0.4249	Accuracy: 0.750
# Batch: 5588	Train Loss: 0.8397	Accuracy: 0.750
# Batch: 5608	Train Loss: 0.4647	Accuracy: 0.750
# Batch: 5628	Train Loss: 0.4362	Accuracy: 0.750
# Batch: 5648	Train Loss: 0.6177	Accuracy: 0.750
# Batch: 5668	Train Loss: 1.4332	Accuracy: 0.250
# Batch: 5688	Train Loss: 0.1223	Accuracy: 1.000
# Batch: 5708	Train Loss: 0.9617	Accuracy: 0.500
# Batch: 5728	Train Loss: 0.8118	Accuracy: 0.750
# Batch: 5748	Train Loss: 0.3050	Accuracy: 1.000
# Batch: 5768	Train Loss: 1.0908	Accuracy: 0.750
# Batch: 5788	Train Loss: 0.0312	Accuracy: 1.000
# Batch: 5808	Train Loss: 0.7704	Accuracy: 0.750
# Batch: 5828	Train Loss: 0.5110	Accuracy: 0.750
# Batch: 5848	Train Loss: 1.2662	Accuracy: 0.750
# Batch: 5868	Train Loss: 1.6931	Accuracy: 0.500
# Batch: 5888	Train Loss: 0.1744	Accuracy: 1.000
# Batch: 5908	Train Loss: 0.1784	Accuracy: 1.000
# Batch: 5928	Train Loss: 0.1630	Accuracy: 1.000
# Batch: 5948	Train Loss: 0.1270	Accuracy: 1.000
# Batch: 5968	Train Loss: 2.1996	Accuracy: 0.500
# Batch: 5988	Train Loss: 1.0593	Accuracy: 0.750
# Batch: 6008	Train Loss: 0.3694	Accuracy: 0.750
# Batch: 6028	Train Loss: 1.1628	Accuracy: 0.500
# Batch: 6048	Train Loss: 0.1284	Accuracy: 1.000
# Epoch: 8
# Train Loss: 0.502396 Acc: 0.8383
# Elapsed 807.27s, 89.70 s/epoch, 0.13 s/batch, ets 986.67s
#
# Test set: Average loss: 1.8003, Accuracy: 418/666 (63%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 6081	Train Loss: 0.2537	Accuracy: 1.000
# Batch: 6101	Train Loss: 0.1707	Accuracy: 1.000
# Batch: 6121	Train Loss: 0.0699	Accuracy: 1.000
# Batch: 6141	Train Loss: 0.0099	Accuracy: 1.000
# Batch: 6161	Train Loss: 0.1201	Accuracy: 1.000
# Batch: 6181	Train Loss: 1.9294	Accuracy: 0.500
# Batch: 6201	Train Loss: 0.2213	Accuracy: 0.750
# Batch: 6221	Train Loss: 0.0766	Accuracy: 1.000
# Batch: 6241	Train Loss: 0.7175	Accuracy: 0.750
# Batch: 6261	Train Loss: 0.3496	Accuracy: 0.750
# Batch: 6281	Train Loss: 0.4328	Accuracy: 0.750
# Batch: 6301	Train Loss: 0.0961	Accuracy: 1.000
# Batch: 6321	Train Loss: 0.5090	Accuracy: 0.750
# Batch: 6341	Train Loss: 2.7132	Accuracy: 0.250
# Batch: 6361	Train Loss: 0.0802	Accuracy: 1.000
# Batch: 6381	Train Loss: 1.0643	Accuracy: 0.750
# Batch: 6401	Train Loss: 0.1201	Accuracy: 1.000
# Batch: 6421	Train Loss: 0.0324	Accuracy: 1.000
# Batch: 6441	Train Loss: 0.0828	Accuracy: 1.000
# Batch: 6461	Train Loss: 0.0038	Accuracy: 1.000
# Batch: 6481	Train Loss: 0.0510	Accuracy: 1.000
# Batch: 6501	Train Loss: 0.0237	Accuracy: 1.000
# Batch: 6521	Train Loss: 0.1470	Accuracy: 1.000
# Batch: 6541	Train Loss: 0.4617	Accuracy: 0.750
# Batch: 6561	Train Loss: 0.0801	Accuracy: 1.000
# Batch: 6581	Train Loss: 0.1501	Accuracy: 1.000
# Batch: 6601	Train Loss: 0.8018	Accuracy: 0.750
# Batch: 6621	Train Loss: 0.0259	Accuracy: 1.000
# Batch: 6641	Train Loss: 0.4317	Accuracy: 0.750
# Batch: 6661	Train Loss: 0.3050	Accuracy: 1.000
# Batch: 6681	Train Loss: 3.9862	Accuracy: 0.000
# Batch: 6701	Train Loss: 0.6623	Accuracy: 0.750
# Batch: 6721	Train Loss: 0.7815	Accuracy: 0.750
# Epoch: 9
# Train Loss: 0.430239 Acc: 0.8713
# Elapsed 898.50s, 89.85 s/epoch, 0.13 s/batch, ets 898.50s
#
# Test set: Average loss: 1.9167, Accuracy: 413/666 (62%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 6755	Train Loss: 0.6914	Accuracy: 0.500
# Batch: 6775	Train Loss: 0.1256	Accuracy: 1.000
# Batch: 6795	Train Loss: 0.0184	Accuracy: 1.000
# Batch: 6815	Train Loss: 1.4429	Accuracy: 0.500
# Batch: 6835	Train Loss: 0.0487	Accuracy: 1.000
# Batch: 6855	Train Loss: 0.4630	Accuracy: 0.750
# Batch: 6875	Train Loss: 0.2993	Accuracy: 0.750
# Batch: 6895	Train Loss: 0.3327	Accuracy: 0.750
# Batch: 6915	Train Loss: 0.2996	Accuracy: 1.000
# Batch: 6935	Train Loss: 0.4468	Accuracy: 0.750
# Batch: 6955	Train Loss: 1.4340	Accuracy: 0.750
# Batch: 6975	Train Loss: 0.0316	Accuracy: 1.000
# Batch: 6995	Train Loss: 0.7479	Accuracy: 0.750
# Batch: 7015	Train Loss: 0.0897	Accuracy: 1.000
# Batch: 7035	Train Loss: 0.0095	Accuracy: 1.000
# Batch: 7055	Train Loss: 0.7818	Accuracy: 0.750
# Batch: 7075	Train Loss: 0.1236	Accuracy: 1.000
# Batch: 7095	Train Loss: 0.0106	Accuracy: 1.000
# Batch: 7115	Train Loss: 1.0176	Accuracy: 0.750
# Batch: 7135	Train Loss: 0.0170	Accuracy: 1.000
# Batch: 7155	Train Loss: 0.1659	Accuracy: 1.000
# Batch: 7175	Train Loss: 0.8273	Accuracy: 0.750
# Batch: 7195	Train Loss: 0.0770	Accuracy: 1.000
# Batch: 7215	Train Loss: 0.1897	Accuracy: 1.000
# Batch: 7235	Train Loss: 0.0406	Accuracy: 1.000
# Batch: 7255	Train Loss: 0.1167	Accuracy: 1.000
# Batch: 7275	Train Loss: 0.7640	Accuracy: 0.750
# Batch: 7295	Train Loss: 0.8760	Accuracy: 0.750
# Batch: 7315	Train Loss: 0.0135	Accuracy: 1.000
# Batch: 7335	Train Loss: 0.2659	Accuracy: 1.000
# Batch: 7355	Train Loss: 0.2787	Accuracy: 1.000
# Batch: 7375	Train Loss: 0.5224	Accuracy: 0.750
# Batch: 7395	Train Loss: 0.1783	Accuracy: 1.000
# Epoch: 10
# Train Loss: 0.371050 Acc: 0.8765
# Elapsed 989.68s, 89.97 s/epoch, 0.13 s/batch, ets 809.74s
#
# Test set: Average loss: 2.0254, Accuracy: 405/666 (61%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 7428	Train Loss: 0.0807	Accuracy: 1.000
# Batch: 7448	Train Loss: 0.5641	Accuracy: 0.750
# Batch: 7468	Train Loss: 0.0695	Accuracy: 1.000
# Batch: 7488	Train Loss: 0.0145	Accuracy: 1.000
# Batch: 7508	Train Loss: 0.4192	Accuracy: 0.750
# Batch: 7528	Train Loss: 0.5738	Accuracy: 0.750
# Batch: 7548	Train Loss: 0.1602	Accuracy: 1.000
# Batch: 7568	Train Loss: 0.0227	Accuracy: 1.000
# Batch: 7588	Train Loss: 0.9287	Accuracy: 0.500
# Batch: 7608	Train Loss: 0.1132	Accuracy: 1.000
# Batch: 7628	Train Loss: 0.0882	Accuracy: 1.000
# Batch: 7648	Train Loss: 0.7068	Accuracy: 0.750
# Batch: 7668	Train Loss: 0.0916	Accuracy: 1.000
# Batch: 7688	Train Loss: 0.0335	Accuracy: 1.000
# Batch: 7708	Train Loss: 0.1486	Accuracy: 1.000
# Batch: 7728	Train Loss: 0.2499	Accuracy: 0.750
# Batch: 7748	Train Loss: 0.0413	Accuracy: 1.000
# Batch: 7768	Train Loss: 0.6811	Accuracy: 0.750
# Batch: 7788	Train Loss: 0.0702	Accuracy: 1.000
# Batch: 7808	Train Loss: 0.1296	Accuracy: 1.000
# Batch: 7828	Train Loss: 0.3180	Accuracy: 0.750
# Batch: 7848	Train Loss: 0.8255	Accuracy: 0.500
# Batch: 7868	Train Loss: 0.2891	Accuracy: 0.750
# Batch: 7888	Train Loss: 0.0110	Accuracy: 1.000
# Batch: 7908	Train Loss: 0.6886	Accuracy: 0.750
# Batch: 7928	Train Loss: 0.6349	Accuracy: 0.750
# Batch: 7948	Train Loss: 0.4559	Accuracy: 0.750
# Batch: 7968	Train Loss: 0.0304	Accuracy: 1.000
# Batch: 7988	Train Loss: 0.1240	Accuracy: 1.000
# Batch: 8008	Train Loss: 0.0007	Accuracy: 1.000
# Batch: 8028	Train Loss: 0.7223	Accuracy: 0.750
# Batch: 8048	Train Loss: 0.9654	Accuracy: 0.750
# Batch: 8068	Train Loss: 0.0289	Accuracy: 1.000
# Epoch: 11
# Train Loss: 0.335005 Acc: 0.8954
# Elapsed 1080.19s, 90.02 s/epoch, 0.13 s/batch, ets 720.13s
#
# Test set: Average loss: 1.9704, Accuracy: 416/666 (62%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 8102	Train Loss: 0.2033	Accuracy: 1.000
# Batch: 8122	Train Loss: 0.0035	Accuracy: 1.000
# Batch: 8142	Train Loss: 0.0918	Accuracy: 1.000
# Batch: 8162	Train Loss: 0.3061	Accuracy: 0.750
# Batch: 8182	Train Loss: 0.4226	Accuracy: 0.750
# Batch: 8202	Train Loss: 1.2064	Accuracy: 0.500
# Batch: 8222	Train Loss: 0.2015	Accuracy: 1.000
# Batch: 8242	Train Loss: 0.0159	Accuracy: 1.000
# Batch: 8262	Train Loss: 0.3864	Accuracy: 1.000
# Batch: 8282	Train Loss: 0.0380	Accuracy: 1.000
# Batch: 8302	Train Loss: 0.7323	Accuracy: 0.750
# Batch: 8322	Train Loss: 0.3570	Accuracy: 0.750
# Batch: 8342	Train Loss: 0.0639	Accuracy: 1.000
# Batch: 8362	Train Loss: 0.3186	Accuracy: 1.000
# Batch: 8382	Train Loss: 0.1920	Accuracy: 1.000
# Batch: 8402	Train Loss: 1.9980	Accuracy: 0.500
# Batch: 8422	Train Loss: 0.4399	Accuracy: 0.750
# Batch: 8442	Train Loss: 0.0241	Accuracy: 1.000
# Batch: 8462	Train Loss: 0.0730	Accuracy: 1.000
# Batch: 8482	Train Loss: 0.0676	Accuracy: 1.000
# Batch: 8502	Train Loss: 0.0086	Accuracy: 1.000
# Batch: 8522	Train Loss: 0.1938	Accuracy: 1.000
# Batch: 8542	Train Loss: 0.4500	Accuracy: 0.750
# Batch: 8562	Train Loss: 2.0117	Accuracy: 0.500
# Batch: 8582	Train Loss: 0.0548	Accuracy: 1.000
# Batch: 8602	Train Loss: 0.0799	Accuracy: 1.000
# Batch: 8622	Train Loss: 0.0989	Accuracy: 1.000
# Batch: 8642	Train Loss: 0.4686	Accuracy: 0.750
# Batch: 8662	Train Loss: 1.6249	Accuracy: 0.500
# Batch: 8682	Train Loss: 0.5227	Accuracy: 0.750
# Batch: 8702	Train Loss: 0.0153	Accuracy: 1.000
# Batch: 8722	Train Loss: 0.0618	Accuracy: 1.000
# Batch: 8742	Train Loss: 0.0181	Accuracy: 1.000
# Epoch: 12
# Train Loss: 0.330348 Acc: 0.9054
# Elapsed 1170.16s, 90.01 s/epoch, 0.13 s/batch, ets 630.09s
#
# Test set: Average loss: 1.8130, Accuracy: 418/666 (63%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 8775	Train Loss: 0.1205	Accuracy: 1.000
# Batch: 8795	Train Loss: 0.0610	Accuracy: 1.000
# Batch: 8815	Train Loss: 0.1284	Accuracy: 1.000
# Batch: 8835	Train Loss: 0.1031	Accuracy: 1.000
# Batch: 8855	Train Loss: 0.0647	Accuracy: 1.000
# Batch: 8875	Train Loss: 0.7085	Accuracy: 1.000
# Batch: 8895	Train Loss: 0.1097	Accuracy: 1.000
# Batch: 8915	Train Loss: 0.1539	Accuracy: 1.000
# Batch: 8935	Train Loss: 0.3229	Accuracy: 0.750
# Batch: 8955	Train Loss: 0.2679	Accuracy: 0.750
# Batch: 8975	Train Loss: 0.0760	Accuracy: 1.000
# Batch: 8995	Train Loss: 0.0309	Accuracy: 1.000
# Batch: 9015	Train Loss: 0.3626	Accuracy: 0.750
# Batch: 9035	Train Loss: 2.6716	Accuracy: 0.250
# Batch: 9055	Train Loss: 0.0265	Accuracy: 1.000
# Batch: 9075	Train Loss: 0.0377	Accuracy: 1.000
# Batch: 9095	Train Loss: 0.0032	Accuracy: 1.000
# Batch: 9115	Train Loss: 0.4242	Accuracy: 1.000
# Batch: 9135	Train Loss: 0.0048	Accuracy: 1.000
# Batch: 9155	Train Loss: 0.1191	Accuracy: 1.000
# Batch: 9175	Train Loss: 0.1193	Accuracy: 1.000
# Batch: 9195	Train Loss: 0.0638	Accuracy: 1.000
# Batch: 9215	Train Loss: 0.0027	Accuracy: 1.000
# Batch: 9235	Train Loss: 0.0659	Accuracy: 1.000
# Batch: 9255	Train Loss: 0.1971	Accuracy: 1.000
# Batch: 9275	Train Loss: 0.4972	Accuracy: 1.000
# Batch: 9295	Train Loss: 0.0390	Accuracy: 1.000
# Batch: 9315	Train Loss: 0.0515	Accuracy: 1.000
# Batch: 9335	Train Loss: 0.0479	Accuracy: 1.000
# Batch: 9355	Train Loss: 0.5584	Accuracy: 0.750
# Batch: 9375	Train Loss: 1.0421	Accuracy: 0.750
# Batch: 9395	Train Loss: 0.0394	Accuracy: 1.000
# Batch: 9415	Train Loss: 0.0071	Accuracy: 1.000
# Epoch: 13
# Train Loss: 0.292054 Acc: 0.9147
# Elapsed 1259.68s, 89.98 s/epoch, 0.13 s/batch, ets 539.86s
#
# Test set: Average loss: 1.9561, Accuracy: 411/666 (62%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 9449	Train Loss: 0.0130	Accuracy: 1.000
# Batch: 9469	Train Loss: 0.1140	Accuracy: 1.000
# Batch: 9489	Train Loss: 0.8358	Accuracy: 0.750
# Batch: 9509	Train Loss: 1.3955	Accuracy: 0.750
# Batch: 9529	Train Loss: 0.0150	Accuracy: 1.000
# Batch: 9549	Train Loss: 0.1262	Accuracy: 1.000
# Batch: 9569	Train Loss: 0.0313	Accuracy: 1.000
# Batch: 9589	Train Loss: 0.6054	Accuracy: 0.750
# Batch: 9609	Train Loss: 0.0630	Accuracy: 1.000
# Batch: 9629	Train Loss: 0.0267	Accuracy: 1.000
# Batch: 9649	Train Loss: 0.3178	Accuracy: 1.000
# Batch: 9669	Train Loss: 0.2615	Accuracy: 1.000
# Batch: 9689	Train Loss: 0.0029	Accuracy: 1.000
# Batch: 9709	Train Loss: 0.0485	Accuracy: 1.000
# Batch: 9729	Train Loss: 0.7538	Accuracy: 0.750
# Batch: 9749	Train Loss: 0.0276	Accuracy: 1.000
# Batch: 9769	Train Loss: 0.0332	Accuracy: 1.000
# Batch: 9789	Train Loss: 0.0604	Accuracy: 1.000
# Batch: 9809	Train Loss: 0.0234	Accuracy: 1.000
# Batch: 9829	Train Loss: 0.0542	Accuracy: 1.000
# Batch: 9849	Train Loss: 0.0450	Accuracy: 1.000
# Batch: 9869	Train Loss: 0.1032	Accuracy: 1.000
# Batch: 9889	Train Loss: 0.0051	Accuracy: 1.000
# Batch: 9909	Train Loss: 0.0240	Accuracy: 1.000
# Batch: 9929	Train Loss: 0.0320	Accuracy: 1.000
# Batch: 9949	Train Loss: 0.0285	Accuracy: 1.000
# Batch: 9969	Train Loss: 0.3501	Accuracy: 0.750
# Batch: 9989	Train Loss: 1.1905	Accuracy: 0.750
# Batch: 10009	Train Loss: 0.0072	Accuracy: 1.000
# Batch: 10029	Train Loss: 0.1157	Accuracy: 1.000
# Batch: 10049	Train Loss: 0.0004	Accuracy: 1.000
# Batch: 10069	Train Loss: 0.0195	Accuracy: 1.000
# Batch: 10089	Train Loss: 0.0159	Accuracy: 1.000
# Epoch: 14
# Train Loss: 0.273121 Acc: 0.9251
# Elapsed 1351.73s, 90.12 s/epoch, 0.13 s/batch, ets 450.58s
#
# Test set: Average loss: 2.0996, Accuracy: 400/666 (60%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 10122	Train Loss: 0.0887	Accuracy: 1.000
# Batch: 10142	Train Loss: 0.0692	Accuracy: 1.000
# Batch: 10162	Train Loss: 1.4832	Accuracy: 0.500
# Batch: 10182	Train Loss: 1.5291	Accuracy: 0.750
# Batch: 10202	Train Loss: 0.0013	Accuracy: 1.000
# Batch: 10222	Train Loss: 0.0764	Accuracy: 1.000
# Batch: 10242	Train Loss: 0.0099	Accuracy: 1.000
# Batch: 10262	Train Loss: 0.0180	Accuracy: 1.000
# Batch: 10282	Train Loss: 0.0582	Accuracy: 1.000
# Batch: 10302	Train Loss: 0.4743	Accuracy: 0.750
# Batch: 10322	Train Loss: 0.7622	Accuracy: 0.750
# Batch: 10342	Train Loss: 0.3190	Accuracy: 0.750
# Batch: 10362	Train Loss: 0.2740	Accuracy: 1.000
# Batch: 10382	Train Loss: 0.0370	Accuracy: 1.000
# Batch: 10402	Train Loss: 0.1752	Accuracy: 1.000
# Batch: 10422	Train Loss: 1.2072	Accuracy: 0.750
# Batch: 10442	Train Loss: 0.0552	Accuracy: 1.000
# Batch: 10462	Train Loss: 0.0731	Accuracy: 1.000
# Batch: 10482	Train Loss: 0.1025	Accuracy: 1.000
# Batch: 10502	Train Loss: 0.2059	Accuracy: 1.000
# Batch: 10522	Train Loss: 0.0051	Accuracy: 1.000
# Batch: 10542	Train Loss: 0.4200	Accuracy: 0.750
# Batch: 10562	Train Loss: 0.4079	Accuracy: 0.750
# Batch: 10582	Train Loss: 0.0599	Accuracy: 1.000
# Batch: 10602	Train Loss: 0.9095	Accuracy: 0.750
# Batch: 10622	Train Loss: 0.0691	Accuracy: 1.000
# Batch: 10642	Train Loss: 0.0119	Accuracy: 1.000
# Batch: 10662	Train Loss: 0.0765	Accuracy: 1.000
# Batch: 10682	Train Loss: 0.0300	Accuracy: 1.000
# Batch: 10702	Train Loss: 0.0016	Accuracy: 1.000
# Batch: 10722	Train Loss: 0.1729	Accuracy: 1.000
# Batch: 10742	Train Loss: 0.3273	Accuracy: 0.750
# Batch: 10762	Train Loss: 0.8973	Accuracy: 0.500
# Epoch: 15
# Train Loss: 0.269271 Acc: 0.9199
# Elapsed 1444.44s, 90.28 s/epoch, 0.13 s/batch, ets 361.11s
#
# Test set: Average loss: 2.0024, Accuracy: 414/666 (62%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 10796	Train Loss: 0.2827	Accuracy: 1.000
# Batch: 10816	Train Loss: 0.0198	Accuracy: 1.000
# Batch: 10836	Train Loss: 0.2208	Accuracy: 1.000
# Batch: 10856	Train Loss: 0.0783	Accuracy: 1.000
# Batch: 10876	Train Loss: 1.3622	Accuracy: 0.500
# Batch: 10896	Train Loss: 0.0285	Accuracy: 1.000
# Batch: 10916	Train Loss: 0.0066	Accuracy: 1.000
# Batch: 10936	Train Loss: 0.0580	Accuracy: 1.000
# Batch: 10956	Train Loss: 0.0100	Accuracy: 1.000
# Batch: 10976	Train Loss: 0.0412	Accuracy: 1.000
# Batch: 10996	Train Loss: 0.2126	Accuracy: 1.000
# Batch: 11016	Train Loss: 0.1424	Accuracy: 1.000
# Batch: 11036	Train Loss: 0.5543	Accuracy: 0.750
# Batch: 11056	Train Loss: 0.0739	Accuracy: 1.000
# Batch: 11076	Train Loss: 0.0851	Accuracy: 1.000
# Batch: 11096	Train Loss: 0.0317	Accuracy: 1.000
# Batch: 11116	Train Loss: 0.1520	Accuracy: 1.000
# Batch: 11136	Train Loss: 0.1532	Accuracy: 1.000
# Batch: 11156	Train Loss: 0.0029	Accuracy: 1.000
# Batch: 11176	Train Loss: 0.0178	Accuracy: 1.000
# Batch: 11196	Train Loss: 0.6616	Accuracy: 0.750
# Batch: 11216	Train Loss: 0.0418	Accuracy: 1.000
# Batch: 11236	Train Loss: 0.0166	Accuracy: 1.000
# Batch: 11256	Train Loss: 0.4993	Accuracy: 0.750
# Batch: 11276	Train Loss: 0.0225	Accuracy: 1.000
# Batch: 11296	Train Loss: 0.4568	Accuracy: 0.750
# Batch: 11316	Train Loss: 0.0551	Accuracy: 1.000
# Batch: 11336	Train Loss: 0.0314	Accuracy: 1.000
# Batch: 11356	Train Loss: 0.5910	Accuracy: 0.750
# Batch: 11376	Train Loss: 0.1469	Accuracy: 1.000
# Batch: 11396	Train Loss: 0.0634	Accuracy: 1.000
# Batch: 11416	Train Loss: 0.1683	Accuracy: 1.000
# Batch: 11436	Train Loss: 0.1601	Accuracy: 1.000
# Epoch: 16
# Train Loss: 0.211148 Acc: 0.9358
# Elapsed 1535.78s, 90.34 s/epoch, 0.13 s/batch, ets 271.02s
#
# Test set: Average loss: 2.1426, Accuracy: 414/666 (62%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 11469	Train Loss: 0.0921	Accuracy: 1.000
# Batch: 11489	Train Loss: 0.0007	Accuracy: 1.000
# Batch: 11509	Train Loss: 0.0046	Accuracy: 1.000
# Batch: 11529	Train Loss: 0.0229	Accuracy: 1.000
# Batch: 11549	Train Loss: 0.5459	Accuracy: 0.750
# Batch: 11569	Train Loss: 0.2976	Accuracy: 0.750
# Batch: 11589	Train Loss: 0.0667	Accuracy: 1.000
# Batch: 11609	Train Loss: 0.1293	Accuracy: 1.000
# Batch: 11629	Train Loss: 0.5062	Accuracy: 0.750
# Batch: 11649	Train Loss: 0.6033	Accuracy: 0.750
# Batch: 11669	Train Loss: 0.7954	Accuracy: 0.500
# Batch: 11689	Train Loss: 0.2807	Accuracy: 0.750
# Batch: 11709	Train Loss: 0.0492	Accuracy: 1.000
# Batch: 11729	Train Loss: 0.0351	Accuracy: 1.000
# Batch: 11749	Train Loss: 0.0445	Accuracy: 1.000
# Batch: 11769	Train Loss: 0.0096	Accuracy: 1.000
# Batch: 11789	Train Loss: 0.9163	Accuracy: 0.750
# Batch: 11809	Train Loss: 0.0960	Accuracy: 1.000
# Batch: 11829	Train Loss: 1.1050	Accuracy: 0.750
# Batch: 11849	Train Loss: 0.0067	Accuracy: 1.000
# Batch: 11869	Train Loss: 0.0118	Accuracy: 1.000
# Batch: 11889	Train Loss: 0.0071	Accuracy: 1.000
# Batch: 11909	Train Loss: 0.1050	Accuracy: 1.000
# Batch: 11929	Train Loss: 0.5814	Accuracy: 0.750
# Batch: 11949	Train Loss: 0.0067	Accuracy: 1.000
# Batch: 11969	Train Loss: 0.0150	Accuracy: 1.000
# Batch: 11989	Train Loss: 0.0472	Accuracy: 1.000
# Batch: 12009	Train Loss: 0.0024	Accuracy: 1.000
# Batch: 12029	Train Loss: 1.7825	Accuracy: 0.500
# Batch: 12049	Train Loss: 0.1787	Accuracy: 1.000
# Batch: 12069	Train Loss: 0.0030	Accuracy: 1.000
# Batch: 12089	Train Loss: 0.0082	Accuracy: 1.000
# Batch: 12109	Train Loss: 0.0362	Accuracy: 1.000
# Epoch: 17
# Train Loss: 0.215777 Acc: 0.9373
# Elapsed 1627.27s, 90.40 s/epoch, 0.13 s/batch, ets 180.81s
#
# Test set: Average loss: 2.2176, Accuracy: 397/666 (60%)
#
# Bad Epochs:1
# last LR = [0.001]
# Batch: 12143	Train Loss: 0.0060	Accuracy: 1.000
# Batch: 12163	Train Loss: 0.0429	Accuracy: 1.000
# Batch: 12183	Train Loss: 0.0463	Accuracy: 1.000
# Batch: 12203	Train Loss: 0.0460	Accuracy: 1.000
# Batch: 12223	Train Loss: 0.4461	Accuracy: 0.750
# Batch: 12243	Train Loss: 0.0678	Accuracy: 1.000
# Batch: 12263	Train Loss: 1.3721	Accuracy: 0.500
# Batch: 12283	Train Loss: 0.3341	Accuracy: 1.000
# Batch: 12303	Train Loss: 0.0068	Accuracy: 1.000
# Batch: 12323	Train Loss: 0.1209	Accuracy: 1.000
# Batch: 12343	Train Loss: 0.0399	Accuracy: 1.000
# Batch: 12363	Train Loss: 0.0129	Accuracy: 1.000
# Batch: 12383	Train Loss: 1.5155	Accuracy: 0.500
# Batch: 12403	Train Loss: 0.0062	Accuracy: 1.000
# Batch: 12423	Train Loss: 0.0289	Accuracy: 1.000
# Batch: 12443	Train Loss: 0.0166	Accuracy: 1.000
# Batch: 12463	Train Loss: 0.0953	Accuracy: 1.000
# Batch: 12483	Train Loss: 1.6736	Accuracy: 0.750
# Batch: 12503	Train Loss: 0.0085	Accuracy: 1.000
# Batch: 12523	Train Loss: 1.3122	Accuracy: 0.750
# Batch: 12543	Train Loss: 0.0263	Accuracy: 1.000
# Batch: 12563	Train Loss: 1.1462	Accuracy: 0.500
# Batch: 12583	Train Loss: 0.2657	Accuracy: 1.000
# Batch: 12603	Train Loss: 0.0020	Accuracy: 1.000
# Batch: 12623	Train Loss: 0.0090	Accuracy: 1.000
# Batch: 12643	Train Loss: 0.0158	Accuracy: 1.000
# Batch: 12663	Train Loss: 0.1509	Accuracy: 1.000
# Batch: 12683	Train Loss: 0.1907	Accuracy: 1.000
# Batch: 12703	Train Loss: 0.1693	Accuracy: 1.000
# Batch: 12723	Train Loss: 0.0957	Accuracy: 1.000
# Batch: 12743	Train Loss: 0.1219	Accuracy: 1.000
# Batch: 12763	Train Loss: 0.0028	Accuracy: 1.000
# Batch: 12783	Train Loss: 0.0706	Accuracy: 1.000
# Epoch: 18
# Train Loss: 0.199968 Acc: 0.9484
# Elapsed 1718.17s, 90.43 s/epoch, 0.13 s/batch, ets 90.43s
#
# Test set: Average loss: 2.1364, Accuracy: 408/666 (61%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 12816	Train Loss: 0.0712	Accuracy: 1.000
# Batch: 12836	Train Loss: 0.0171	Accuracy: 1.000
# Batch: 12856	Train Loss: 0.0050	Accuracy: 1.000
# Batch: 12876	Train Loss: 1.0624	Accuracy: 0.750
# Batch: 12896	Train Loss: 0.0509	Accuracy: 1.000
# Batch: 12916	Train Loss: 0.1728	Accuracy: 1.000
# Batch: 12936	Train Loss: 0.5872	Accuracy: 0.750
# Batch: 12956	Train Loss: 0.2617	Accuracy: 1.000
# Batch: 12976	Train Loss: 0.2660	Accuracy: 1.000
# Batch: 12996	Train Loss: 0.1535	Accuracy: 1.000
# Batch: 13016	Train Loss: 0.0263	Accuracy: 1.000
# Batch: 13036	Train Loss: 0.0209	Accuracy: 1.000
# Batch: 13056	Train Loss: 0.0002	Accuracy: 1.000
# Batch: 13076	Train Loss: 0.1142	Accuracy: 1.000
# Batch: 13096	Train Loss: 2.0286	Accuracy: 0.750
# Batch: 13116	Train Loss: 0.0121	Accuracy: 1.000
# Batch: 13136	Train Loss: 0.3532	Accuracy: 0.750
# Batch: 13156	Train Loss: 0.2081	Accuracy: 1.000
# Batch: 13176	Train Loss: 0.0104	Accuracy: 1.000
# Batch: 13196	Train Loss: 0.0282	Accuracy: 1.000
# Batch: 13216	Train Loss: 0.0560	Accuracy: 1.000
# Batch: 13236	Train Loss: 0.0014	Accuracy: 1.000
# Batch: 13256	Train Loss: 0.0039	Accuracy: 1.000
# Batch: 13276	Train Loss: 0.4737	Accuracy: 0.750
# Batch: 13296	Train Loss: 0.4206	Accuracy: 0.750
# Batch: 13316	Train Loss: 0.4403	Accuracy: 0.750
# Batch: 13336	Train Loss: 0.0042	Accuracy: 1.000
# Batch: 13356	Train Loss: 0.0052	Accuracy: 1.000
# Batch: 13376	Train Loss: 1.1868	Accuracy: 0.750
# Batch: 13396	Train Loss: 0.0614	Accuracy: 1.000
# Batch: 13416	Train Loss: 0.1523	Accuracy: 1.000
# Batch: 13436	Train Loss: 0.1195	Accuracy: 1.000
# Batch: 13456	Train Loss: 0.0445	Accuracy: 1.000
# Epoch: 19
# Train Loss: 0.191678 Acc: 0.9399
# Elapsed 1811.07s, 90.55 s/epoch, 0.13 s/batch, ets 0.00s
#
# Test set: Average loss: 2.2485, Accuracy: 392/666 (59%)
#
# Bad Epochs:0
# last LR = [0.001]
# Total time: 1828.82, Best Loss: 1.267

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')
