# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import os 
import random
import time
from dataclasses import dataclass

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets, models
from torchvision.transforms import functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.tensorboard import SummaryWriter


from matplotlib import pyplot as plt
from PIL import Image

# %%
 data_root = './'
#data_root = '/kaggle/input/pytorch-opencv-course-classification/'

image_root = os.path.join(data_root, 'images/images')
data_csv_path = os.path.join(data_root, 'train.csv')
test_csv_path = os.path.join(data_root, 'test.csv')
train_csv='train.csv'
val_csv='validation.csv'
valid_fraction=0.2

# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load in 

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the "../input/" directory.
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # Any results you write to the current directory are saved as output.

# %%
def split_train_validation(csv_path, valid_fraction=0.2, train_csv='train.csv', val_csv='validation.csv', print_info=True):
    """
    It takes .csv file that have two column: ['id', 'class'] and create two .csv file for traing and validation. Return a list of classes
    Parms:
    csv_path (str): path of data csv
    valid_fraction (float): fraction for validation data (0 to 1). 
    train_csv (str): train data file path
    val_csv (str): validation data file path
    print_info (boolean): True for print data overview else False
    
    return (list): List of classes 
    """
    data_df = pd.read_csv(csv_path)

    classes = list(data_df['class'].unique())
    
    if print_info:
        print('There is {} classes and its names are the following:\n{}\n'.format(len(classes), classes))
        
    f_val = open(val_csv, 'w')
    f_train = open(train_csv, 'w')
    
    f_val.write('{},{}\n'.format('id', 'class'))
    f_train.write('{},{}\n'.format('id', 'class'))
        
    for i, cls in enumerate(classes):
        cls_data = data_df[data_df['class']==cls]['id'].to_list()
        val_count = int(len(cls_data) * valid_fraction)
        val_data = random.sample(cls_data, k=val_count)
        
        if print_info:
            print('{}.\tCLASS NAME: {}\tTRAIN COUNT: {}\tVALIDATION COUNT: {}'.format(i, cls, len(cls_data)-len(val_data), len(val_data)))
        for img_id in cls_data:
            if img_id in val_data:
                f_val.write('{},{}\n'.format(img_id, cls))
            else:
                f_train.write('{},{}\n'.format(img_id, cls))
    f_val.close()
    f_train.close()
    
    return classes

# %%
class_names = split_train_validation(csv_path=data_csv_path, 
                                     valid_fraction=valid_fraction, 
                                     train_csv=train_csv, 
                                     val_csv=val_csv, 
                                     print_info=True)
# Out:
# There is 13 classes and its names are the following:
# ['githeri', 'ugali', 'kachumbari', 'matoke', 'sukumawiki', 'bhaji', 'mandazi', 'kukuchoma', 'nyamachoma', 'pilau', 'chapati', 'masalachips', 'mukimo']
#
# 0.	CLASS NAME: githeri	TRAIN COUNT: 384	VALIDATION COUNT: 95
# 1.	CLASS NAME: ugali	TRAIN COUNT: 503	VALIDATION COUNT: 125
# 2.	CLASS NAME: kachumbari	TRAIN COUNT: 396	VALIDATION COUNT: 98
# 3.	CLASS NAME: matoke	TRAIN COUNT: 387	VALIDATION COUNT: 96
# 4.	CLASS NAME: sukumawiki	TRAIN COUNT: 322	VALIDATION COUNT: 80
# 5.	CLASS NAME: bhaji	TRAIN COUNT: 506	VALIDATION COUNT: 126
# 6.	CLASS NAME: mandazi	TRAIN COUNT: 496	VALIDATION COUNT: 124
# 7.	CLASS NAME: kukuchoma	TRAIN COUNT: 139	VALIDATION COUNT: 34
# 8.	CLASS NAME: nyamachoma	TRAIN COUNT: 628	VALIDATION COUNT: 156
# 9.	CLASS NAME: pilau	TRAIN COUNT: 264	VALIDATION COUNT: 65
# 10.	CLASS NAME: chapati	TRAIN COUNT: 690	VALIDATION COUNT: 172
# 11.	CLASS NAME: masalachips	TRAIN COUNT: 351	VALIDATION COUNT: 87
# 12.	CLASS NAME: mukimo	TRAIN COUNT: 170	VALIDATION COUNT: 42

# %%
df = pd.read_csv(val_csv)
print(df.head())
print(df.tail())
# Out:
#                      id    class
# 0   4939671543203955477  githeri
# 1  10229702182160656293  githeri
# 2   6709969051567974643  githeri
# 3  13553351930702178275  githeri
# 4  16044883435360842449  githeri
#                         id   class
# 1295   1691778555637836289  mukimo
# 1296   2112842425320350193  mukimo
# 1297   5257010799671376262  mukimo
# 1298  13565196064532595911  mukimo
# 1299   7025428207417401593  mukimo

# %%
class KenyanFood13Dataset(Dataset):
    """
    This custom dataset class take root image directory and csv path
    and return dataset
    """
    
    def __init__(self, image_root, csv_path, classes, image_shape=None, transform=None):
        
        """
        init method of the class.
        
         Parameters:
         
         image_root (string): path of image directory.
         
         csv_path (string): path of train, val or test csv
         
         classes (list): a list of classes 
         
         image_shape (int or tuple or list): [optional] (height, width) int or tuple or list. Defaut is None. 
                                             It is not None image will resize to the given shape.
                                 
         transform (method): method that will take PIL image and transforms it.
         
        """
        
        self.image_root = image_root
        
        data_df = pd.read_csv(csv_path)
        
        self.classes = classes
        
        
        # set image_resize attribute
        if image_shape is not None:
            if isinstance(image_shape, int):
                self.image_shape = (image_shape, image_shape)
            
            elif isinstance(image_shape, tuple) or isinstance(image_shape, list):
                assert len(image_shape) == 1 or len(image_shape) == 2, 'Invalid image_shape tuple size'
                if len(image_shape) == 1:
                    self.image_shape = (image_shape[0], image_shape[0])
                else:
                    self.image_shape = image_shape
            else:
                raise NotImplementedError
        else:
            self.image_shape = image_shape
            
        # set transform attribute
        self.transform = transform
                
        
        # initialize the data dictionary
        self.data_dict = {
            'image_path': [],
            'label': []
        }
        
        cols = data_df.columns
        for i in range(len(data_df)):
            img_id = data_df['id'][i]
            image_path = os.path.join(image_root, '{}.jpg'.format(img_id))
            
            # making compatible with test data also
            if 'class' in cols:
                cls = data_df['class'][i]
                cls_idx = self.classes.index(cls)
                assert 0 <= cls_idx <= 12
            else: 
                cls_idx = None
                
            self.data_dict['image_path'].append(image_path)
            self.data_dict['label'].append(cls_idx)
        
                    
    def __len__(self):
        """
        return length of the dataset
        """
        return len(self.data_dict['label'])
    
    
    def __getitem__(self, idx):
        """
        For given index, return images with resize and preprocessing.
        """
        
        image = Image.open(self.data_dict['image_path'][idx]).convert("RGB")
        
        if self.image_shape is not None:
            height, width = self.image_shape
            image = F.resize(image, self.image_shape)
            
        if self.transform is not None:
            image = self.transform(image)
            
        target = self.data_dict['label'][idx]
        
        return image, target            
                
        
    def classes(self, label):
        """
        Get class names
        """
        return self.classes
    
    def class_to_index(self, class_name):
        """
        Get index of the class
        """
        return self.classes.index(class_name)
    
    def index_to_class(self, class_index):
        """
        Get class name for the class index
        """
        
        return self.classes[class_index]

# %%
val_dataset =  KenyanFood13Dataset(image_root=image_root, csv_path=val_csv, classes=class_names, image_shape=(256, 400))

print('Length of the dataset: {}'.format(len(val_dataset)))

img, trgt = val_dataset[300]

print('Label: {}, Class name: {}'.format(trgt, val_dataset.index_to_class(trgt)))
plt.imshow(img)
plt.show()
# Out:
# Length of the dataset: 1300
# Label: 2, Class name: kachumbari

# %%
preprocess = transforms.Compose([
    transforms.Resize(299),
    transforms.CenterCrop(299),
    transforms.ToTensor()
    ])

val_dataset =  KenyanFood13Dataset(image_root=image_root, csv_path=val_csv, classes=class_names, image_shape=None, transform=preprocess)

# dataloader with dataset
val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=15,
    shuffle=True,
    num_workers=2
    )


# Plot few images
plt.rcParams["figure.figsize"] = (15, 9)
plt.figure
for images, labels in val_loader:
    for i in range(len(labels)):
        plt.subplot(3, 5, i+1)
        img = F.to_pil_image(images[i])
        plt.imshow(img)
        plt.gca().set_title('{}: {}'.format(val_dataset.index_to_class(labels[i]), labels[i]))
    plt.show()
    break

# %%
def image_common_transforms(mean, std):
    
    preprocess = transforms.Compose([
        transforms.Resize(299,299),
        transforms.CenterCrop(299),
        transforms.ToTensor()
        ])
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %%
def data_augmentation_preprocess(mean, std):
    
    initail_transoform = transforms.RandomChoice([
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(90),
        ])
    
    preprocess = transforms.Compose([
        transforms.RandomAffine(degrees=120, translate=(0.2, 0.2), scale=(0.8, 1.2), 
                                shear=(-20, 20, -20, 20), resample=False, fillcolor=(0, 0,0)),
        transforms.RandomErasing(p=0.2, scale=(0.02, 0.2), ratio=(0.3, 3.3), 
                                 value='random', inplace=False),
        transforms.Resize(299,299),
        transforms.RandomCrop(299),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0, hue=0),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
        ])
                
    aug_transforms = transforms.Compose([
        initail_transoform,
        transforms.RandomGrayscale(p=0.1),
        preprocess
        ])
    
    return aug_transforms

# %%
def data_loader(image_root, csv_path, classes, transform, batch_size=4, shuffle=False, num_workers=2):
    dataset =  KenyanFood13Dataset(image_root, csv_path, classes, transform=preprocess)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %%
def get_mean_std():
    
    mean = [0.485, 0.456, 0.406] 
    std = [0.229, 0.224, 0.225]
    
    return mean, std

# %%
def get_data(batch_size, num_workers=4, data_augmentation=True):
           
    mean, std = get_mean_std()
    
    common_transforms = image_common_transforms(mean, std)
        
   
    # if data_augmentation is true 
    # data augmentation implementation
    if data_augmentation:    
        train_transforms = data_augmentation_preprocess(mean, std)
    # else do common transforms
    else:
        train_transforms = common_transforms
        
        
    # train dataloader
    train_loader = data_loader(image_root, 
                               train_csv, 
                               class_names, 
                               train_transforms, 
                               batch_size=batch_size, 
                               shuffle=True, 
                               num_workers=num_workers)
    
    # test dataloader
    test_loader = data_loader(image_root,
                              val_csv,
                              class_names,
                              common_transforms, 
                              batch_size=batch_size, 
                              shuffle=False, 
                              num_workers=num_workers)
    
    
    return train_loader, test_loader

# %%
# %load_ext tensorboard
# # %reload_ext tensorboard

# %tensorboard --logdir logs/resnet18

# %% [markdown]
# ## <font style="color:green">System Configuration</font>

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ## <font style="color:green">Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 4 
    epochs_count: int = 20 
    init_learning_rate: float = 0.001  # initial learning rate for lr scheduler
    decay_rate: float = 0.1  
    log_interval: int = 20  
    test_interval: int = 1  
    num_workers: int = 16 
    device: str = 'cuda'

# %% [markdown]
# ## <font style="color:green">System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:green">Training Function</font>
#
# We are familiar with the training pipeline used in PyTorch.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int, tb_writer: SummaryWriter
) -> None:
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is mandatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = nn.functional.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = nn.functional.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])

        if batch_idx % train_config.log_interval == 0 and batch_idx > 0:
            
            total_batch = epoch_idx * len(train_loader.dataset)/train_config.batch_size + batch_idx
            tb_writer.add_scalar('Loss/train-batch', loss.item(), total_batch)
            tb_writer.add_scalar('Accuracy/train-batch', acc, total_batch)
            print('Batch: {0}\tTrain Loss: {1:.4f}\tAccuracy: {2:.3f}'.format(int(total_batch), loss.item(), acc))
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:green">Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader
) -> float:
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        output = model(data)
        # add loss for each mini batch
        test_loss += nn.functional.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = nn.functional.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='final_model.pt'):
    
    train_config = TrainingConfiguration()
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device[:4] == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device[:4] == 'cuda':
        model.to(device)
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='final_model.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:green">Main Function for Training and Validation</font>
#
# In this section of code, we use the configuration parameters defined above and start the training. Here are the important actions being taken in the code below:
#
# 1. Set up system parameters like CPU/GPU, number of threads etc
# 1. Load the data using dataloaders
# 1. For each epoch, call train function, and for every test interval, call validation function.
# 1. Do `scheduler.step()` to update learning rate for next epoch.
# 1. Set up variables to track loss and accuracy and start training.

# %%
def main(model, optimizer, tb_writer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=False, model_name='final_model1.pt'):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = training_configuration.device
    else:
        device = "cpu"
        batch_size_to_set = 4
        num_workers_to_set = 2

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, init_val_accuracy*100))
    
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch, tb_writer)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])
        
        # add scalar (loss/accuracy) to tensorboard
        tb_writer.add_scalar('Loss/Train',train_loss, epoch)
        tb_writer.add_scalar('Accuracy/Train', train_acc, epoch)

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )
        
        # add time metadata to tensorboard
        tb_writer.add_scalar('Time/elapsed_time', elapsed_time, epoch)
        tb_writer.add_scalar('Time/speed_epoch', speed_epoch, epoch)
        tb_writer.add_scalar('Time/speed_batch', speed_batch, epoch)
        tb_writer.add_scalar('Time/eta', eta, epoch)
        

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            # add scalar (loss/accuracy) to tensorboard
            tb_writer.add_scalar('Loss/Validation', current_loss, epoch)
            tb_writer.add_scalar('Accuracy/Validation', current_accuracy, epoch)
            
            # add scalars (loss/accuracy) to tensorboard
            tb_writer.add_scalars('Loss/train-val', {'train': train_loss, 
                                           'validation': current_loss}, epoch)
            tb_writer.add_scalars('Accuracy/train-val', {'train': train_acc, 
                                               'validation': current_accuracy}, epoch)
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device, model_file_name=model_name)
                
        
        # scheduler step/ update learning rate
        # scheduler step/ update learning rate
        if scheduler is not None:
            if isinstance(scheduler, lr_scheduler.ReduceLROnPlateau):
                scheduler.step(train_loss)
                print("Bad Epochs:{}".format(scheduler.num_bad_epochs))
                print("last LR = {}".format(scheduler._last_lr))
            else:
                scheduler.step()
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:green">Optimizer and Scheduler</font>
#
# Let's write optimizer and scheduler as a method because we have to use it in all training experiments.

# %%
def get_optimizer_and_scheduler(model):
    train_config = TrainingConfiguration()

    init_learning_rate = train_config.init_learning_rate

    # optimizer
    optimizer = optim.SGD(
        model.parameters(),
        lr = init_learning_rate,
        momentum = 0.9
    )
    
    factor = 0.5  # reduce by factor 0.5
    patience = 2  # epochs
    verbose = True
    
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, factor=factor, patience=patience, verbose=verbose)
    
    return optimizer, scheduler

# %% [markdown]
# # <font style="color:blue">ResNet Model</font>
# We will load the resnet18 model with its pretrained weights.
#
# The layers are configured such that if you pass the transfer_learning flag, it just replaces the last layers of the network. Otherwise, it will retrain all layers, but with the pretrained weights, not from scratch.

# %%
# def pretrained_resnet18(transfer_learning=True, num_class=3):
#     resnet = models.resnet18(pretrained=True)
    
#     if transfer_learning:
#         for param in resnet.parameters():
#             param.requires_grad = False
            
#     last_layer_in = resnet.fc.in_features
#     resnet.fc = nn.Linear(last_layer_in, num_class)
    
#     return resnet

def pretrained_inception_v3(transfer_learning=True, num_class=3):
    inception_v3 = models.inception_v3(pretrained=True)
    
    if transfer_learning:
        for param in inception_v3.parameters():
            param.requires_grad = False
            
    last_layer_in = inception_v3.fc.in_features
    inception_v3.fc = nn.Linear(last_layer_in, num_class)
    
    return inception_v3

# %%
# def inception_v3(feature_extract=True, num_class=13):
#     model = models.inception_v3(pretrained=True)

    
#     if feature_extract:
#         for param in model.parameters():
#             param.requires_grad = False
            
# #         for param in model.layer3.parameters():
# #             param.requires_grad = True
            
#         for param in model.Mixed_7c.parameters():
#             param.requires_grad = True
            
            
    

                              
#     last_layer_in = model.fc.in_features
#     model.fc = nn.Linear(last_layer_in, num_class)
    
#     return model

def inception_v3(feature_extract=True, num_class=13):
    model = models.inception_v3(pretrained=True)

    
    if feature_extract:
        for param in model.parameters():
            param.requires_grad = False
            
#         for param in model.layer3.parameters():
#             param.requires_grad = True
            
        for param in model.Mixed_7c.parameters():
            param.requires_grad = True
            
            
    

                              
    last_layer_in = model.fc.in_features
    model.fc = nn.Linear(last_layer_in, num_class)
    
    return model

# %%
def resnext50_32x4d(transfer_learning=True, num_class=13):
    model = models.resnext50_32x4d(pretrained=True)
    
    if transfer_learning:
        for param in model.parameters():
            param.requires_grad = False
            

            
        for param in model.layer4.parameters():
            param.requires_grad = True
            
            
    

                              
    last_layer_in = model.fc.in_features
    model.fc = nn.Linear(last_layer_in, num_class)
    
    return model

# %%
class PreTrainedModel(nn.Module):
    def __init__(self, model_name, freeze_layers, num_class):
        super().__init__()

        # convolution layers
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )
        
        mod = getattr(models, model_name)(pretrained=True)
        
        self.features = mod.features
        
        for name, param in self.features.named_parameters():
            
            if int(name.split('.')[0]) == freeze_layers:
                break
                
            if param.requires_grad:
                param.requires_grad = False
                
        self.avgpool = mod.avgpool
            
        
        # Fully connected layers
        self.classifier = nn.Sequential(
            
            nn.Linear(in_features=25088, out_features=4096), 
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            
            nn.Linear(in_features=4096, out_features=1024), 
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            
            nn.Linear(in_features=1024, out_features=num_class)
        )

    def forward(self, x):
        x = self.features(x)
        
        x = self.avgpool(x)
        
        x = x.view(x.size()[0], -1)
        
        x = self.classifier(x)
        return x

# %% [markdown]
# # <font style="color:blue">Transfer Learning</font>

# %%
model_name = 'inception_v3'

freeze_layers = 20

num_class = len(class_names)

#model = PreTrainedModel(model_name, freeze_layers, num_class)
#model = resnext50_32x4d()
#model = inception_v3()
model = torch.hub.load('pytorch/vision:v0.5.0', 'inception_v3', pretrained=True,aux_logits=False)
 
#model=inception_v3()


print(model)
# get optimizer and scheduler
optimizer, scheduler = get_optimizer_and_scheduler(model)

# Tensorboard summary writer
logs = 'pretrained2/{}_{}'.format(model_name, freeze_layers)
transfer_learning_sw = SummaryWriter(logs)  

model_name = '{}_{}.pt'.format(model_name, freeze_layers)
# Out:
# Downloading: "https://github.com/pytorch/vision/archive/v0.5.0.zip" to /root/.cache/torch/hub/v0.5.0.zip
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/checkpoints/inception_v3_google-1a9a5a14.pth
# HBox(children=(IntProgress(value=0, max=108857766), HTML(value='')))
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, 
                                                       optimizer,
                                                       transfer_learning_sw,
                                                       scheduler,
                                                       data_augmentation=True,
                                                       model_name=model_name)
transfer_learning_sw.close()
# Out:
# Test set: Average loss: 8.9366, Accuracy: 0/1300 (0%)
#
# Initial Test Loss : 8.936580,
# Initial Test Accuracy : 0.000%
#
# Batch: 20	Train Loss: 5.5498	Accuracy: 0.000
# Batch: 40	Train Loss: 1.6327	Accuracy: 0.500
# Batch: 60	Train Loss: 2.1835	Accuracy: 0.250
# Batch: 80	Train Loss: 1.4986	Accuracy: 0.500
# Batch: 100	Train Loss: 2.8693	Accuracy: 0.000
# Batch: 120	Train Loss: 2.0887	Accuracy: 0.250
# Batch: 140	Train Loss: 2.4907	Accuracy: 0.500
# Batch: 160	Train Loss: 2.5019	Accuracy: 0.250
# Batch: 180	Train Loss: 3.1881	Accuracy: 0.000
# Batch: 200	Train Loss: 2.7975	Accuracy: 0.500
# Batch: 220	Train Loss: 2.2977	Accuracy: 0.250
# Batch: 240	Train Loss: 2.5577	Accuracy: 0.000
# Batch: 260	Train Loss: 2.7422	Accuracy: 0.500
# Batch: 280	Train Loss: 2.9520	Accuracy: 0.250
# Batch: 300	Train Loss: 3.4564	Accuracy: 0.000
# Batch: 320	Train Loss: 3.2122	Accuracy: 0.250
# Batch: 340	Train Loss: 0.9070	Accuracy: 0.750
# Batch: 360	Train Loss: 1.5024	Accuracy: 0.500
# Batch: 380	Train Loss: 1.7225	Accuracy: 0.500
# Batch: 400	Train Loss: 1.3326	Accuracy: 0.500
# Batch: 420	Train Loss: 2.2013	Accuracy: 0.250
# Batch: 440	Train Loss: 1.9755	Accuracy: 0.250
# Batch: 460	Train Loss: 2.3765	Accuracy: 0.000
# Batch: 480	Train Loss: 1.3993	Accuracy: 0.500
# Batch: 500	Train Loss: 0.9852	Accuracy: 0.750
# Batch: 520	Train Loss: 2.6965	Accuracy: 0.250
# Batch: 540	Train Loss: 2.1722	Accuracy: 0.000
# Batch: 560	Train Loss: 4.3258	Accuracy: 0.000
# Batch: 580	Train Loss: 1.4359	Accuracy: 0.500
# Batch: 600	Train Loss: 1.3342	Accuracy: 0.750
# Batch: 620	Train Loss: 2.4943	Accuracy: 0.250
# Batch: 640	Train Loss: 1.6756	Accuracy: 0.500
# Batch: 660	Train Loss: 1.4034	Accuracy: 0.750
# Batch: 680	Train Loss: 1.8749	Accuracy: 0.250
# Batch: 700	Train Loss: 2.9763	Accuracy: 0.000
# Batch: 720	Train Loss: 2.0684	Accuracy: 0.250
# Batch: 740	Train Loss: 2.3996	Accuracy: 0.500
# Batch: 760	Train Loss: 2.2247	Accuracy: 0.500
# Batch: 780	Train Loss: 2.2013	Accuracy: 0.500
# Batch: 800	Train Loss: 2.7132	Accuracy: 0.250
# Batch: 820	Train Loss: 2.0930	Accuracy: 0.250
# Batch: 840	Train Loss: 2.1544	Accuracy: 0.000
# Batch: 860	Train Loss: 3.7464	Accuracy: 0.000
# Batch: 880	Train Loss: 2.1363	Accuracy: 0.250
# Batch: 900	Train Loss: 0.7606	Accuracy: 0.750
# Batch: 920	Train Loss: 0.7626	Accuracy: 0.750
# Batch: 940	Train Loss: 1.5461	Accuracy: 0.500
# Batch: 960	Train Loss: 0.6183	Accuracy: 0.750
# Batch: 980	Train Loss: 1.5177	Accuracy: 0.750
# Batch: 1000	Train Loss: 1.5265	Accuracy: 0.500
# Batch: 1020	Train Loss: 2.2298	Accuracy: 0.250
# Batch: 1040	Train Loss: 2.2733	Accuracy: 0.500
# Batch: 1060	Train Loss: 2.0307	Accuracy: 0.250
# Batch: 1080	Train Loss: 2.6119	Accuracy: 0.250
# Batch: 1100	Train Loss: 1.1197	Accuracy: 0.750
# Batch: 1120	Train Loss: 2.3795	Accuracy: 0.000
# Batch: 1140	Train Loss: 0.4938	Accuracy: 1.000
# Batch: 1160	Train Loss: 2.2356	Accuracy: 0.500
# Batch: 1180	Train Loss: 2.5610	Accuracy: 0.500
# Batch: 1200	Train Loss: 1.3674	Accuracy: 0.500
# Batch: 1220	Train Loss: 1.6014	Accuracy: 0.500
# Batch: 1240	Train Loss: 2.2381	Accuracy: 0.250
# Batch: 1260	Train Loss: 2.4211	Accuracy: 0.500
# Batch: 1280	Train Loss: 2.1462	Accuracy: 0.500
# Batch: 1300	Train Loss: 1.2358	Accuracy: 0.250
# Epoch: 0
# Train Loss: 1.930287 Acc: 0.4417
# Elapsed 326.80s, 326.80 s/epoch, 0.25 s/batch, ets 6209.20s
#
# Test set: Average loss: 1.2016, Accuracy: 844/1300 (65%)
#
# Model Improved. Saving the Model...
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 1329	Train Loss: 0.7829	Accuracy: 0.750
# Batch: 1349	Train Loss: 0.7539	Accuracy: 0.750
# Batch: 1369	Train Loss: 0.5359	Accuracy: 1.000
# Batch: 1389	Train Loss: 2.4134	Accuracy: 0.250
# Batch: 1409	Train Loss: 0.3809	Accuracy: 1.000
# Batch: 1429	Train Loss: 0.7196	Accuracy: 0.750
# Batch: 1449	Train Loss: 0.4131	Accuracy: 1.000
# Batch: 1469	Train Loss: 1.1520	Accuracy: 0.750
# Batch: 1489	Train Loss: 0.9705	Accuracy: 0.500
# Batch: 1509	Train Loss: 1.1333	Accuracy: 0.500
# Batch: 1529	Train Loss: 0.7229	Accuracy: 1.000
# Batch: 1549	Train Loss: 2.3884	Accuracy: 0.250
# Batch: 1569	Train Loss: 0.9979	Accuracy: 0.750
# Batch: 1589	Train Loss: 2.4794	Accuracy: 0.250
# Batch: 1609	Train Loss: 1.4901	Accuracy: 0.500
# Batch: 1629	Train Loss: 0.5725	Accuracy: 1.000
# Batch: 1649	Train Loss: 0.6009	Accuracy: 1.000
# Batch: 1669	Train Loss: 2.8595	Accuracy: 0.000
# Batch: 1689	Train Loss: 2.2114	Accuracy: 0.250
# Batch: 1709	Train Loss: 0.8780	Accuracy: 0.500
# Batch: 1729	Train Loss: 1.6843	Accuracy: 0.750
# Batch: 1749	Train Loss: 0.5449	Accuracy: 0.750
# Batch: 1769	Train Loss: 1.5750	Accuracy: 0.500
# Batch: 1789	Train Loss: 1.6920	Accuracy: 0.250
# Batch: 1809	Train Loss: 0.8539	Accuracy: 0.500
# Batch: 1829	Train Loss: 2.6590	Accuracy: 0.250
# Batch: 1849	Train Loss: 1.3223	Accuracy: 0.500
# Batch: 1869	Train Loss: 0.9593	Accuracy: 0.500
# Batch: 1889	Train Loss: 1.7365	Accuracy: 0.500
# Batch: 1909	Train Loss: 1.7478	Accuracy: 0.500
# Batch: 1929	Train Loss: 1.1302	Accuracy: 0.500
# Batch: 1949	Train Loss: 1.1505	Accuracy: 0.750
# Batch: 1969	Train Loss: 1.2212	Accuracy: 0.750
# Batch: 1989	Train Loss: 1.5035	Accuracy: 0.250
# Batch: 2009	Train Loss: 1.4131	Accuracy: 0.500
# Batch: 2029	Train Loss: 1.7791	Accuracy: 0.500
# Batch: 2049	Train Loss: 0.9686	Accuracy: 0.750
# Batch: 2069	Train Loss: 1.1026	Accuracy: 0.500
# Batch: 2089	Train Loss: 0.6030	Accuracy: 0.750
# Batch: 2109	Train Loss: 0.8536	Accuracy: 1.000
# Batch: 2129	Train Loss: 1.8669	Accuracy: 0.500
# Batch: 2149	Train Loss: 2.2041	Accuracy: 0.250
# Batch: 2169	Train Loss: 1.3191	Accuracy: 0.500
# Batch: 2189	Train Loss: 1.1757	Accuracy: 0.500
# Batch: 2209	Train Loss: 0.6802	Accuracy: 0.750
# Batch: 2229	Train Loss: 1.3062	Accuracy: 0.250
# Batch: 2249	Train Loss: 1.3048	Accuracy: 0.250
# Batch: 2269	Train Loss: 0.7269	Accuracy: 0.750
# Batch: 2289	Train Loss: 0.4718	Accuracy: 1.000
# Batch: 2309	Train Loss: 1.4084	Accuracy: 0.500
# Batch: 2329	Train Loss: 2.1585	Accuracy: 0.000
# Batch: 2349	Train Loss: 1.0006	Accuracy: 0.500
# Batch: 2369	Train Loss: 1.6658	Accuracy: 0.500
# Batch: 2389	Train Loss: 1.2314	Accuracy: 0.750
# Batch: 2409	Train Loss: 0.8382	Accuracy: 0.750
# Batch: 2429	Train Loss: 1.8227	Accuracy: 0.500
# Batch: 2449	Train Loss: 1.7032	Accuracy: 0.500
# Batch: 2469	Train Loss: 0.3802	Accuracy: 1.000
# Batch: 2489	Train Loss: 0.5878	Accuracy: 0.750
# Batch: 2509	Train Loss: 0.7776	Accuracy: 0.750
# Batch: 2529	Train Loss: 1.1688	Accuracy: 0.750
# Batch: 2549	Train Loss: 0.8776	Accuracy: 0.500
# Batch: 2569	Train Loss: 1.7372	Accuracy: 0.250
# Batch: 2589	Train Loss: 0.9710	Accuracy: 0.750
# Batch: 2609	Train Loss: 1.5487	Accuracy: 0.250
# Epoch: 1
# Train Loss: 1.342696 Acc: 0.5835
# Elapsed 694.01s, 347.01 s/epoch, 0.27 s/batch, ets 6246.12s
#
# Test set: Average loss: 1.1017, Accuracy: 883/1300 (68%)
#
# Model Improved. Saving the Model...
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 2638	Train Loss: 0.3997	Accuracy: 1.000
# Batch: 2658	Train Loss: 1.7920	Accuracy: 0.250
# Batch: 2678	Train Loss: 2.3066	Accuracy: 0.250
# Batch: 2698	Train Loss: 1.2077	Accuracy: 0.500
# Batch: 2718	Train Loss: 1.1461	Accuracy: 0.750
# Batch: 2738	Train Loss: 1.4219	Accuracy: 0.250
# Batch: 2758	Train Loss: 0.6012	Accuracy: 0.750
# Batch: 2778	Train Loss: 0.1167	Accuracy: 1.000
# Batch: 2798	Train Loss: 0.4107	Accuracy: 0.750
# Batch: 2818	Train Loss: 1.5790	Accuracy: 0.750
# Batch: 2838	Train Loss: 2.3501	Accuracy: 0.500
# Batch: 2858	Train Loss: 0.4199	Accuracy: 1.000
# Batch: 2878	Train Loss: 1.2253	Accuracy: 0.500
# Batch: 2898	Train Loss: 1.8066	Accuracy: 0.500
# Batch: 2918	Train Loss: 1.6765	Accuracy: 0.750
# Batch: 2938	Train Loss: 1.8823	Accuracy: 0.500
# Batch: 2958	Train Loss: 1.5281	Accuracy: 0.750
# Batch: 2978	Train Loss: 1.1046	Accuracy: 0.750
# Batch: 2998	Train Loss: 0.6560	Accuracy: 0.750
# Batch: 3018	Train Loss: 1.4159	Accuracy: 0.500
# Batch: 3038	Train Loss: 1.1281	Accuracy: 0.500
# Batch: 3058	Train Loss: 0.3622	Accuracy: 0.750
# Batch: 3078	Train Loss: 2.6100	Accuracy: 0.250
# Batch: 3098	Train Loss: 2.3318	Accuracy: 0.250
# Batch: 3118	Train Loss: 1.9887	Accuracy: 0.500
# Batch: 3138	Train Loss: 1.0719	Accuracy: 0.500
# Batch: 3158	Train Loss: 1.2330	Accuracy: 0.750
# Batch: 3178	Train Loss: 1.0411	Accuracy: 0.750
# Batch: 3198	Train Loss: 2.9466	Accuracy: 0.500
# Batch: 3218	Train Loss: 1.6718	Accuracy: 0.500
# Batch: 3238	Train Loss: 0.1733	Accuracy: 1.000
# Batch: 3258	Train Loss: 2.7921	Accuracy: 0.250
# Batch: 3278	Train Loss: 1.6316	Accuracy: 0.500
# Batch: 3298	Train Loss: 1.5423	Accuracy: 0.750
# Batch: 3318	Train Loss: 1.2807	Accuracy: 0.500
# Batch: 3338	Train Loss: 1.9271	Accuracy: 0.500
# Batch: 3358	Train Loss: 1.7583	Accuracy: 0.250
# Batch: 3378	Train Loss: 0.4989	Accuracy: 0.750
# Batch: 3398	Train Loss: 0.7516	Accuracy: 0.750
# Batch: 3418	Train Loss: 0.3813	Accuracy: 1.000
# Batch: 3438	Train Loss: 1.5918	Accuracy: 0.500
# Batch: 3458	Train Loss: 1.5743	Accuracy: 0.500
# Batch: 3478	Train Loss: 0.6365	Accuracy: 1.000
# Batch: 3498	Train Loss: 0.3979	Accuracy: 1.000
# Batch: 3518	Train Loss: 1.9336	Accuracy: 0.750
# Batch: 3538	Train Loss: 2.4511	Accuracy: 0.750
# Batch: 3558	Train Loss: 0.1133	Accuracy: 1.000
# Batch: 3578	Train Loss: 1.2975	Accuracy: 0.500
# Batch: 3598	Train Loss: 2.0959	Accuracy: 0.500
# Batch: 3618	Train Loss: 1.7640	Accuracy: 0.500
# Batch: 3638	Train Loss: 0.8736	Accuracy: 0.750
# Batch: 3658	Train Loss: 0.8446	Accuracy: 0.750
# Batch: 3678	Train Loss: 0.4728	Accuracy: 0.750
# Batch: 3698	Train Loss: 1.0713	Accuracy: 0.500
# Batch: 3718	Train Loss: 2.1481	Accuracy: 0.250
# Batch: 3738	Train Loss: 1.1576	Accuracy: 0.750
# Batch: 3758	Train Loss: 1.3566	Accuracy: 0.500
# Batch: 3778	Train Loss: 0.6266	Accuracy: 0.750
# Batch: 3798	Train Loss: 2.3373	Accuracy: 0.500
# Batch: 3818	Train Loss: 2.2366	Accuracy: 0.250
# Batch: 3838	Train Loss: 0.3847	Accuracy: 0.750
# Batch: 3858	Train Loss: 1.6608	Accuracy: 0.500
# Batch: 3878	Train Loss: 1.0145	Accuracy: 0.500
# Batch: 3898	Train Loss: 0.9320	Accuracy: 0.750
# Batch: 3918	Train Loss: 0.4191	Accuracy: 1.000
# Epoch: 2
# Train Loss: 1.111180 Acc: 0.6616
# Elapsed 1060.49s, 353.50 s/epoch, 0.27 s/batch, ets 6009.44s
#
# Test set: Average loss: 1.2333, Accuracy: 850/1300 (65%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 3947	Train Loss: 0.3470	Accuracy: 1.000
# Batch: 3967	Train Loss: 1.3257	Accuracy: 0.750
# Batch: 3987	Train Loss: 0.1961	Accuracy: 1.000
# Batch: 4007	Train Loss: 0.5935	Accuracy: 0.500
# Batch: 4027	Train Loss: 0.1015	Accuracy: 1.000
# Batch: 4047	Train Loss: 0.8656	Accuracy: 0.750
# Batch: 4067	Train Loss: 1.3402	Accuracy: 0.500
# Batch: 4087	Train Loss: 1.0855	Accuracy: 0.750
# Batch: 4107	Train Loss: 1.1740	Accuracy: 0.500
# Batch: 4127	Train Loss: 1.9466	Accuracy: 0.500
# Batch: 4147	Train Loss: 0.4022	Accuracy: 1.000
# Batch: 4167	Train Loss: 0.0823	Accuracy: 1.000
# Batch: 4187	Train Loss: 1.6007	Accuracy: 0.500
# Batch: 4207	Train Loss: 0.0828	Accuracy: 1.000
# Batch: 4227	Train Loss: 0.1673	Accuracy: 1.000
# Batch: 4247	Train Loss: 0.5365	Accuracy: 0.750
# Batch: 4267	Train Loss: 0.1633	Accuracy: 1.000
# Batch: 4287	Train Loss: 0.9217	Accuracy: 0.750
# Batch: 4307	Train Loss: 1.1177	Accuracy: 0.750
# Batch: 4327	Train Loss: 0.1700	Accuracy: 1.000
# Batch: 4347	Train Loss: 0.9511	Accuracy: 0.500
# Batch: 4367	Train Loss: 0.5694	Accuracy: 1.000
# Batch: 4387	Train Loss: 1.2065	Accuracy: 0.500
# Batch: 4407	Train Loss: 0.4016	Accuracy: 0.750
# Batch: 4427	Train Loss: 0.8067	Accuracy: 0.750
# Batch: 4447	Train Loss: 0.5498	Accuracy: 0.750
# Batch: 4467	Train Loss: 1.6277	Accuracy: 0.500
# Batch: 4487	Train Loss: 0.0539	Accuracy: 1.000
# Batch: 4507	Train Loss: 0.4246	Accuracy: 0.750
# Batch: 4527	Train Loss: 0.9929	Accuracy: 0.750
# Batch: 4547	Train Loss: 0.7862	Accuracy: 0.750
# Batch: 4567	Train Loss: 0.4761	Accuracy: 0.750
# Batch: 4587	Train Loss: 0.9920	Accuracy: 0.500
# Batch: 4607	Train Loss: 0.9804	Accuracy: 0.750
# Batch: 4627	Train Loss: 0.4433	Accuracy: 0.750
# Batch: 4647	Train Loss: 0.9481	Accuracy: 0.750
# Batch: 4667	Train Loss: 0.6497	Accuracy: 0.750
# Batch: 4687	Train Loss: 1.1278	Accuracy: 0.750
# Batch: 4707	Train Loss: 0.6811	Accuracy: 0.500
# Batch: 4727	Train Loss: 0.7938	Accuracy: 0.750
# Batch: 4747	Train Loss: 1.1603	Accuracy: 0.750
# Batch: 4767	Train Loss: 0.9116	Accuracy: 0.750
# Batch: 4787	Train Loss: 0.1634	Accuracy: 1.000
# Batch: 4807	Train Loss: 1.2815	Accuracy: 0.250
# Batch: 4827	Train Loss: 0.7056	Accuracy: 1.000
# Batch: 4847	Train Loss: 0.1225	Accuracy: 1.000
# Batch: 4867	Train Loss: 1.4248	Accuracy: 0.500
# Batch: 4887	Train Loss: 0.9637	Accuracy: 0.750
# Batch: 4907	Train Loss: 0.9144	Accuracy: 0.500
# Batch: 4927	Train Loss: 0.1939	Accuracy: 1.000
# Batch: 4947	Train Loss: 0.6933	Accuracy: 0.750
# Batch: 4967	Train Loss: 0.6098	Accuracy: 0.750
# Batch: 4987	Train Loss: 0.1927	Accuracy: 1.000
# Batch: 5007	Train Loss: 1.2694	Accuracy: 0.500
# Batch: 5027	Train Loss: 1.1974	Accuracy: 0.500
# Batch: 5047	Train Loss: 0.3835	Accuracy: 1.000
# Batch: 5067	Train Loss: 1.5961	Accuracy: 0.750
# Batch: 5087	Train Loss: 0.1915	Accuracy: 1.000
# Batch: 5107	Train Loss: 1.1163	Accuracy: 0.750
# Batch: 5127	Train Loss: 1.4699	Accuracy: 0.500
# Batch: 5147	Train Loss: 1.4106	Accuracy: 0.500
# Batch: 5167	Train Loss: 0.7940	Accuracy: 0.750
# Batch: 5187	Train Loss: 1.2475	Accuracy: 0.500
# Batch: 5207	Train Loss: 1.7049	Accuracy: 0.500
# Batch: 5227	Train Loss: 1.1031	Accuracy: 0.750
# Epoch: 3
# Train Loss: 0.894541 Acc: 0.7200
# Elapsed 1425.73s, 356.43 s/epoch, 0.27 s/batch, ets 5702.90s
#
# Test set: Average loss: 1.1597, Accuracy: 895/1300 (69%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 5256	Train Loss: 0.2005	Accuracy: 1.000
# Batch: 5276	Train Loss: 0.4120	Accuracy: 0.750
# Batch: 5296	Train Loss: 0.0419	Accuracy: 1.000
# Batch: 5316	Train Loss: 1.1066	Accuracy: 0.500
# Batch: 5336	Train Loss: 1.4057	Accuracy: 0.250
# Batch: 5356	Train Loss: 1.2727	Accuracy: 0.500
# Batch: 5376	Train Loss: 0.7075	Accuracy: 0.750
# Batch: 5396	Train Loss: 0.5508	Accuracy: 1.000
# Batch: 5416	Train Loss: 0.5572	Accuracy: 0.750
# Batch: 5436	Train Loss: 0.0268	Accuracy: 1.000
# Batch: 5456	Train Loss: 1.7067	Accuracy: 0.750
# Batch: 5476	Train Loss: 0.0607	Accuracy: 1.000
# Batch: 5496	Train Loss: 1.2257	Accuracy: 0.500
# Batch: 5516	Train Loss: 0.3801	Accuracy: 0.750
# Batch: 5536	Train Loss: 0.8490	Accuracy: 0.750
# Batch: 5556	Train Loss: 0.5843	Accuracy: 0.500
# Batch: 5576	Train Loss: 0.9443	Accuracy: 0.750
# Batch: 5596	Train Loss: 1.8519	Accuracy: 0.500
# Batch: 5616	Train Loss: 0.0689	Accuracy: 1.000
# Batch: 5636	Train Loss: 1.3824	Accuracy: 0.500
# Batch: 5656	Train Loss: 0.0685	Accuracy: 1.000
# Batch: 5676	Train Loss: 0.9678	Accuracy: 0.500
# Batch: 5696	Train Loss: 0.7540	Accuracy: 0.750
# Batch: 5716	Train Loss: 0.0737	Accuracy: 1.000
# Batch: 5736	Train Loss: 0.2883	Accuracy: 1.000
# Batch: 5756	Train Loss: 0.9085	Accuracy: 0.750
# Batch: 5776	Train Loss: 0.7602	Accuracy: 0.750
# Batch: 5796	Train Loss: 0.7546	Accuracy: 0.500
# Batch: 5816	Train Loss: 0.8452	Accuracy: 0.750
# Batch: 5836	Train Loss: 1.1542	Accuracy: 0.750
# Batch: 5856	Train Loss: 0.4737	Accuracy: 0.750
# Batch: 5876	Train Loss: 0.1525	Accuracy: 1.000
# Batch: 5896	Train Loss: 2.2036	Accuracy: 0.250
# Batch: 5916	Train Loss: 1.3812	Accuracy: 0.500
# Batch: 5936	Train Loss: 0.2878	Accuracy: 1.000
# Batch: 5956	Train Loss: 0.9915	Accuracy: 0.500
# Batch: 5976	Train Loss: 0.3015	Accuracy: 0.750
# Batch: 5996	Train Loss: 0.0359	Accuracy: 1.000
# Batch: 6016	Train Loss: 0.9243	Accuracy: 0.750
# Batch: 6036	Train Loss: 1.3871	Accuracy: 0.750
# Batch: 6056	Train Loss: 2.1584	Accuracy: 0.250
# Batch: 6076	Train Loss: 0.5983	Accuracy: 0.750
# Batch: 6096	Train Loss: 0.5266	Accuracy: 0.750
# Batch: 6116	Train Loss: 0.1834	Accuracy: 1.000
# Batch: 6136	Train Loss: 1.2628	Accuracy: 0.500
# Batch: 6156	Train Loss: 0.3111	Accuracy: 0.750
# Batch: 6176	Train Loss: 0.1777	Accuracy: 1.000
# Batch: 6196	Train Loss: 0.2973	Accuracy: 1.000
# Batch: 6216	Train Loss: 0.5568	Accuracy: 1.000
# Batch: 6236	Train Loss: 0.2906	Accuracy: 1.000
# Batch: 6256	Train Loss: 0.8325	Accuracy: 0.750
# Batch: 6276	Train Loss: 0.5007	Accuracy: 1.000
# Batch: 6296	Train Loss: 0.5728	Accuracy: 0.750
# Batch: 6316	Train Loss: 0.2634	Accuracy: 1.000
# Batch: 6336	Train Loss: 1.1122	Accuracy: 0.750
# Batch: 6356	Train Loss: 1.6128	Accuracy: 0.750
# Batch: 6376	Train Loss: 0.4647	Accuracy: 1.000
# Batch: 6396	Train Loss: 0.2722	Accuracy: 1.000
# Batch: 6416	Train Loss: 0.2762	Accuracy: 1.000
# Batch: 6436	Train Loss: 0.9657	Accuracy: 0.750
# Batch: 6456	Train Loss: 1.5993	Accuracy: 0.750
# Batch: 6476	Train Loss: 0.1397	Accuracy: 1.000
# Batch: 6496	Train Loss: 0.1522	Accuracy: 1.000
# Batch: 6516	Train Loss: 0.7271	Accuracy: 0.750
# Batch: 6536	Train Loss: 0.7143	Accuracy: 0.750
# Epoch: 4
# Train Loss: 0.756731 Acc: 0.7613
# Elapsed 1789.18s, 357.84 s/epoch, 0.27 s/batch, ets 5367.54s
#
# Test set: Average loss: 1.2360, Accuracy: 908/1300 (70%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 6565	Train Loss: 0.1980	Accuracy: 1.000
# Batch: 6585	Train Loss: 0.5605	Accuracy: 0.750
# Batch: 6605	Train Loss: 1.1356	Accuracy: 0.750
# Batch: 6625	Train Loss: 0.7811	Accuracy: 0.750
# Batch: 6645	Train Loss: 0.3410	Accuracy: 1.000
# Batch: 6665	Train Loss: 0.5113	Accuracy: 0.500
# Batch: 6685	Train Loss: 1.0804	Accuracy: 0.750
# Batch: 6705	Train Loss: 0.0834	Accuracy: 1.000
# Batch: 6725	Train Loss: 1.8079	Accuracy: 0.250
# Batch: 6745	Train Loss: 0.8068	Accuracy: 0.750
# Batch: 6765	Train Loss: 0.7181	Accuracy: 0.750
# Batch: 6785	Train Loss: 0.1068	Accuracy: 1.000
# Batch: 6805	Train Loss: 0.0169	Accuracy: 1.000
# Batch: 6825	Train Loss: 0.3310	Accuracy: 0.750
# Batch: 6845	Train Loss: 0.4177	Accuracy: 0.750
# Batch: 6865	Train Loss: 0.0458	Accuracy: 1.000
# Batch: 6885	Train Loss: 0.2550	Accuracy: 1.000
# Batch: 6905	Train Loss: 0.9038	Accuracy: 0.500
# Batch: 6925	Train Loss: 0.2291	Accuracy: 1.000
# Batch: 6945	Train Loss: 0.3863	Accuracy: 0.750
# Batch: 6965	Train Loss: 0.5777	Accuracy: 0.750
# Batch: 6985	Train Loss: 0.5371	Accuracy: 0.750
# Batch: 7005	Train Loss: 0.9156	Accuracy: 0.500
# Batch: 7025	Train Loss: 0.0516	Accuracy: 1.000
# Batch: 7045	Train Loss: 1.0753	Accuracy: 0.750
# Batch: 7065	Train Loss: 0.8736	Accuracy: 0.750
# Batch: 7085	Train Loss: 0.8858	Accuracy: 0.750
# Batch: 7105	Train Loss: 0.2420	Accuracy: 1.000
# Batch: 7125	Train Loss: 1.4200	Accuracy: 0.500
# Batch: 7145	Train Loss: 0.3071	Accuracy: 0.750
# Batch: 7165	Train Loss: 0.6287	Accuracy: 0.750
# Batch: 7185	Train Loss: 1.4941	Accuracy: 0.500
# Batch: 7205	Train Loss: 0.2284	Accuracy: 1.000
# Batch: 7225	Train Loss: 0.1558	Accuracy: 1.000
# Batch: 7245	Train Loss: 0.1865	Accuracy: 1.000
# Batch: 7265	Train Loss: 0.5050	Accuracy: 0.750
# Batch: 7285	Train Loss: 1.6015	Accuracy: 0.750
# Batch: 7305	Train Loss: 0.2938	Accuracy: 1.000
# Batch: 7325	Train Loss: 0.6770	Accuracy: 0.750
# Batch: 7345	Train Loss: 0.5766	Accuracy: 1.000
# Batch: 7365	Train Loss: 1.6059	Accuracy: 0.500
# Batch: 7385	Train Loss: 1.4108	Accuracy: 0.750
# Batch: 7405	Train Loss: 0.5628	Accuracy: 0.750
# Batch: 7425	Train Loss: 0.0100	Accuracy: 1.000
# Batch: 7445	Train Loss: 1.3934	Accuracy: 0.750
# Batch: 7465	Train Loss: 0.2369	Accuracy: 0.750
# Batch: 7485	Train Loss: 0.7493	Accuracy: 0.750
# Batch: 7505	Train Loss: 1.0574	Accuracy: 0.500
# Batch: 7525	Train Loss: 0.3020	Accuracy: 0.750
# Batch: 7545	Train Loss: 0.0435	Accuracy: 1.000
# Batch: 7565	Train Loss: 0.5661	Accuracy: 1.000
# Batch: 7585	Train Loss: 0.0773	Accuracy: 1.000
# Batch: 7605	Train Loss: 0.6791	Accuracy: 0.750
# Batch: 7625	Train Loss: 0.7263	Accuracy: 0.750
# Batch: 7645	Train Loss: 0.3510	Accuracy: 1.000
# Batch: 7665	Train Loss: 0.1752	Accuracy: 1.000
# Batch: 7685	Train Loss: 1.2510	Accuracy: 0.500
# Batch: 7705	Train Loss: 1.7179	Accuracy: 0.500
# Batch: 7725	Train Loss: 0.1869	Accuracy: 1.000
# Batch: 7745	Train Loss: 0.7948	Accuracy: 0.750
# Batch: 7765	Train Loss: 2.1982	Accuracy: 0.750
# Batch: 7785	Train Loss: 1.2039	Accuracy: 0.750
# Batch: 7805	Train Loss: 1.7388	Accuracy: 0.750
# Batch: 7825	Train Loss: 0.2899	Accuracy: 1.000
# Batch: 7845	Train Loss: 0.2076	Accuracy: 1.000
# Epoch: 5
# Train Loss: 0.625588 Acc: 0.8065
# Elapsed 2155.57s, 359.26 s/epoch, 0.27 s/batch, ets 5029.65s
#
# Test set: Average loss: 1.4883, Accuracy: 869/1300 (67%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 7874	Train Loss: 0.1204	Accuracy: 1.000
# Batch: 7894	Train Loss: 0.4078	Accuracy: 1.000
# Batch: 7914	Train Loss: 0.5824	Accuracy: 0.750
# Batch: 7934	Train Loss: 0.5566	Accuracy: 0.750
# Batch: 7954	Train Loss: 1.4912	Accuracy: 0.750
# Batch: 7974	Train Loss: 0.7914	Accuracy: 0.750
# Batch: 7994	Train Loss: 0.3783	Accuracy: 1.000
# Batch: 8014	Train Loss: 0.0571	Accuracy: 1.000
# Batch: 8034	Train Loss: 0.2067	Accuracy: 1.000
# Batch: 8054	Train Loss: 0.1355	Accuracy: 1.000
# Batch: 8074	Train Loss: 0.4910	Accuracy: 0.750
# Batch: 8094	Train Loss: 0.1097	Accuracy: 1.000
# Batch: 8114	Train Loss: 0.1229	Accuracy: 1.000
# Batch: 8134	Train Loss: 0.1799	Accuracy: 1.000
# Batch: 8154	Train Loss: 1.0511	Accuracy: 0.500
# Batch: 8174	Train Loss: 0.4869	Accuracy: 0.750
# Batch: 8194	Train Loss: 0.0957	Accuracy: 1.000
# Batch: 8214	Train Loss: 0.5149	Accuracy: 0.750
# Batch: 8234	Train Loss: 0.2094	Accuracy: 1.000
# Batch: 8254	Train Loss: 0.2511	Accuracy: 1.000
# Batch: 8274	Train Loss: 0.0349	Accuracy: 1.000
# Batch: 8294	Train Loss: 0.2668	Accuracy: 1.000
# Batch: 8314	Train Loss: 1.6127	Accuracy: 0.750
# Batch: 8334	Train Loss: 0.6697	Accuracy: 0.500
# Batch: 8354	Train Loss: 0.4797	Accuracy: 0.750
# Batch: 8374	Train Loss: 0.7803	Accuracy: 0.750
# Batch: 8394	Train Loss: 0.2959	Accuracy: 1.000
# Batch: 8414	Train Loss: 0.1351	Accuracy: 1.000
# Batch: 8434	Train Loss: 1.0373	Accuracy: 0.500
# Batch: 8454	Train Loss: 1.1798	Accuracy: 0.750
# Batch: 8474	Train Loss: 0.5325	Accuracy: 0.750
# Batch: 8494	Train Loss: 0.6032	Accuracy: 0.750
# Batch: 8514	Train Loss: 0.5166	Accuracy: 0.750
# Batch: 8534	Train Loss: 0.8813	Accuracy: 0.500
# Batch: 8554	Train Loss: 0.0047	Accuracy: 1.000
# Batch: 8574	Train Loss: 0.7160	Accuracy: 0.750
# Batch: 8594	Train Loss: 0.4009	Accuracy: 0.750
# Batch: 8614	Train Loss: 0.3583	Accuracy: 1.000
# Batch: 8634	Train Loss: 0.8674	Accuracy: 0.500
# Batch: 8654	Train Loss: 0.0221	Accuracy: 1.000
# Batch: 8674	Train Loss: 0.1962	Accuracy: 1.000
# Batch: 8694	Train Loss: 1.7179	Accuracy: 0.500
# Batch: 8714	Train Loss: 0.1319	Accuracy: 1.000
# Batch: 8734	Train Loss: 0.0970	Accuracy: 1.000
# Batch: 8754	Train Loss: 0.2861	Accuracy: 1.000
# Batch: 8774	Train Loss: 0.1714	Accuracy: 1.000
# Batch: 8794	Train Loss: 0.7671	Accuracy: 0.750
# Batch: 8814	Train Loss: 0.0422	Accuracy: 1.000
# Batch: 8834	Train Loss: 0.0660	Accuracy: 1.000
# Batch: 8854	Train Loss: 0.3676	Accuracy: 0.750
# Batch: 8874	Train Loss: 0.4737	Accuracy: 0.750
# Batch: 8894	Train Loss: 0.3422	Accuracy: 0.750
# Batch: 8914	Train Loss: 1.2484	Accuracy: 0.750
# Batch: 8934	Train Loss: 0.0670	Accuracy: 1.000
# Batch: 8954	Train Loss: 0.6077	Accuracy: 0.750
# Batch: 8974	Train Loss: 2.0828	Accuracy: 0.500
# Batch: 8994	Train Loss: 0.0708	Accuracy: 1.000
# Batch: 9014	Train Loss: 0.8398	Accuracy: 0.750
# Batch: 9034	Train Loss: 0.2756	Accuracy: 0.750
# Batch: 9054	Train Loss: 0.2206	Accuracy: 1.000
# Batch: 9074	Train Loss: 0.2424	Accuracy: 1.000
# Batch: 9094	Train Loss: 2.3108	Accuracy: 0.500
# Batch: 9114	Train Loss: 0.0091	Accuracy: 1.000
# Batch: 9134	Train Loss: 0.1212	Accuracy: 1.000
# Batch: 9154	Train Loss: 0.1819	Accuracy: 1.000
# Epoch: 6
# Train Loss: 0.518777 Acc: 0.8400
# Elapsed 2519.45s, 359.92 s/epoch, 0.27 s/batch, ets 4678.98s
#
# Test set: Average loss: 1.2164, Accuracy: 920/1300 (71%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 9183	Train Loss: 1.1227	Accuracy: 0.750
# Batch: 9203	Train Loss: 0.1336	Accuracy: 1.000
# Batch: 9223	Train Loss: 0.6121	Accuracy: 0.750
# Batch: 9243	Train Loss: 0.9522	Accuracy: 0.750
# Batch: 9263	Train Loss: 1.2235	Accuracy: 0.500
# Batch: 9283	Train Loss: 0.4191	Accuracy: 0.750
# Batch: 9303	Train Loss: 0.6065	Accuracy: 0.750
# Batch: 9323	Train Loss: 0.5196	Accuracy: 0.750
# Batch: 9343	Train Loss: 0.1176	Accuracy: 1.000
# Batch: 9363	Train Loss: 0.7135	Accuracy: 0.750
# Batch: 9383	Train Loss: 0.2181	Accuracy: 1.000
# Batch: 9403	Train Loss: 0.0283	Accuracy: 1.000
# Batch: 9423	Train Loss: 0.1465	Accuracy: 1.000
# Batch: 9443	Train Loss: 0.3218	Accuracy: 0.750
# Batch: 9463	Train Loss: 0.0684	Accuracy: 1.000
# Batch: 9483	Train Loss: 0.1727	Accuracy: 1.000
# Batch: 9503	Train Loss: 0.1716	Accuracy: 1.000
# Batch: 9523	Train Loss: 1.2829	Accuracy: 0.750
# Batch: 9543	Train Loss: 0.0196	Accuracy: 1.000
# Batch: 9563	Train Loss: 1.4217	Accuracy: 0.750
# Batch: 9583	Train Loss: 0.9402	Accuracy: 0.500
# Batch: 9603	Train Loss: 0.2445	Accuracy: 0.750
# Batch: 9623	Train Loss: 0.0603	Accuracy: 1.000
# Batch: 9643	Train Loss: 0.0173	Accuracy: 1.000
# Batch: 9663	Train Loss: 0.0588	Accuracy: 1.000
# Batch: 9683	Train Loss: 0.1202	Accuracy: 1.000
# Batch: 9703	Train Loss: 1.0593	Accuracy: 0.750
# Batch: 9723	Train Loss: 0.4282	Accuracy: 0.750
# Batch: 9743	Train Loss: 0.6101	Accuracy: 0.500
# Batch: 9763	Train Loss: 1.1086	Accuracy: 0.500
# Batch: 9783	Train Loss: 0.3712	Accuracy: 1.000
# Batch: 9803	Train Loss: 0.0388	Accuracy: 1.000
# Batch: 9823	Train Loss: 0.4365	Accuracy: 0.750
# Batch: 9843	Train Loss: 0.5312	Accuracy: 0.750
# Batch: 9863	Train Loss: 0.5253	Accuracy: 0.750
# Batch: 9883	Train Loss: 0.0906	Accuracy: 1.000
# Batch: 9903	Train Loss: 0.5405	Accuracy: 0.750
# Batch: 9923	Train Loss: 0.0411	Accuracy: 1.000
# Batch: 9943	Train Loss: 1.9182	Accuracy: 0.500
# Batch: 9963	Train Loss: 0.2703	Accuracy: 1.000
# Batch: 9983	Train Loss: 0.1868	Accuracy: 1.000
# Batch: 10003	Train Loss: 0.1132	Accuracy: 1.000
# Batch: 10023	Train Loss: 0.2787	Accuracy: 1.000
# Batch: 10043	Train Loss: 0.2971	Accuracy: 0.750
# Batch: 10063	Train Loss: 0.4891	Accuracy: 0.750
# Batch: 10083	Train Loss: 0.3466	Accuracy: 1.000
# Batch: 10103	Train Loss: 0.3287	Accuracy: 0.750
# Batch: 10123	Train Loss: 0.4900	Accuracy: 0.750
# Batch: 10143	Train Loss: 0.8527	Accuracy: 0.750
# Batch: 10163	Train Loss: 0.3629	Accuracy: 1.000
# Batch: 10183	Train Loss: 1.1438	Accuracy: 0.750
# Batch: 10203	Train Loss: 0.8146	Accuracy: 0.500
# Batch: 10223	Train Loss: 0.1569	Accuracy: 1.000
# Batch: 10243	Train Loss: 0.5963	Accuracy: 0.750
# Batch: 10263	Train Loss: 0.2022	Accuracy: 1.000
# Batch: 10283	Train Loss: 1.3071	Accuracy: 0.500
# Batch: 10303	Train Loss: 0.0683	Accuracy: 1.000
# Batch: 10323	Train Loss: 1.3763	Accuracy: 0.750
# Batch: 10343	Train Loss: 0.7502	Accuracy: 0.500
# Batch: 10363	Train Loss: 1.2017	Accuracy: 0.750
# Batch: 10383	Train Loss: 1.1743	Accuracy: 0.750
# Batch: 10403	Train Loss: 0.5530	Accuracy: 0.500
# Batch: 10423	Train Loss: 1.4831	Accuracy: 0.250
# Batch: 10443	Train Loss: 0.0996	Accuracy: 1.000
# Batch: 10463	Train Loss: 0.4490	Accuracy: 0.750
# Epoch: 7
# Train Loss: 0.484887 Acc: 0.8497
# Elapsed 2886.50s, 360.81 s/epoch, 0.28 s/batch, ets 4329.74s
#
# Test set: Average loss: 1.3548, Accuracy: 877/1300 (67%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 10492	Train Loss: 0.0133	Accuracy: 1.000
# Batch: 10512	Train Loss: 0.0527	Accuracy: 1.000
# Batch: 10532	Train Loss: 0.1915	Accuracy: 1.000
# Batch: 10552	Train Loss: 0.9227	Accuracy: 0.500
# Batch: 10572	Train Loss: 1.3207	Accuracy: 0.500
# Batch: 10592	Train Loss: 0.0670	Accuracy: 1.000
# Batch: 10612	Train Loss: 0.0155	Accuracy: 1.000
# Batch: 10632	Train Loss: 0.0816	Accuracy: 1.000
# Batch: 10652	Train Loss: 0.1591	Accuracy: 1.000
# Batch: 10672	Train Loss: 1.0632	Accuracy: 0.750
# Batch: 10692	Train Loss: 0.0187	Accuracy: 1.000
# Batch: 10712	Train Loss: 1.6233	Accuracy: 0.500
# Batch: 10732	Train Loss: 0.1022	Accuracy: 1.000
# Batch: 10752	Train Loss: 0.2223	Accuracy: 1.000
# Batch: 10772	Train Loss: 0.3597	Accuracy: 1.000
# Batch: 10792	Train Loss: 0.3006	Accuracy: 1.000
# Batch: 10812	Train Loss: 0.5309	Accuracy: 0.750
# Batch: 10832	Train Loss: 0.0290	Accuracy: 1.000
# Batch: 10852	Train Loss: 0.0478	Accuracy: 1.000
# Batch: 10872	Train Loss: 0.0998	Accuracy: 1.000
# Batch: 10892	Train Loss: 0.0240	Accuracy: 1.000
# Batch: 10912	Train Loss: 1.1015	Accuracy: 0.750
# Batch: 10932	Train Loss: 0.7540	Accuracy: 0.750
# Batch: 10952	Train Loss: 0.6400	Accuracy: 0.750
# Batch: 10972	Train Loss: 0.2116	Accuracy: 1.000
# Batch: 10992	Train Loss: 0.6432	Accuracy: 0.500
# Batch: 11012	Train Loss: 1.9907	Accuracy: 0.250
# Batch: 11032	Train Loss: 0.8153	Accuracy: 0.750
# Batch: 11052	Train Loss: 0.2796	Accuracy: 1.000
# Batch: 11072	Train Loss: 0.0212	Accuracy: 1.000
# Batch: 11092	Train Loss: 0.0320	Accuracy: 1.000
# Batch: 11112	Train Loss: 1.8164	Accuracy: 0.500
# Batch: 11132	Train Loss: 0.1458	Accuracy: 1.000
# Batch: 11152	Train Loss: 0.0064	Accuracy: 1.000
# Batch: 11172	Train Loss: 0.0029	Accuracy: 1.000
# Batch: 11192	Train Loss: 0.0303	Accuracy: 1.000
# Batch: 11212	Train Loss: 0.2061	Accuracy: 0.750
# Batch: 11232	Train Loss: 0.3351	Accuracy: 1.000
# Batch: 11252	Train Loss: 0.0023	Accuracy: 1.000
# Batch: 11272	Train Loss: 0.2375	Accuracy: 0.750
# Batch: 11292	Train Loss: 0.0686	Accuracy: 1.000
# Batch: 11312	Train Loss: 0.1907	Accuracy: 1.000
# Batch: 11332	Train Loss: 0.1631	Accuracy: 1.000
# Batch: 11352	Train Loss: 0.0193	Accuracy: 1.000
# Batch: 11372	Train Loss: 0.1043	Accuracy: 1.000
# Batch: 11392	Train Loss: 1.9611	Accuracy: 0.500
# Batch: 11412	Train Loss: 1.3115	Accuracy: 0.750
# Batch: 11432	Train Loss: 0.0977	Accuracy: 1.000
# Batch: 11452	Train Loss: 0.1493	Accuracy: 1.000
# Batch: 11472	Train Loss: 0.2967	Accuracy: 1.000
# Batch: 11492	Train Loss: 0.2035	Accuracy: 1.000
# Batch: 11512	Train Loss: 0.1162	Accuracy: 1.000
# Batch: 11532	Train Loss: 0.0088	Accuracy: 1.000
# Batch: 11552	Train Loss: 0.4818	Accuracy: 0.750
# Batch: 11572	Train Loss: 0.0153	Accuracy: 1.000
# Batch: 11592	Train Loss: 0.4091	Accuracy: 0.750
# Batch: 11612	Train Loss: 0.0370	Accuracy: 1.000
# Batch: 11632	Train Loss: 0.1135	Accuracy: 1.000
# Batch: 11652	Train Loss: 0.0970	Accuracy: 1.000
# Batch: 11672	Train Loss: 0.6457	Accuracy: 0.750
# Batch: 11692	Train Loss: 1.3885	Accuracy: 0.750
# Batch: 11712	Train Loss: 0.0086	Accuracy: 1.000
# Batch: 11732	Train Loss: 0.1468	Accuracy: 1.000
# Batch: 11752	Train Loss: 0.0140	Accuracy: 1.000
# Batch: 11772	Train Loss: 0.4034	Accuracy: 0.750
# Epoch: 8
# Train Loss: 0.390612 Acc: 0.8787
# Elapsed 3252.77s, 361.42 s/epoch, 0.28 s/batch, ets 3975.61s
#
# Test set: Average loss: 1.3405, Accuracy: 891/1300 (69%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 11801	Train Loss: 0.0396	Accuracy: 1.000
# Batch: 11821	Train Loss: 0.6714	Accuracy: 0.750
# Batch: 11841	Train Loss: 0.0613	Accuracy: 1.000
# Batch: 11861	Train Loss: 0.1662	Accuracy: 1.000
# Batch: 11881	Train Loss: 0.0063	Accuracy: 1.000
# Batch: 11901	Train Loss: 0.0160	Accuracy: 1.000
# Batch: 11921	Train Loss: 0.8992	Accuracy: 0.750
# Batch: 11941	Train Loss: 0.2294	Accuracy: 1.000
# Batch: 11961	Train Loss: 0.0972	Accuracy: 1.000
# Batch: 11981	Train Loss: 0.0022	Accuracy: 1.000
# Batch: 12001	Train Loss: 0.7290	Accuracy: 0.750
# Batch: 12021	Train Loss: 0.0263	Accuracy: 1.000
# Batch: 12041	Train Loss: 0.0915	Accuracy: 1.000
# Batch: 12061	Train Loss: 0.5241	Accuracy: 0.750
# Batch: 12081	Train Loss: 0.0146	Accuracy: 1.000
# Batch: 12101	Train Loss: 0.0884	Accuracy: 1.000
# Batch: 12121	Train Loss: 0.0043	Accuracy: 1.000
# Batch: 12141	Train Loss: 1.4131	Accuracy: 0.750
# Batch: 12161	Train Loss: 0.0105	Accuracy: 1.000
# Batch: 12181	Train Loss: 2.1370	Accuracy: 0.250
# Batch: 12201	Train Loss: 0.0996	Accuracy: 1.000
# Batch: 12221	Train Loss: 0.0409	Accuracy: 1.000
# Batch: 12241	Train Loss: 0.8554	Accuracy: 0.500
# Batch: 12261	Train Loss: 0.0149	Accuracy: 1.000
# Batch: 12281	Train Loss: 0.1407	Accuracy: 1.000
# Batch: 12301	Train Loss: 0.1881	Accuracy: 1.000
# Batch: 12321	Train Loss: 0.0888	Accuracy: 1.000
# Batch: 12341	Train Loss: 0.9213	Accuracy: 0.750
# Batch: 12361	Train Loss: 0.0292	Accuracy: 1.000
# Batch: 12381	Train Loss: 0.1252	Accuracy: 1.000
# Batch: 12401	Train Loss: 0.2281	Accuracy: 1.000
# Batch: 12421	Train Loss: 0.3590	Accuracy: 0.750
# Batch: 12441	Train Loss: 0.8471	Accuracy: 0.750
# Batch: 12461	Train Loss: 0.0665	Accuracy: 1.000
# Batch: 12481	Train Loss: 0.1754	Accuracy: 1.000
# Batch: 12501	Train Loss: 0.0408	Accuracy: 1.000
# Batch: 12521	Train Loss: 0.7886	Accuracy: 0.500
# Batch: 12541	Train Loss: 0.1351	Accuracy: 1.000
# Batch: 12561	Train Loss: 0.8873	Accuracy: 0.750
# Batch: 12581	Train Loss: 0.0223	Accuracy: 1.000
# Batch: 12601	Train Loss: 0.0372	Accuracy: 1.000
# Batch: 12621	Train Loss: 0.2268	Accuracy: 1.000
# Batch: 12641	Train Loss: 0.0109	Accuracy: 1.000
# Batch: 12661	Train Loss: 1.6837	Accuracy: 0.500
# Batch: 12681	Train Loss: 0.1359	Accuracy: 1.000
# Batch: 12701	Train Loss: 0.0267	Accuracy: 1.000
# Batch: 12721	Train Loss: 0.1365	Accuracy: 1.000
# Batch: 12741	Train Loss: 0.4222	Accuracy: 1.000
# Batch: 12761	Train Loss: 0.0536	Accuracy: 1.000
# Batch: 12781	Train Loss: 0.0921	Accuracy: 1.000
# Batch: 12801	Train Loss: 0.3069	Accuracy: 1.000
# Batch: 12821	Train Loss: 0.9334	Accuracy: 0.750
# Batch: 12841	Train Loss: 0.0122	Accuracy: 1.000
# Batch: 12861	Train Loss: 0.0044	Accuracy: 1.000
# Batch: 12881	Train Loss: 0.0235	Accuracy: 1.000
# Batch: 12901	Train Loss: 0.2862	Accuracy: 0.750
# Batch: 12921	Train Loss: 0.3781	Accuracy: 1.000
# Batch: 12941	Train Loss: 0.1332	Accuracy: 1.000
# Batch: 12961	Train Loss: 1.0037	Accuracy: 0.750
# Batch: 12981	Train Loss: 0.0059	Accuracy: 1.000
# Batch: 13001	Train Loss: 0.3572	Accuracy: 0.750
# Batch: 13021	Train Loss: 1.1956	Accuracy: 0.500
# Batch: 13041	Train Loss: 0.0066	Accuracy: 1.000
# Batch: 13061	Train Loss: 0.0382	Accuracy: 1.000
# Batch: 13081	Train Loss: 0.1494	Accuracy: 1.000
# Epoch: 9
# Train Loss: 0.339954 Acc: 0.8938
# Elapsed 3620.07s, 362.01 s/epoch, 0.28 s/batch, ets 3620.07s
#
# Test set: Average loss: 1.2875, Accuracy: 909/1300 (70%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 13110	Train Loss: 0.1134	Accuracy: 1.000
# Batch: 13130	Train Loss: 0.0474	Accuracy: 1.000
# Batch: 13150	Train Loss: 0.5874	Accuracy: 0.750
# Batch: 13170	Train Loss: 1.0799	Accuracy: 0.750
# Batch: 13190	Train Loss: 0.0755	Accuracy: 1.000
# Batch: 13210	Train Loss: 1.7218	Accuracy: 0.750
# Batch: 13230	Train Loss: 1.9225	Accuracy: 0.500
# Batch: 13250	Train Loss: 0.6558	Accuracy: 0.750
# Batch: 13270	Train Loss: 0.2582	Accuracy: 0.750
# Batch: 13290	Train Loss: 0.0362	Accuracy: 1.000
# Batch: 13310	Train Loss: 0.0331	Accuracy: 1.000
# Batch: 13330	Train Loss: 0.3585	Accuracy: 0.750
# Batch: 13350	Train Loss: 0.2555	Accuracy: 1.000
# Batch: 13370	Train Loss: 0.0108	Accuracy: 1.000
# Batch: 13390	Train Loss: 0.0482	Accuracy: 1.000
# Batch: 13410	Train Loss: 0.7726	Accuracy: 0.750
# Batch: 13430	Train Loss: 0.1645	Accuracy: 1.000
# Batch: 13450	Train Loss: 0.4303	Accuracy: 0.750
# Batch: 13470	Train Loss: 0.0599	Accuracy: 1.000
# Batch: 13490	Train Loss: 0.0571	Accuracy: 1.000
# Batch: 13510	Train Loss: 0.1224	Accuracy: 1.000
# Batch: 13530	Train Loss: 1.4706	Accuracy: 0.750
# Batch: 13550	Train Loss: 0.0073	Accuracy: 1.000
# Batch: 13570	Train Loss: 0.0139	Accuracy: 1.000
# Batch: 13590	Train Loss: 0.0554	Accuracy: 1.000
# Batch: 13610	Train Loss: 0.4499	Accuracy: 0.750
# Batch: 13630	Train Loss: 0.2545	Accuracy: 1.000
# Batch: 13650	Train Loss: 0.2334	Accuracy: 1.000
# Batch: 13670	Train Loss: 0.0122	Accuracy: 1.000
# Batch: 13690	Train Loss: 0.8841	Accuracy: 0.750
# Batch: 13710	Train Loss: 0.3857	Accuracy: 0.750
# Batch: 13730	Train Loss: 1.7474	Accuracy: 0.500
# Batch: 13750	Train Loss: 0.7864	Accuracy: 0.750
# Batch: 13770	Train Loss: 0.0510	Accuracy: 1.000
# Batch: 13790	Train Loss: 0.0917	Accuracy: 1.000
# Batch: 13810	Train Loss: 0.1683	Accuracy: 1.000
# Batch: 13830	Train Loss: 0.1674	Accuracy: 1.000
# Batch: 13850	Train Loss: 0.1336	Accuracy: 1.000
# Batch: 13870	Train Loss: 0.0061	Accuracy: 1.000
# Batch: 13890	Train Loss: 0.0663	Accuracy: 1.000
# Batch: 13910	Train Loss: 0.2997	Accuracy: 0.750
# Batch: 13930	Train Loss: 1.0833	Accuracy: 0.500
# Batch: 13950	Train Loss: 0.0342	Accuracy: 1.000
# Batch: 13970	Train Loss: 0.1539	Accuracy: 1.000
# Batch: 13990	Train Loss: 1.1824	Accuracy: 0.750
# Batch: 14010	Train Loss: 0.0665	Accuracy: 1.000
# Batch: 14030	Train Loss: 0.3295	Accuracy: 0.750
# Batch: 14050	Train Loss: 0.0116	Accuracy: 1.000
# Batch: 14070	Train Loss: 0.2089	Accuracy: 1.000
# Batch: 14090	Train Loss: 0.4165	Accuracy: 0.750
# Batch: 14110	Train Loss: 1.6185	Accuracy: 0.750
# Batch: 14130	Train Loss: 0.0362	Accuracy: 1.000
# Batch: 14150	Train Loss: 0.3855	Accuracy: 0.750
# Batch: 14170	Train Loss: 0.0201	Accuracy: 1.000
# Batch: 14190	Train Loss: 0.3075	Accuracy: 1.000
# Batch: 14210	Train Loss: 0.4122	Accuracy: 1.000
# Batch: 14230	Train Loss: 0.0102	Accuracy: 1.000
# Batch: 14250	Train Loss: 0.0895	Accuracy: 1.000
# Batch: 14270	Train Loss: 0.0035	Accuracy: 1.000
# Batch: 14290	Train Loss: 0.0044	Accuracy: 1.000
# Batch: 14310	Train Loss: 0.0064	Accuracy: 1.000
# Batch: 14330	Train Loss: 0.0367	Accuracy: 1.000
# Batch: 14350	Train Loss: 0.5506	Accuracy: 0.750
# Batch: 14370	Train Loss: 0.2439	Accuracy: 0.750
# Batch: 14390	Train Loss: 0.3311	Accuracy: 0.750
# Epoch: 10
# Train Loss: 0.311602 Acc: 0.9066
# Elapsed 3985.36s, 362.31 s/epoch, 0.28 s/batch, ets 3260.75s
#
# Test set: Average loss: 1.3411, Accuracy: 911/1300 (70%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 14419	Train Loss: 0.2750	Accuracy: 1.000
# Batch: 14439	Train Loss: 0.1760	Accuracy: 1.000
# Batch: 14459	Train Loss: 0.0207	Accuracy: 1.000
# Batch: 14479	Train Loss: 0.1492	Accuracy: 1.000
# Batch: 14499	Train Loss: 0.1510	Accuracy: 1.000
# Batch: 14519	Train Loss: 0.0118	Accuracy: 1.000
# Batch: 14539	Train Loss: 0.0249	Accuracy: 1.000
# Batch: 14559	Train Loss: 0.0018	Accuracy: 1.000
# Batch: 14579	Train Loss: 0.0070	Accuracy: 1.000
# Batch: 14599	Train Loss: 0.0014	Accuracy: 1.000
# Batch: 14619	Train Loss: 0.0052	Accuracy: 1.000
# Batch: 14639	Train Loss: 0.0228	Accuracy: 1.000
# Batch: 14659	Train Loss: 0.0106	Accuracy: 1.000
# Batch: 14679	Train Loss: 0.0600	Accuracy: 1.000
# Batch: 14699	Train Loss: 0.0102	Accuracy: 1.000
# Batch: 14719	Train Loss: 1.2368	Accuracy: 0.500
# Batch: 14739	Train Loss: 0.2098	Accuracy: 0.750
# Batch: 14759	Train Loss: 0.4771	Accuracy: 0.750
# Batch: 14779	Train Loss: 0.0110	Accuracy: 1.000
# Batch: 14799	Train Loss: 0.0029	Accuracy: 1.000
# Batch: 14819	Train Loss: 0.9532	Accuracy: 0.500
# Batch: 14839	Train Loss: 1.0162	Accuracy: 0.750
# Batch: 14859	Train Loss: 0.0802	Accuracy: 1.000
# Batch: 14879	Train Loss: 0.0091	Accuracy: 1.000
# Batch: 14899	Train Loss: 1.4260	Accuracy: 0.500
# Batch: 14919	Train Loss: 0.7720	Accuracy: 0.750
# Batch: 14939	Train Loss: 0.0477	Accuracy: 1.000
# Batch: 14959	Train Loss: 0.3825	Accuracy: 0.750
# Batch: 14979	Train Loss: 0.0450	Accuracy: 1.000
# Batch: 14999	Train Loss: 0.2739	Accuracy: 0.750
# Batch: 15019	Train Loss: 0.0650	Accuracy: 1.000
# Batch: 15039	Train Loss: 0.0658	Accuracy: 1.000
# Batch: 15059	Train Loss: 0.0133	Accuracy: 1.000
# Batch: 15079	Train Loss: 1.0545	Accuracy: 0.750
# Batch: 15099	Train Loss: 0.0371	Accuracy: 1.000
# Batch: 15119	Train Loss: 0.8176	Accuracy: 0.750
# Batch: 15139	Train Loss: 0.1797	Accuracy: 1.000
# Batch: 15159	Train Loss: 0.4648	Accuracy: 0.750
# Batch: 15179	Train Loss: 0.3993	Accuracy: 0.750
# Batch: 15199	Train Loss: 0.0105	Accuracy: 1.000
# Batch: 15219	Train Loss: 0.0236	Accuracy: 1.000
# Batch: 15239	Train Loss: 0.0629	Accuracy: 1.000
# Batch: 15259	Train Loss: 0.0265	Accuracy: 1.000
# Batch: 15279	Train Loss: 0.1193	Accuracy: 1.000
# Batch: 15299	Train Loss: 0.5186	Accuracy: 0.750
# Batch: 15319	Train Loss: 0.4288	Accuracy: 0.750
# Batch: 15339	Train Loss: 0.1085	Accuracy: 1.000
# Batch: 15359	Train Loss: 0.0389	Accuracy: 1.000
# Batch: 15379	Train Loss: 0.2488	Accuracy: 1.000
# Batch: 15399	Train Loss: 0.2230	Accuracy: 0.750
# Batch: 15419	Train Loss: 0.6495	Accuracy: 0.750
# Batch: 15439	Train Loss: 1.3095	Accuracy: 0.750
# Batch: 15459	Train Loss: 0.3573	Accuracy: 1.000
# Batch: 15479	Train Loss: 1.2891	Accuracy: 0.750
# Batch: 15499	Train Loss: 0.1490	Accuracy: 1.000
# Batch: 15519	Train Loss: 0.5403	Accuracy: 0.750
# Batch: 15539	Train Loss: 0.4152	Accuracy: 0.750
# Batch: 15559	Train Loss: 0.0033	Accuracy: 1.000
# Batch: 15579	Train Loss: 0.1791	Accuracy: 1.000
# Batch: 15599	Train Loss: 0.0898	Accuracy: 1.000
# Batch: 15619	Train Loss: 2.6828	Accuracy: 0.500
# Batch: 15639	Train Loss: 0.3470	Accuracy: 0.750
# Batch: 15659	Train Loss: 0.0323	Accuracy: 1.000
# Batch: 15679	Train Loss: 0.2116	Accuracy: 0.750
# Batch: 15699	Train Loss: 0.0160	Accuracy: 1.000
# Epoch: 11
# Train Loss: 0.280039 Acc: 0.9154
# Elapsed 4350.95s, 362.58 s/epoch, 0.28 s/batch, ets 2900.63s
#
# Test set: Average loss: 1.3940, Accuracy: 891/1300 (69%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 15728	Train Loss: 0.4529	Accuracy: 0.750
# Batch: 15748	Train Loss: 1.2001	Accuracy: 0.750
# Batch: 15768	Train Loss: 0.0037	Accuracy: 1.000
# Batch: 15788	Train Loss: 0.0059	Accuracy: 1.000
# Batch: 15808	Train Loss: 0.0776	Accuracy: 1.000
# Batch: 15828	Train Loss: 0.1465	Accuracy: 1.000
# Batch: 15848	Train Loss: 1.5745	Accuracy: 0.750
# Batch: 15868	Train Loss: 1.0940	Accuracy: 0.500
# Batch: 15888	Train Loss: 0.0387	Accuracy: 1.000
# Batch: 15908	Train Loss: 0.2627	Accuracy: 0.750
# Batch: 15928	Train Loss: 0.0783	Accuracy: 1.000
# Batch: 15948	Train Loss: 0.0602	Accuracy: 1.000
# Batch: 15968	Train Loss: 0.3394	Accuracy: 0.750
# Batch: 15988	Train Loss: 0.0710	Accuracy: 1.000
# Batch: 16008	Train Loss: 0.0303	Accuracy: 1.000
# Batch: 16028	Train Loss: 1.3386	Accuracy: 0.500
# Batch: 16048	Train Loss: 0.0241	Accuracy: 1.000
# Batch: 16068	Train Loss: 1.0732	Accuracy: 0.750
# Batch: 16088	Train Loss: 0.0132	Accuracy: 1.000
# Batch: 16108	Train Loss: 0.1159	Accuracy: 1.000
# Batch: 16128	Train Loss: 0.0739	Accuracy: 1.000
# Batch: 16148	Train Loss: 0.7019	Accuracy: 0.750
# Batch: 16168	Train Loss: 0.1977	Accuracy: 1.000
# Batch: 16188	Train Loss: 0.0095	Accuracy: 1.000
# Batch: 16208	Train Loss: 0.0659	Accuracy: 1.000
# Batch: 16228	Train Loss: 0.1032	Accuracy: 1.000
# Batch: 16248	Train Loss: 0.0158	Accuracy: 1.000
# Batch: 16268	Train Loss: 0.0785	Accuracy: 1.000
# Batch: 16288	Train Loss: 0.3950	Accuracy: 0.750
# Batch: 16308	Train Loss: 0.2629	Accuracy: 0.750
# Batch: 16328	Train Loss: 0.0546	Accuracy: 1.000
# Batch: 16348	Train Loss: 0.5413	Accuracy: 1.000
# Batch: 16368	Train Loss: 0.0345	Accuracy: 1.000
# Batch: 16388	Train Loss: 0.1535	Accuracy: 1.000
# Batch: 16408	Train Loss: 0.2634	Accuracy: 1.000
# Batch: 16428	Train Loss: 0.6469	Accuracy: 0.750
# Batch: 16448	Train Loss: 0.1646	Accuracy: 1.000
# Batch: 16468	Train Loss: 0.2115	Accuracy: 0.750
# Batch: 16488	Train Loss: 0.6585	Accuracy: 0.750
# Batch: 16508	Train Loss: 0.0073	Accuracy: 1.000
# Batch: 16528	Train Loss: 0.0461	Accuracy: 1.000
# Batch: 16548	Train Loss: 0.0175	Accuracy: 1.000
# Batch: 16568	Train Loss: 0.0184	Accuracy: 1.000
# Batch: 16588	Train Loss: 0.0118	Accuracy: 1.000
# Batch: 16608	Train Loss: 0.0493	Accuracy: 1.000
# Batch: 16628	Train Loss: 0.1686	Accuracy: 1.000
# Batch: 16648	Train Loss: 0.0122	Accuracy: 1.000
# Batch: 16668	Train Loss: 0.2228	Accuracy: 1.000
# Batch: 16688	Train Loss: 0.8601	Accuracy: 0.750
# Batch: 16708	Train Loss: 0.0018	Accuracy: 1.000
# Batch: 16728	Train Loss: 0.1645	Accuracy: 1.000
# Batch: 16748	Train Loss: 0.7435	Accuracy: 0.500
# Batch: 16768	Train Loss: 0.0689	Accuracy: 1.000
# Batch: 16788	Train Loss: 0.1425	Accuracy: 1.000
# Batch: 16808	Train Loss: 0.2831	Accuracy: 1.000
# Batch: 16828	Train Loss: 0.1550	Accuracy: 1.000
# Batch: 16848	Train Loss: 0.0050	Accuracy: 1.000
# Batch: 16868	Train Loss: 0.0192	Accuracy: 1.000
# Batch: 16888	Train Loss: 0.0830	Accuracy: 1.000
# Batch: 16908	Train Loss: 0.5639	Accuracy: 0.750
# Batch: 16928	Train Loss: 0.0588	Accuracy: 1.000
# Batch: 16948	Train Loss: 0.2338	Accuracy: 1.000
# Batch: 16968	Train Loss: 0.1316	Accuracy: 1.000
# Batch: 16988	Train Loss: 0.0607	Accuracy: 1.000
# Batch: 17008	Train Loss: 0.3232	Accuracy: 0.750
# Epoch: 12
# Train Loss: 0.242232 Acc: 0.9248
# Elapsed 4717.68s, 362.90 s/epoch, 0.28 s/batch, ets 2540.29s
#
# Test set: Average loss: 1.5400, Accuracy: 877/1300 (67%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 17037	Train Loss: 0.0327	Accuracy: 1.000
# Batch: 17057	Train Loss: 0.1223	Accuracy: 1.000
# Batch: 17077	Train Loss: 0.0026	Accuracy: 1.000
# Batch: 17097	Train Loss: 0.0256	Accuracy: 1.000
# Batch: 17117	Train Loss: 0.0075	Accuracy: 1.000
# Batch: 17137	Train Loss: 0.0170	Accuracy: 1.000
# Batch: 17157	Train Loss: 0.0191	Accuracy: 1.000
# Batch: 17177	Train Loss: 0.0022	Accuracy: 1.000
# Batch: 17197	Train Loss: 0.5357	Accuracy: 0.750
# Batch: 17217	Train Loss: 0.1066	Accuracy: 1.000
# Batch: 17237	Train Loss: 0.0201	Accuracy: 1.000
# Batch: 17257	Train Loss: 0.0510	Accuracy: 1.000
# Batch: 17277	Train Loss: 0.0226	Accuracy: 1.000
# Batch: 17297	Train Loss: 0.0065	Accuracy: 1.000
# Batch: 17317	Train Loss: 0.9321	Accuracy: 0.750
# Batch: 17337	Train Loss: 0.0092	Accuracy: 1.000
# Batch: 17357	Train Loss: 0.0152	Accuracy: 1.000
# Batch: 17377	Train Loss: 0.0376	Accuracy: 1.000
# Batch: 17397	Train Loss: 0.0351	Accuracy: 1.000
# Batch: 17417	Train Loss: 0.0038	Accuracy: 1.000
# Batch: 17437	Train Loss: 0.0067	Accuracy: 1.000
# Batch: 17457	Train Loss: 0.0198	Accuracy: 1.000
# Batch: 17477	Train Loss: 0.0062	Accuracy: 1.000
# Batch: 17497	Train Loss: 0.0888	Accuracy: 1.000
# Batch: 17517	Train Loss: 0.0190	Accuracy: 1.000
# Batch: 17537	Train Loss: 1.9520	Accuracy: 0.750
# Batch: 17557	Train Loss: 0.0029	Accuracy: 1.000
# Batch: 17577	Train Loss: 0.0750	Accuracy: 1.000
# Batch: 17597	Train Loss: 0.0200	Accuracy: 1.000
# Batch: 17617	Train Loss: 0.0226	Accuracy: 1.000
# Batch: 17637	Train Loss: 0.3178	Accuracy: 1.000
# Batch: 17657	Train Loss: 0.1526	Accuracy: 1.000
# Batch: 17677	Train Loss: 0.3578	Accuracy: 1.000
# Batch: 17697	Train Loss: 0.0309	Accuracy: 1.000
# Batch: 17717	Train Loss: 0.0841	Accuracy: 1.000
# Batch: 17737	Train Loss: 0.0015	Accuracy: 1.000
# Batch: 17757	Train Loss: 0.0117	Accuracy: 1.000
# Batch: 17777	Train Loss: 0.3677	Accuracy: 0.750
# Batch: 17797	Train Loss: 0.0108	Accuracy: 1.000
# Batch: 17817	Train Loss: 0.4784	Accuracy: 0.750
# Batch: 17837	Train Loss: 0.4951	Accuracy: 0.750
# Batch: 17857	Train Loss: 0.9706	Accuracy: 0.750
# Batch: 17877	Train Loss: 0.0124	Accuracy: 1.000
# Batch: 17897	Train Loss: 0.0877	Accuracy: 1.000
# Batch: 17917	Train Loss: 0.0324	Accuracy: 1.000
# Batch: 17937	Train Loss: 0.1393	Accuracy: 1.000
# Batch: 17957	Train Loss: 0.0542	Accuracy: 1.000
# Batch: 17977	Train Loss: 1.0876	Accuracy: 0.500
# Batch: 17997	Train Loss: 0.0102	Accuracy: 1.000
# Batch: 18017	Train Loss: 0.0505	Accuracy: 1.000
# Batch: 18037	Train Loss: 0.1001	Accuracy: 1.000
# Batch: 18057	Train Loss: 0.2659	Accuracy: 0.750
# Batch: 18077	Train Loss: 0.0600	Accuracy: 1.000
# Batch: 18097	Train Loss: 0.1141	Accuracy: 1.000
# Batch: 18117	Train Loss: 0.0109	Accuracy: 1.000
# Batch: 18137	Train Loss: 0.3982	Accuracy: 0.750
# Batch: 18157	Train Loss: 0.0186	Accuracy: 1.000
# Batch: 18177	Train Loss: 0.4714	Accuracy: 0.750
# Batch: 18197	Train Loss: 0.5666	Accuracy: 0.750
# Batch: 18217	Train Loss: 0.2512	Accuracy: 1.000
# Batch: 18237	Train Loss: 0.0110	Accuracy: 1.000
# Batch: 18257	Train Loss: 0.0040	Accuracy: 1.000
# Batch: 18277	Train Loss: 1.3572	Accuracy: 0.750
# Batch: 18297	Train Loss: 0.0237	Accuracy: 1.000
# Batch: 18317	Train Loss: 0.0141	Accuracy: 1.000
# Epoch: 13
# Train Loss: 0.204995 Acc: 0.9408
# Elapsed 5084.24s, 363.16 s/epoch, 0.28 s/batch, ets 2178.96s
#
# Test set: Average loss: 1.4445, Accuracy: 897/1300 (69%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 18346	Train Loss: 0.0476	Accuracy: 1.000
# Batch: 18366	Train Loss: 0.0141	Accuracy: 1.000
# Batch: 18386	Train Loss: 0.0741	Accuracy: 1.000
# Batch: 18406	Train Loss: 0.0262	Accuracy: 1.000
# Batch: 18426	Train Loss: 0.0296	Accuracy: 1.000
# Batch: 18446	Train Loss: 0.9237	Accuracy: 0.750
# Batch: 18466	Train Loss: 0.0156	Accuracy: 1.000
# Batch: 18486	Train Loss: 0.0610	Accuracy: 1.000
# Batch: 18506	Train Loss: 0.0037	Accuracy: 1.000
# Batch: 18526	Train Loss: 0.0176	Accuracy: 1.000
# Batch: 18546	Train Loss: 0.0014	Accuracy: 1.000
# Batch: 18566	Train Loss: 0.3710	Accuracy: 0.750
# Batch: 18586	Train Loss: 0.0028	Accuracy: 1.000
# Batch: 18606	Train Loss: 0.1275	Accuracy: 1.000
# Batch: 18626	Train Loss: 0.1864	Accuracy: 1.000
# Batch: 18646	Train Loss: 0.1710	Accuracy: 1.000
# Batch: 18666	Train Loss: 0.1611	Accuracy: 1.000
# Batch: 18686	Train Loss: 0.3070	Accuracy: 0.750
# Batch: 18706	Train Loss: 0.0464	Accuracy: 1.000
# Batch: 18726	Train Loss: 0.0265	Accuracy: 1.000
# Batch: 18746	Train Loss: 0.0010	Accuracy: 1.000
# Batch: 18766	Train Loss: 0.0462	Accuracy: 1.000
# Batch: 18786	Train Loss: 0.0025	Accuracy: 1.000
# Batch: 18806	Train Loss: 0.0203	Accuracy: 1.000
# Batch: 18826	Train Loss: 0.0485	Accuracy: 1.000
# Batch: 18846	Train Loss: 0.0236	Accuracy: 1.000
# Batch: 18866	Train Loss: 0.2482	Accuracy: 0.750
# Batch: 18886	Train Loss: 0.2523	Accuracy: 1.000
# Batch: 18906	Train Loss: 0.2733	Accuracy: 1.000
# Batch: 18926	Train Loss: 0.4014	Accuracy: 0.750
# Batch: 18946	Train Loss: 0.2323	Accuracy: 1.000
# Batch: 18966	Train Loss: 0.0476	Accuracy: 1.000
# Batch: 18986	Train Loss: 0.0034	Accuracy: 1.000
# Batch: 19006	Train Loss: 0.0409	Accuracy: 1.000
# Batch: 19026	Train Loss: 0.0495	Accuracy: 1.000
# Batch: 19046	Train Loss: 0.2560	Accuracy: 0.750
# Batch: 19066	Train Loss: 0.0009	Accuracy: 1.000
# Batch: 19086	Train Loss: 1.0412	Accuracy: 0.750
# Batch: 19106	Train Loss: 0.2480	Accuracy: 1.000
# Batch: 19126	Train Loss: 0.0814	Accuracy: 1.000
# ...
# Batch: 19915	Train Loss: 0.0171	Accuracy: 1.000
# Batch: 19935	Train Loss: 0.0037	Accuracy: 1.000
# Batch: 19955	Train Loss: 0.0128	Accuracy: 1.000
# Batch: 19975	Train Loss: 0.0017	Accuracy: 1.000
# Batch: 19995	Train Loss: 0.0010	Accuracy: 1.000
# Batch: 20015	Train Loss: 0.9651	Accuracy: 0.750
# Batch: 20035	Train Loss: 0.0105	Accuracy: 1.000
# Batch: 20055	Train Loss: 0.0566	Accuracy: 1.000
# Batch: 20075	Train Loss: 0.0042	Accuracy: 1.000
# Batch: 20095	Train Loss: 0.0062	Accuracy: 1.000
# Batch: 20115	Train Loss: 0.0303	Accuracy: 1.000
# Batch: 20135	Train Loss: 0.0250	Accuracy: 1.000
# Batch: 20155	Train Loss: 0.1832	Accuracy: 1.000
# Batch: 20175	Train Loss: 0.0014	Accuracy: 1.000
# Batch: 20195	Train Loss: 0.0239	Accuracy: 1.000
# Batch: 20215	Train Loss: 0.0564	Accuracy: 1.000
# Batch: 20235	Train Loss: 0.0194	Accuracy: 1.000
# Batch: 20255	Train Loss: 0.0209	Accuracy: 1.000
# Batch: 20275	Train Loss: 0.0134	Accuracy: 1.000
# Batch: 20295	Train Loss: 0.0049	Accuracy: 1.000
# Batch: 20315	Train Loss: 0.0035	Accuracy: 1.000
# Batch: 20335	Train Loss: 0.2815	Accuracy: 1.000
# Batch: 20355	Train Loss: 0.0139	Accuracy: 1.000
# Batch: 20375	Train Loss: 0.0091	Accuracy: 1.000
# Batch: 20395	Train Loss: 0.0952	Accuracy: 1.000
# Batch: 20415	Train Loss: 0.5851	Accuracy: 0.750
# Batch: 20435	Train Loss: 0.1396	Accuracy: 1.000
# Batch: 20455	Train Loss: 0.0207	Accuracy: 1.000
# Batch: 20475	Train Loss: 0.0259	Accuracy: 1.000
# Batch: 20495	Train Loss: 0.0017	Accuracy: 1.000
# Batch: 20515	Train Loss: 0.0019	Accuracy: 1.000
# Batch: 20535	Train Loss: 0.3611	Accuracy: 1.000
# Batch: 20555	Train Loss: 0.0108	Accuracy: 1.000
# Batch: 20575	Train Loss: 0.3920	Accuracy: 1.000
# Batch: 20595	Train Loss: 0.0345	Accuracy: 1.000
# Batch: 20615	Train Loss: 0.0759	Accuracy: 1.000
# Batch: 20635	Train Loss: 0.0119	Accuracy: 1.000
# Batch: 20655	Train Loss: 0.9903	Accuracy: 0.750
# Batch: 20675	Train Loss: 0.0026	Accuracy: 1.000
# Batch: 20695	Train Loss: 0.0074	Accuracy: 1.000
# Batch: 20715	Train Loss: 0.3137	Accuracy: 1.000
# Batch: 20735	Train Loss: 1.3005	Accuracy: 0.500
# Batch: 20755	Train Loss: 0.5029	Accuracy: 0.750
# Batch: 20775	Train Loss: 0.1995	Accuracy: 1.000
# Batch: 20795	Train Loss: 0.4274	Accuracy: 0.750
# Batch: 20815	Train Loss: 0.0197	Accuracy: 1.000
# Batch: 20835	Train Loss: 0.0519	Accuracy: 1.000
# Batch: 20855	Train Loss: 0.3646	Accuracy: 0.750
# Batch: 20875	Train Loss: 2.3629	Accuracy: 0.750
# Batch: 20895	Train Loss: 1.7908	Accuracy: 0.750
# Batch: 20915	Train Loss: 0.0970	Accuracy: 1.000
# Batch: 20935	Train Loss: 0.1090	Accuracy: 1.000
# Epoch: 15
# Train Loss: 0.192544 Acc: 0.9439
# Elapsed 5817.44s, 363.59 s/epoch, 0.28 s/batch, ets 1454.36s
#
# Test set: Average loss: 1.2877, Accuracy: 906/1300 (70%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 20964	Train Loss: 0.0043	Accuracy: 1.000
# Batch: 20984	Train Loss: 0.1548	Accuracy: 1.000
# Batch: 21004	Train Loss: 0.0052	Accuracy: 1.000
# Batch: 21024	Train Loss: 0.2442	Accuracy: 0.750
# Batch: 21044	Train Loss: 0.0113	Accuracy: 1.000
# Batch: 21064	Train Loss: 0.0050	Accuracy: 1.000
# Batch: 21084	Train Loss: 0.0105	Accuracy: 1.000
# Batch: 21104	Train Loss: 0.0088	Accuracy: 1.000
# Batch: 21124	Train Loss: 0.0046	Accuracy: 1.000
# Batch: 21144	Train Loss: 0.0833	Accuracy: 1.000
# Batch: 21164	Train Loss: 0.0339	Accuracy: 1.000
# Batch: 21184	Train Loss: 0.9778	Accuracy: 0.750
# Batch: 21204	Train Loss: 0.0192	Accuracy: 1.000
# Batch: 21224	Train Loss: 0.1870	Accuracy: 0.750
# Batch: 21244	Train Loss: 0.0201	Accuracy: 1.000
# Batch: 21264	Train Loss: 0.0025	Accuracy: 1.000
# Batch: 21284	Train Loss: 0.0240	Accuracy: 1.000
# Batch: 21304	Train Loss: 0.1264	Accuracy: 1.000
# Batch: 21324	Train Loss: 0.1785	Accuracy: 1.000
# Batch: 21344	Train Loss: 0.0023	Accuracy: 1.000
# Batch: 21364	Train Loss: 0.5950	Accuracy: 0.750
# Batch: 21384	Train Loss: 0.0019	Accuracy: 1.000
# Batch: 21404	Train Loss: 0.2413	Accuracy: 1.000
# Batch: 21424	Train Loss: 0.0096	Accuracy: 1.000
# Batch: 21444	Train Loss: 0.0046	Accuracy: 1.000
# Batch: 21464	Train Loss: 0.3049	Accuracy: 1.000
# Batch: 21484	Train Loss: 0.0008	Accuracy: 1.000
# Batch: 21504	Train Loss: 0.0059	Accuracy: 1.000
# Batch: 21524	Train Loss: 0.0131	Accuracy: 1.000
# Batch: 21544	Train Loss: 0.1131	Accuracy: 1.000
# Batch: 21564	Train Loss: 0.0022	Accuracy: 1.000
# Batch: 21584	Train Loss: 0.1290	Accuracy: 1.000
# Batch: 21604	Train Loss: 0.0018	Accuracy: 1.000
# Batch: 21624	Train Loss: 0.5656	Accuracy: 0.750
# Batch: 21644	Train Loss: 0.1187	Accuracy: 1.000
# Batch: 21664	Train Loss: 0.3792	Accuracy: 0.750
# Batch: 21684	Train Loss: 0.0018	Accuracy: 1.000
# Batch: 21704	Train Loss: 0.4612	Accuracy: 0.500
# Batch: 21724	Train Loss: 0.6990	Accuracy: 0.750
# Batch: 21744	Train Loss: 0.0201	Accuracy: 1.000
# Batch: 21764	Train Loss: 0.0021	Accuracy: 1.000
# Batch: 21784	Train Loss: 0.0494	Accuracy: 1.000
# Batch: 21804	Train Loss: 0.0015	Accuracy: 1.000
# Batch: 21824	Train Loss: 0.0122	Accuracy: 1.000
# Batch: 21844	Train Loss: 0.0018	Accuracy: 1.000
# Batch: 21864	Train Loss: 0.0091	Accuracy: 1.000
# Batch: 21884	Train Loss: 0.0009	Accuracy: 1.000
# Batch: 21904	Train Loss: 0.0060	Accuracy: 1.000
# Batch: 21924	Train Loss: 0.0279	Accuracy: 1.000
# Batch: 21944	Train Loss: 0.0837	Accuracy: 1.000
# Batch: 21964	Train Loss: 0.0004	Accuracy: 1.000
# Batch: 21984	Train Loss: 0.0003	Accuracy: 1.000
# Batch: 22004	Train Loss: 0.0366	Accuracy: 1.000
# Batch: 22024	Train Loss: 0.0016	Accuracy: 1.000
# Batch: 22044	Train Loss: 0.0621	Accuracy: 1.000
# Batch: 22064	Train Loss: 0.1521	Accuracy: 1.000
# Batch: 22084	Train Loss: 0.0886	Accuracy: 1.000
# Batch: 22104	Train Loss: 0.0020	Accuracy: 1.000
# Batch: 22124	Train Loss: 1.4967	Accuracy: 0.750
# Batch: 22144	Train Loss: 0.4560	Accuracy: 0.750
# Batch: 22164	Train Loss: 0.1592	Accuracy: 1.000
# Batch: 22184	Train Loss: 0.0015	Accuracy: 1.000
# Batch: 22204	Train Loss: 0.0700	Accuracy: 1.000
# Batch: 22224	Train Loss: 0.0078	Accuracy: 1.000
# Batch: 22244	Train Loss: 0.0127	Accuracy: 1.000
# Epoch: 16
# Train Loss: 0.151944 Acc: 0.9557
# Elapsed 6184.81s, 363.81 s/epoch, 0.28 s/batch, ets 1091.44s
#
# Test set: Average loss: 1.5815, Accuracy: 882/1300 (68%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 22273	Train Loss: 0.0687	Accuracy: 1.000
# Batch: 22293	Train Loss: 0.0034	Accuracy: 1.000
# Batch: 22313	Train Loss: 0.0328	Accuracy: 1.000
# Batch: 22333	Train Loss: 0.3111	Accuracy: 0.750
# Batch: 22353	Train Loss: 0.0008	Accuracy: 1.000
# Batch: 22373	Train Loss: 0.0142	Accuracy: 1.000
# Batch: 22393	Train Loss: 0.5026	Accuracy: 0.750
# Batch: 22413	Train Loss: 0.1636	Accuracy: 1.000
# Batch: 22433	Train Loss: 0.0025	Accuracy: 1.000
# Batch: 22453	Train Loss: 0.7421	Accuracy: 0.750
# Batch: 22473	Train Loss: 0.0806	Accuracy: 1.000
# Batch: 22493	Train Loss: 0.1232	Accuracy: 1.000
# Batch: 22513	Train Loss: 0.0520	Accuracy: 1.000
# Batch: 22533	Train Loss: 0.0680	Accuracy: 1.000
# Batch: 22553	Train Loss: 0.0105	Accuracy: 1.000
# Batch: 22573	Train Loss: 0.0143	Accuracy: 1.000
# Batch: 22593	Train Loss: 0.1969	Accuracy: 1.000
# Batch: 22613	Train Loss: 0.0193	Accuracy: 1.000
# Batch: 22633	Train Loss: 0.1639	Accuracy: 1.000
# Batch: 22653	Train Loss: 0.0090	Accuracy: 1.000
# Batch: 22673	Train Loss: 0.0036	Accuracy: 1.000
# Batch: 22693	Train Loss: 0.0004	Accuracy: 1.000
# Batch: 22713	Train Loss: 0.1646	Accuracy: 1.000
# Batch: 22733	Train Loss: 0.0098	Accuracy: 1.000
# Batch: 22753	Train Loss: 0.0715	Accuracy: 1.000
# Batch: 22773	Train Loss: 0.1717	Accuracy: 1.000
# Batch: 22793	Train Loss: 0.5747	Accuracy: 0.750
# Batch: 22813	Train Loss: 0.0121	Accuracy: 1.000
# Batch: 22833	Train Loss: 0.0002	Accuracy: 1.000
# Batch: 22853	Train Loss: 0.0874	Accuracy: 1.000
# Batch: 22873	Train Loss: 0.0009	Accuracy: 1.000
# Batch: 22893	Train Loss: 0.4543	Accuracy: 0.750
# Batch: 22913	Train Loss: 0.0047	Accuracy: 1.000
# Batch: 22933	Train Loss: 0.0156	Accuracy: 1.000
# Batch: 22953	Train Loss: 0.0056	Accuracy: 1.000
# Batch: 22973	Train Loss: 0.0207	Accuracy: 1.000
# Batch: 22993	Train Loss: 0.0376	Accuracy: 1.000
# Batch: 23013	Train Loss: 0.3313	Accuracy: 1.000
# Batch: 23033	Train Loss: 0.0156	Accuracy: 1.000
# Batch: 23053	Train Loss: 0.0302	Accuracy: 1.000
# Batch: 23073	Train Loss: 0.0962	Accuracy: 1.000
# Batch: 23093	Train Loss: 1.2795	Accuracy: 0.500
# Batch: 23113	Train Loss: 0.0330	Accuracy: 1.000
# Batch: 23133	Train Loss: 0.0447	Accuracy: 1.000
# Batch: 23153	Train Loss: 0.0065	Accuracy: 1.000
# Batch: 23173	Train Loss: 0.0055	Accuracy: 1.000
# Batch: 23193	Train Loss: 0.0387	Accuracy: 1.000
# Batch: 23213	Train Loss: 0.0079	Accuracy: 1.000
# Batch: 23233	Train Loss: 0.0022	Accuracy: 1.000
# Batch: 23253	Train Loss: 0.0015	Accuracy: 1.000
# Batch: 23273	Train Loss: 0.0174	Accuracy: 1.000
# Batch: 23293	Train Loss: 0.0643	Accuracy: 1.000
# Batch: 23313	Train Loss: 0.0016	Accuracy: 1.000
# Batch: 23333	Train Loss: 0.3248	Accuracy: 0.750
# Batch: 23353	Train Loss: 0.6519	Accuracy: 0.750
# Batch: 23373	Train Loss: 0.0110	Accuracy: 1.000
# Batch: 23393	Train Loss: 0.0012	Accuracy: 1.000
# Batch: 23413	Train Loss: 0.0260	Accuracy: 1.000
# Batch: 23433	Train Loss: 0.0027	Accuracy: 1.000
# Batch: 23453	Train Loss: 0.0079	Accuracy: 1.000
# Batch: 23473	Train Loss: 0.1985	Accuracy: 1.000
# Batch: 23493	Train Loss: 0.0068	Accuracy: 1.000
# Batch: 23513	Train Loss: 0.0142	Accuracy: 1.000
# Batch: 23533	Train Loss: 0.4785	Accuracy: 0.750
# Batch: 23553	Train Loss: 0.0011	Accuracy: 1.000
# Epoch: 17
# Train Loss: 0.130036 Acc: 0.9626
# Elapsed 6551.98s, 364.00 s/epoch, 0.28 s/batch, ets 728.00s
#
# Test set: Average loss: 1.6016, Accuracy: 905/1300 (70%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 23582	Train Loss: 0.0041	Accuracy: 1.000
# Batch: 23602	Train Loss: 0.2655	Accuracy: 0.750
# Batch: 23622	Train Loss: 0.0009	Accuracy: 1.000
# Batch: 23642	Train Loss: 0.0028	Accuracy: 1.000
# Batch: 23662	Train Loss: 0.1480	Accuracy: 1.000
# Batch: 23682	Train Loss: 0.1046	Accuracy: 1.000
# Batch: 23702	Train Loss: 0.2260	Accuracy: 0.750
# Batch: 23722	Train Loss: 0.0625	Accuracy: 1.000
# Batch: 23742	Train Loss: 0.7650	Accuracy: 0.500
# Batch: 23762	Train Loss: 0.1342	Accuracy: 1.000
# Batch: 23782	Train Loss: 0.0060	Accuracy: 1.000
# Batch: 23802	Train Loss: 0.0277	Accuracy: 1.000
# Batch: 23822	Train Loss: 0.0084	Accuracy: 1.000
# Batch: 23842	Train Loss: 0.0003	Accuracy: 1.000
# Batch: 23862	Train Loss: 0.4328	Accuracy: 1.000
# Batch: 23882	Train Loss: 0.0088	Accuracy: 1.000
# Batch: 23902	Train Loss: 0.0127	Accuracy: 1.000
# Batch: 23922	Train Loss: 0.0431	Accuracy: 1.000
# Batch: 23942	Train Loss: 0.0062	Accuracy: 1.000
# Batch: 23962	Train Loss: 0.0053	Accuracy: 1.000
# Batch: 23982	Train Loss: 0.0534	Accuracy: 1.000
# Batch: 24002	Train Loss: 0.1122	Accuracy: 1.000
# Batch: 24022	Train Loss: 0.0013	Accuracy: 1.000
# Batch: 24042	Train Loss: 0.4376	Accuracy: 0.750
# Batch: 24062	Train Loss: 0.0196	Accuracy: 1.000
# Batch: 24082	Train Loss: 0.2613	Accuracy: 1.000
# Batch: 24102	Train Loss: 0.0037	Accuracy: 1.000
# Batch: 24122	Train Loss: 0.9986	Accuracy: 0.750
# Batch: 24142	Train Loss: 0.0050	Accuracy: 1.000
# Batch: 24162	Train Loss: 0.0510	Accuracy: 1.000
# Batch: 24182	Train Loss: 0.0941	Accuracy: 1.000
# Batch: 24202	Train Loss: 0.0023	Accuracy: 1.000
# Batch: 24222	Train Loss: 0.0785	Accuracy: 1.000
# Batch: 24242	Train Loss: 0.1385	Accuracy: 1.000
# Batch: 24262	Train Loss: 0.0189	Accuracy: 1.000
# Batch: 24282	Train Loss: 0.0203	Accuracy: 1.000
# Batch: 24302	Train Loss: 0.5230	Accuracy: 0.750
# Batch: 24322	Train Loss: 0.0032	Accuracy: 1.000
# Batch: 24342	Train Loss: 0.0542	Accuracy: 1.000
# Batch: 24362	Train Loss: 2.9867	Accuracy: 0.500
# Batch: 24382	Train Loss: 0.0330	Accuracy: 1.000
# Batch: 24402	Train Loss: 0.0027	Accuracy: 1.000
# Batch: 24422	Train Loss: 0.0183	Accuracy: 1.000
# Batch: 24442	Train Loss: 0.0466	Accuracy: 1.000
# Batch: 24462	Train Loss: 0.0083	Accuracy: 1.000
# Batch: 24482	Train Loss: 0.0082	Accuracy: 1.000
# Batch: 24502	Train Loss: 0.0096	Accuracy: 1.000
# Batch: 24522	Train Loss: 0.0067	Accuracy: 1.000
# Batch: 24542	Train Loss: 0.0019	Accuracy: 1.000
# Batch: 24562	Train Loss: 0.0017	Accuracy: 1.000
# Batch: 24582	Train Loss: 1.5336	Accuracy: 0.500
# Batch: 24602	Train Loss: 0.0039	Accuracy: 1.000
# Batch: 24622	Train Loss: 0.0070	Accuracy: 1.000
# Batch: 24642	Train Loss: 0.0426	Accuracy: 1.000
# Batch: 24662	Train Loss: 0.0580	Accuracy: 1.000
# Batch: 24682	Train Loss: 0.0427	Accuracy: 1.000
# Batch: 24702	Train Loss: 0.0190	Accuracy: 1.000
# Batch: 24722	Train Loss: 0.0045	Accuracy: 1.000
# Batch: 24742	Train Loss: 1.2365	Accuracy: 0.750
# Batch: 24762	Train Loss: 0.1811	Accuracy: 1.000
# Batch: 24782	Train Loss: 1.1319	Accuracy: 0.750
# Batch: 24802	Train Loss: 0.0386	Accuracy: 1.000
# Batch: 24822	Train Loss: 0.0508	Accuracy: 1.000
# Batch: 24842	Train Loss: 0.0170	Accuracy: 1.000
# Batch: 24862	Train Loss: 0.6932	Accuracy: 0.750
# Epoch: 18
# Train Loss: 0.144647 Acc: 0.9586
# Elapsed 6921.59s, 364.29 s/epoch, 0.28 s/batch, ets 364.29s
#
# Test set: Average loss: 1.4504, Accuracy: 895/1300 (69%)
#
# Bad Epochs:1
# last LR = [0.001]
# Batch: 24891	Train Loss: 0.0043	Accuracy: 1.000
# Batch: 24911	Train Loss: 1.6658	Accuracy: 0.750
# Batch: 24931	Train Loss: 0.4124	Accuracy: 0.750
# Batch: 24951	Train Loss: 0.1312	Accuracy: 1.000
# Batch: 24971	Train Loss: 0.0246	Accuracy: 1.000
# Batch: 24991	Train Loss: 0.0074	Accuracy: 1.000
# Batch: 25011	Train Loss: 0.0004	Accuracy: 1.000
# Batch: 25031	Train Loss: 0.0060	Accuracy: 1.000
# Batch: 25051	Train Loss: 0.0718	Accuracy: 1.000
# Batch: 25071	Train Loss: 0.0171	Accuracy: 1.000
# Batch: 25091	Train Loss: 0.0466	Accuracy: 1.000
# Batch: 25111	Train Loss: 0.1160	Accuracy: 1.000
# Batch: 25131	Train Loss: 0.0429	Accuracy: 1.000
# Batch: 25151	Train Loss: 0.0509	Accuracy: 1.000
# Batch: 25171	Train Loss: 0.5909	Accuracy: 0.750
# Batch: 25191	Train Loss: 0.0004	Accuracy: 1.000
# Batch: 25211	Train Loss: 0.1048	Accuracy: 1.000
# Batch: 25231	Train Loss: 0.1180	Accuracy: 1.000
# Batch: 25251	Train Loss: 1.1214	Accuracy: 0.750
# Batch: 25271	Train Loss: 0.0077	Accuracy: 1.000
# Batch: 25291	Train Loss: 0.0035	Accuracy: 1.000
# Batch: 25311	Train Loss: 0.0010	Accuracy: 1.000
# Batch: 25331	Train Loss: 0.2525	Accuracy: 1.000
# Batch: 25351	Train Loss: 0.0065	Accuracy: 1.000
# Batch: 25371	Train Loss: 0.0429	Accuracy: 1.000
# Batch: 25391	Train Loss: 0.1231	Accuracy: 1.000
# Batch: 25411	Train Loss: 0.0958	Accuracy: 1.000
# Batch: 25431	Train Loss: 0.0131	Accuracy: 1.000
# Batch: 25451	Train Loss: 0.5515	Accuracy: 0.750
# Batch: 25471	Train Loss: 0.1144	Accuracy: 1.000
# Batch: 25491	Train Loss: 0.0096	Accuracy: 1.000
# Batch: 25511	Train Loss: 0.1700	Accuracy: 1.000
# Batch: 25531	Train Loss: 0.0661	Accuracy: 1.000
# Batch: 25551	Train Loss: 0.0116	Accuracy: 1.000
# Batch: 25571	Train Loss: 0.0610	Accuracy: 1.000
# Batch: 25591	Train Loss: 0.4732	Accuracy: 0.750
# Batch: 25611	Train Loss: 0.0331	Accuracy: 1.000
# Batch: 25631	Train Loss: 0.0060	Accuracy: 1.000
# Batch: 25651	Train Loss: 0.0051	Accuracy: 1.000
# Batch: 25671	Train Loss: 0.0002	Accuracy: 1.000
# Batch: 25691	Train Loss: 0.0157	Accuracy: 1.000
# Batch: 25711	Train Loss: 0.2550	Accuracy: 1.000
# Batch: 25731	Train Loss: 0.0200	Accuracy: 1.000
# Batch: 25751	Train Loss: 0.0114	Accuracy: 1.000
# Batch: 25771	Train Loss: 0.0004	Accuracy: 1.000
# Batch: 25791	Train Loss: 0.0001	Accuracy: 1.000
# Batch: 25811	Train Loss: 0.1838	Accuracy: 1.000
# Batch: 25831	Train Loss: 0.0064	Accuracy: 1.000
# Batch: 25851	Train Loss: 0.0175	Accuracy: 1.000
# Batch: 25871	Train Loss: 0.0365	Accuracy: 1.000
# Batch: 25891	Train Loss: 0.8794	Accuracy: 0.750
# Batch: 25911	Train Loss: 0.3876	Accuracy: 0.750
# Batch: 25931	Train Loss: 0.0041	Accuracy: 1.000
# Batch: 25951	Train Loss: 0.0603	Accuracy: 1.000
# Batch: 25971	Train Loss: 0.0062	Accuracy: 1.000
# Batch: 25991	Train Loss: 0.0062	Accuracy: 1.000
# Batch: 26011	Train Loss: 0.0215	Accuracy: 1.000
# Batch: 26031	Train Loss: 0.1641	Accuracy: 1.000
# Batch: 26051	Train Loss: 0.0011	Accuracy: 1.000
# Batch: 26071	Train Loss: 0.0118	Accuracy: 1.000
# Batch: 26091	Train Loss: 0.1050	Accuracy: 1.000
# Batch: 26111	Train Loss: 0.0101	Accuracy: 1.000
# Batch: 26131	Train Loss: 0.0043	Accuracy: 1.000
# Batch: 26151	Train Loss: 0.2280	Accuracy: 1.000
# Batch: 26171	Train Loss: 1.0869	Accuracy: 0.750
# Epoch: 19
# Train Loss: 0.139377 Acc: 0.9601
# Elapsed 7291.40s, 364.57 s/epoch, 0.28 s/batch, ets 0.00s
#
# Test set: Average loss: 1.5441, Accuracy: 893/1300 (69%)
#
# Bad Epochs:2
# last LR = [0.001]
# Total time: 7331.46, Best Loss: 1.102

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')
