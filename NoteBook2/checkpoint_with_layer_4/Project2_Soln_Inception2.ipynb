# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import os 
import random
import time
from dataclasses import dataclass

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets, models
from torchvision.transforms import functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.tensorboard import SummaryWriter


from matplotlib import pyplot as plt
from PIL import Image

# %%
 data_root = './'
#data_root = '/kaggle/input/pytorch-opencv-course-classification/'

image_root = os.path.join(data_root, 'images/images')
data_csv_path = os.path.join(data_root, 'train.csv')
test_csv_path = os.path.join(data_root, 'test.csv')
train_csv='train.csv'
val_csv='validation.csv'
valid_fraction=0.2

# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load in 

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the "../input/" directory.
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # Any results you write to the current directory are saved as output.

# %%
def split_train_validation(csv_path, valid_fraction=0.2, train_csv='train.csv', val_csv='validation.csv', print_info=True):
    """
    It takes .csv file that have two column: ['id', 'class'] and create two .csv file for traing and validation. Return a list of classes
    Parms:
    csv_path (str): path of data csv
    valid_fraction (float): fraction for validation data (0 to 1). 
    train_csv (str): train data file path
    val_csv (str): validation data file path
    print_info (boolean): True for print data overview else False
    
    return (list): List of classes 
    """
    data_df = pd.read_csv(csv_path)

    classes = list(data_df['class'].unique())
    
    if print_info:
        print('There is {} classes and its names are the following:\n{}\n'.format(len(classes), classes))
        
    f_val = open(val_csv, 'w')
    f_train = open(train_csv, 'w')
    
    f_val.write('{},{}\n'.format('id', 'class'))
    f_train.write('{},{}\n'.format('id', 'class'))
        
    for i, cls in enumerate(classes):
        cls_data = data_df[data_df['class']==cls]['id'].to_list()
        val_count = int(len(cls_data) * valid_fraction)
        val_data = random.sample(cls_data, k=val_count)
        
        if print_info:
            print('{}.\tCLASS NAME: {}\tTRAIN COUNT: {}\tVALIDATION COUNT: {}'.format(i, cls, len(cls_data)-len(val_data), len(val_data)))
        for img_id in cls_data:
            if img_id in val_data:
                f_val.write('{},{}\n'.format(img_id, cls))
            else:
                f_train.write('{},{}\n'.format(img_id, cls))
    f_val.close()
    f_train.close()
    
    return classes

# %%
class_names = split_train_validation(csv_path=data_csv_path, 
                                     valid_fraction=valid_fraction, 
                                     train_csv=train_csv, 
                                     val_csv=val_csv, 
                                     print_info=True)
# Out:
# There is 13 classes and its names are the following:
# ['githeri', 'ugali', 'kachumbari', 'matoke', 'sukumawiki', 'bhaji', 'mandazi', 'kukuchoma', 'nyamachoma', 'pilau', 'chapati', 'masalachips', 'mukimo']
#
# 0.	CLASS NAME: githeri	TRAIN COUNT: 308	VALIDATION COUNT: 76
# 1.	CLASS NAME: ugali	TRAIN COUNT: 403	VALIDATION COUNT: 100
# 2.	CLASS NAME: kachumbari	TRAIN COUNT: 317	VALIDATION COUNT: 79
# 3.	CLASS NAME: matoke	TRAIN COUNT: 310	VALIDATION COUNT: 77
# 4.	CLASS NAME: sukumawiki	TRAIN COUNT: 258	VALIDATION COUNT: 64
# 5.	CLASS NAME: bhaji	TRAIN COUNT: 405	VALIDATION COUNT: 101
# 6.	CLASS NAME: mandazi	TRAIN COUNT: 397	VALIDATION COUNT: 99
# 7.	CLASS NAME: kukuchoma	TRAIN COUNT: 112	VALIDATION COUNT: 27
# 8.	CLASS NAME: nyamachoma	TRAIN COUNT: 503	VALIDATION COUNT: 125
# 9.	CLASS NAME: pilau	TRAIN COUNT: 212	VALIDATION COUNT: 52
# 10.	CLASS NAME: chapati	TRAIN COUNT: 552	VALIDATION COUNT: 138
# 11.	CLASS NAME: masalachips	TRAIN COUNT: 281	VALIDATION COUNT: 70
# 12.	CLASS NAME: mukimo	TRAIN COUNT: 136	VALIDATION COUNT: 34

# %%
df = pd.read_csv(val_csv)
print(df.head())
print(df.tail())
# Out:
#                      id    class
# 0   4222441716327528413  githeri
# 1   4939671543203955477  githeri
# 2  11046471567567707496  githeri
# 3  10526888018530471027  githeri
# 4    255658809211593677  githeri
#                         id   class
# 1037  17007731591344275740  mukimo
# 1038   6875531799312516842  mukimo
# 1039   8458813849280411843  mukimo
# 1040  13565196064532595911  mukimo
# 1041   7039809651508355803  mukimo

# %%
class KenyanFood13Dataset(Dataset):
    """
    This custom dataset class take root image directory and csv path
    and return dataset
    """
    
    def __init__(self, image_root, csv_path, classes, image_shape=None, transform=None):
        
        """
        init method of the class.
        
         Parameters:
         
         image_root (string): path of image directory.
         
         csv_path (string): path of train, val or test csv
         
         classes (list): a list of classes 
         
         image_shape (int or tuple or list): [optional] (height, width) int or tuple or list. Defaut is None. 
                                             It is not None image will resize to the given shape.
                                 
         transform (method): method that will take PIL image and transforms it.
         
        """
        
        self.image_root = image_root
        
        data_df = pd.read_csv(csv_path)
        
        self.classes = classes
        
        
        # set image_resize attribute
        if image_shape is not None:
            if isinstance(image_shape, int):
                self.image_shape = (image_shape, image_shape)
            
            elif isinstance(image_shape, tuple) or isinstance(image_shape, list):
                assert len(image_shape) == 1 or len(image_shape) == 2, 'Invalid image_shape tuple size'
                if len(image_shape) == 1:
                    self.image_shape = (image_shape[0], image_shape[0])
                else:
                    self.image_shape = image_shape
            else:
                raise NotImplementedError
        else:
            self.image_shape = image_shape
            
        # set transform attribute
        self.transform = transform
                
        
        # initialize the data dictionary
        self.data_dict = {
            'image_path': [],
            'label': []
        }
        
        cols = data_df.columns
        for i in range(len(data_df)):
            img_id = data_df['id'][i]
            image_path = os.path.join(image_root, '{}.jpg'.format(img_id))
            
            # making compatible with test data also
            if 'class' in cols:
                cls = data_df['class'][i]
                cls_idx = self.classes.index(cls)
                assert 0 <= cls_idx <= 12
            else: 
                cls_idx = None
                
            self.data_dict['image_path'].append(image_path)
            self.data_dict['label'].append(cls_idx)
        
                    
    def __len__(self):
        """
        return length of the dataset
        """
        return len(self.data_dict['label'])
    
    
    def __getitem__(self, idx):
        """
        For given index, return images with resize and preprocessing.
        """
        
        image = Image.open(self.data_dict['image_path'][idx]).convert("RGB")
        
        if self.image_shape is not None:
            height, width = self.image_shape
            image = F.resize(image, self.image_shape)
            
        if self.transform is not None:
            image = self.transform(image)
            
        target = self.data_dict['label'][idx]
        
        return image, target            
                
        
    def classes(self, label):
        """
        Get class names
        """
        return self.classes
    
    def class_to_index(self, class_name):
        """
        Get index of the class
        """
        return self.classes.index(class_name)
    
    def index_to_class(self, class_index):
        """
        Get class name for the class index
        """
        
        return self.classes[class_index]

# %%
val_dataset =  KenyanFood13Dataset(image_root=image_root, csv_path=val_csv, classes=class_names, image_shape=(256, 400))

print('Length of the dataset: {}'.format(len(val_dataset)))

img, trgt = val_dataset[300]

print('Label: {}, Class name: {}'.format(trgt, val_dataset.index_to_class(trgt)))
plt.imshow(img)
plt.show()
# Out:
# Length of the dataset: 1042
# Label: 3, Class name: matoke

# %%
preprocess = transforms.Compose([
    transforms.Resize(299),
    transforms.CenterCrop(299),
    transforms.ToTensor()
    ])

val_dataset =  KenyanFood13Dataset(image_root=image_root, csv_path=val_csv, classes=class_names, image_shape=None, transform=preprocess)

# dataloader with dataset
val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=15,
    shuffle=True,
    num_workers=2
    )


# Plot few images
plt.rcParams["figure.figsize"] = (15, 9)
plt.figure
for images, labels in val_loader:
    for i in range(len(labels)):
        plt.subplot(3, 5, i+1)
        img = F.to_pil_image(images[i])
        plt.imshow(img)
        plt.gca().set_title('{}: {}'.format(val_dataset.index_to_class(labels[i]), labels[i]))
    plt.show()
    break

# %%
def image_common_transforms(mean, std):
    
    preprocess = transforms.Compose([
        transforms.Resize(299,299),
        transforms.CenterCrop(299),
        transforms.ToTensor()
        ])
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %%
def data_augmentation_preprocess(mean, std):
    
    initail_transoform = transforms.RandomChoice([
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(90),
        ])
    
    preprocess = transforms.Compose([
        transforms.RandomAffine(degrees=120, translate=(0.2, 0.2), scale=(0.8, 1.2), 
                                shear=(-20, 20, -20, 20), resample=False, fillcolor=(0, 0,0)),
        transforms.RandomErasing(p=0.2, scale=(0.02, 0.2), ratio=(0.3, 3.3), 
                                 value='random', inplace=False),
        transforms.Resize(299,299),
        transforms.RandomCrop(299),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0, hue=0),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
        ])
                
    aug_transforms = transforms.Compose([
        initail_transoform,
        transforms.RandomGrayscale(p=0.1),
        preprocess
        ])
    
    return aug_transforms

# %%
def data_loader(image_root, csv_path, classes, transform, batch_size=4, shuffle=False, num_workers=2):
    dataset =  KenyanFood13Dataset(image_root, csv_path, classes, transform=preprocess)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %%
def get_mean_std():
    
    mean = [0.485, 0.456, 0.406] 
    std = [0.229, 0.224, 0.225]
    
    return mean, std

# %%
def get_data(batch_size, num_workers=4, data_augmentation=True):
           
    mean, std = get_mean_std()
    
    common_transforms = image_common_transforms(mean, std)
        
   
    # if data_augmentation is true 
    # data augmentation implementation
    if data_augmentation:    
        train_transforms = data_augmentation_preprocess(mean, std)
    # else do common transforms
    else:
        train_transforms = common_transforms
        
        
    # train dataloader
    train_loader = data_loader(image_root, 
                               train_csv, 
                               class_names, 
                               train_transforms, 
                               batch_size=batch_size, 
                               shuffle=True, 
                               num_workers=num_workers)
    
    # test dataloader
    test_loader = data_loader(image_root,
                              val_csv,
                              class_names,
                              common_transforms, 
                              batch_size=batch_size, 
                              shuffle=False, 
                              num_workers=num_workers)
    
    
    return train_loader, test_loader

# %%
# %load_ext tensorboard
# # %reload_ext tensorboard

# %tensorboard --logdir logs/resnet18

# %% [markdown]
# ## <font style="color:green">System Configuration</font>

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ## <font style="color:green">Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 4 
    epochs_count: int = 20 
    init_learning_rate: float = 0.001  # initial learning rate for lr scheduler
    decay_rate: float = 0.1  
    log_interval: int = 20  
    test_interval: int = 1  
    num_workers: int = 16 
    device: str = 'cuda'

# %% [markdown]
# ## <font style="color:green">System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:green">Training Function</font>
#
# We are familiar with the training pipeline used in PyTorch.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int, tb_writer: SummaryWriter
) -> None:
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is mandatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = nn.functional.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = nn.functional.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])

        if batch_idx % train_config.log_interval == 0 and batch_idx > 0:
            
            total_batch = epoch_idx * len(train_loader.dataset)/train_config.batch_size + batch_idx
            tb_writer.add_scalar('Loss/train-batch', loss.item(), total_batch)
            tb_writer.add_scalar('Accuracy/train-batch', acc, total_batch)
            print('Batch: {0}\tTrain Loss: {1:.4f}\tAccuracy: {2:.3f}'.format(int(total_batch), loss.item(), acc))
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:green">Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader
) -> float:
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        output = model(data)
        # add loss for each mini batch
        test_loss += nn.functional.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = nn.functional.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='final_model.pt'):
    
    train_config = TrainingConfiguration()
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device[:4] == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device[:4] == 'cuda':
        model.to(device)
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='final_model.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:green">Main Function for Training and Validation</font>
#
# In this section of code, we use the configuration parameters defined above and start the training. Here are the important actions being taken in the code below:
#
# 1. Set up system parameters like CPU/GPU, number of threads etc
# 1. Load the data using dataloaders
# 1. For each epoch, call train function, and for every test interval, call validation function.
# 1. Do `scheduler.step()` to update learning rate for next epoch.
# 1. Set up variables to track loss and accuracy and start training.

# %%
def main(model, optimizer, tb_writer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=False, model_name='final_model1.pt'):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = training_configuration.device
    else:
        device = "cpu"
        batch_size_to_set = 4
        num_workers_to_set = 2

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, init_val_accuracy*100))
    
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch, tb_writer)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])
        
        # add scalar (loss/accuracy) to tensorboard
        tb_writer.add_scalar('Loss/Train',train_loss, epoch)
        tb_writer.add_scalar('Accuracy/Train', train_acc, epoch)

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )
        
        # add time metadata to tensorboard
        tb_writer.add_scalar('Time/elapsed_time', elapsed_time, epoch)
        tb_writer.add_scalar('Time/speed_epoch', speed_epoch, epoch)
        tb_writer.add_scalar('Time/speed_batch', speed_batch, epoch)
        tb_writer.add_scalar('Time/eta', eta, epoch)
        

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            # add scalar (loss/accuracy) to tensorboard
            tb_writer.add_scalar('Loss/Validation', current_loss, epoch)
            tb_writer.add_scalar('Accuracy/Validation', current_accuracy, epoch)
            
            # add scalars (loss/accuracy) to tensorboard
            tb_writer.add_scalars('Loss/train-val', {'train': train_loss, 
                                           'validation': current_loss}, epoch)
            tb_writer.add_scalars('Accuracy/train-val', {'train': train_acc, 
                                               'validation': current_accuracy}, epoch)
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device, model_file_name=model_name)
                
        
        # scheduler step/ update learning rate
        # scheduler step/ update learning rate
        if scheduler is not None:
            if isinstance(scheduler, lr_scheduler.ReduceLROnPlateau):
                scheduler.step(train_loss)
                print("Bad Epochs:{}".format(scheduler.num_bad_epochs))
                print("last LR = {}".format(scheduler._last_lr))
            else:
                scheduler.step()
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:green">Optimizer and Scheduler</font>
#
# Let's write optimizer and scheduler as a method because we have to use it in all training experiments.

# %%
def get_optimizer_and_scheduler(model):
    train_config = TrainingConfiguration()

    init_learning_rate = train_config.init_learning_rate

    # optimizer
    optimizer = optim.SGD(
        model.parameters(),
        lr = init_learning_rate,
        momentum = 0.9
    )
    
    factor = 0.5  # reduce by factor 0.5
    patience = 2  # epochs
    verbose = True
    
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, factor=factor, patience=patience, verbose=verbose)
    
    return optimizer, scheduler

# %% [markdown]
# # <font style="color:blue">ResNet Model</font>
# We will load the resnet18 model with its pretrained weights.
#
# The layers are configured such that if you pass the transfer_learning flag, it just replaces the last layers of the network. Otherwise, it will retrain all layers, but with the pretrained weights, not from scratch.

# %%
# def pretrained_resnet18(transfer_learning=True, num_class=3):
#     resnet = models.resnet18(pretrained=True)
    
#     if transfer_learning:
#         for param in resnet.parameters():
#             param.requires_grad = False
            
#     last_layer_in = resnet.fc.in_features
#     resnet.fc = nn.Linear(last_layer_in, num_class)
    
#     return resnet

# def pretrained_inception_v3(transfer_learning=True, num_class=3):
#     inception_v3 = models.inception_v3(pretrained=True)
    
#     if transfer_learning:
#         for param in inception_v3.parameters():

#             param.requires_grad = False
            
#     last_layer_in = inception_v3.fc.in_features
#     inception_v3.fc = nn.Linear(last_layer_in, num_class)
    
#     return inception_v3



def pretrained_inception_v3(transfer_learning=True, num_class=3):
  inception_v3 = models.inception_v3(pretrained=True)

  if transfer_learning:
    for param in inception_v3.parameters():
      param.required_grad = False

  last_layer_in = inception_v3.fc.in_features
  inception_v3.fc = nn.Linear(last_layer_in,num_class)

  return inception_v3

# %%
# def inception_v3(feature_extract=True, num_class=13):
#     model = models.inception_v3(pretrained=True)

    
#     if feature_extract:
#         for param in model.parameters():
#             param.requires_grad = False
            
# #         for param in model.layer3.parameters():
# #             param.requires_grad = True
            
#         for param in model.Mixed_7c.parameters():
#             param.requires_grad = True
            
            
    

                              
#     last_layer_in = model.fc.in_features
#     model.fc = nn.Linear(last_layer_in, num_class)
    
#     return model

#####################################################################
def inception_v3(feature_extract= True, num_class=13):
  model =models.inception_v3(pretrained=True,aux_logits=False)

  if feature_extract:
    for param in model.parameters():
      param.requires_grad = False


    for param in model.Mixed_7c.parameters():
      
      param.requires_grad=True
      


    # for param in model.parameters():
    #   param.aux_logits = False




    last_layer_in = model.fc.in_features

    model.fc = nn.Linear(last_layer_in , num_class)


  return model


################################################
# def inception_v3(feature_extract=True, num_class=13):
#     model = models.inception_v3(pretrained=True)

    
#     if feature_extract:
#         for param in model.parameters():

#             param.requires_grad = False

#         for param in model.parameters():
#           param.aux_logits = False



            
            
# #         for param in model.layer3.parameters():
# #             param.requires_grad = True
            
#         # for param in model.Mixed_7c.parameters():
#         #     param.requires_grad = True
            
            
    

                              
#     last_layer_in = model.fc.in_features
#     model.fc = nn.Linear(last_layer_in, num_class)
    
#     return model









# def inception_v3(pretrained=False, progress=True, **kwargs):
#     r"""Inception v3 model architecture from
#     `"Rethinking the Inception Architecture for Computer Vision" <http://arxiv.org/abs/1512.00567>`_.
#     .. note::
#         **Important**: In contrast to the other models the inception_v3 expects tensors with a size of
#         N x 3 x 299 x 299, so ensure your images are sized accordingly.
#     Args:
#         pretrained (bool): If True, returns a model pre-trained on ImageNet
#         progress (bool): If True, displays a progress bar of the download to stderr
#         aux_logits (bool): If True, add an auxiliary branch that can improve training.
#             Default: *True*
#         transform_input (bool): If True, preprocesses the input according to the method with which it
#             was trained on ImageNet. Default: *False*
#     """
#     if pretrained:
#         if 'transform_input' not in kwargs:
#             kwargs['transform_input'] = True
#         if 'aux_logits' in kwargs:
#             original_aux_logits = kwargs['aux_logits']
#             kwargs['aux_logits'] = True
#         else:
#             original_aux_logits = True
#         model = Inception3(**kwargs)
#         state_dict = load_state_dict_from_url(model_urls['inception_v3_google'],
#                                               progress=progress)
#         model.load_state_dict(state_dict)
#         if not original_aux_logits:
#             model.aux_logits = False
#             del model.AuxLogits
#         return model

#     return Inception3(**kwargs)

# %%
def resnext50_32x4d(transfer_learning=True, num_class=13):
    model = models.resnext50_32x4d(pretrained=True)
    
    if transfer_learning:
        for param in model.parameters():
          
            param.requires_grad = False
            

            
        for param in model.layer4.parameters():
            param.requires_grad = True
            
            
    

                              
    last_layer_in = model.fc.in_features
    model.fc = nn.Linear(last_layer_in, num_class)
    
    return model

# %%
class PreTrainedModel(nn.Module):
    def __init__(self, model_name, freeze_layers, num_class):
        super().__init__()

        # convolution layers
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )
        
        mod = getattr(models, model_name)(pretrained=True)
        
        self.features = mod.features
        
        for name, param in self.features.named_parameters():
            
            if int(name.split('.')[0]) == freeze_layers:
                break
                
            if param.requires_grad:
                param.requires_grad = False
                
        self.avgpool = mod.avgpool
            
        
        # Fully connected layers
        self.classifier = nn.Sequential(
            
            nn.Linear(in_features=25088, out_features=4096), 
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            
            nn.Linear(in_features=4096, out_features=1024), 
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            
            nn.Linear(in_features=1024, out_features=num_class)
        )

    def forward(self, x):
        x = self.features(x)
        
        x = self.avgpool(x)
        
        x = x.view(x.size()[0], -1)
        
        x = self.classifier(x)
        return x

# %% [markdown]
# # <font style="color:blue">Transfer Learning</font>

# %%
model_name = 'inception_v3_with_layers'

freeze_layers = 20

num_class = len(class_names)

#model = PreTrainedModel(model_name, freeze_layers, num_class)
#model = resnext50_32x4d()
model = inception_v3()
#model = torch.hub.load('pytorch/vision:v0.5.0', 'inception_v3', pretrained=True,aux_logits=False,feature_extracting = True,requires_grad=False)
 
#model=Inception_v3(.../,weights='imagenet',include_top=False)


print(model)
# get optimizer and scheduler
optimizer, scheduler = get_optimizer_and_scheduler(model)

# Tensorboard summary writer
logs = 'pretrained2/{}_{}'.format(model_name, freeze_layers)
transfer_learning_sw = SummaryWriter(logs)  

model_name = '{}_{}.pt'.format(model_name, freeze_layers)
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/checkpoints/inception_v3_google-1a9a5a14.pth
# HBox(children=(IntProgress(value=0, max=108857766), HTML(value='')))
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc): Linear(in_features=2048, out_features=13, bias=True)
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, 
                                                       optimizer,
                                                       transfer_learning_sw,
                                                       scheduler,
                                                       data_augmentation=True,
                                                       model_name=model_name)
transfer_learning_sw.close()
# Out:
# Test set: Average loss: 2.5996, Accuracy: 63/1042 (6%)
#
# Initial Test Loss : 2.599594,
# Initial Test Accuracy : 6.046%
#
# Batch: 20	Train Loss: 2.5719	Accuracy: 0.000
# Batch: 40	Train Loss: 2.3513	Accuracy: 0.000
# Batch: 60	Train Loss: 2.2524	Accuracy: 0.250
# Batch: 80	Train Loss: 2.1184	Accuracy: 0.500
# Batch: 100	Train Loss: 2.6172	Accuracy: 0.000
# Batch: 120	Train Loss: 2.3457	Accuracy: 0.500
# Batch: 140	Train Loss: 1.8766	Accuracy: 0.500
# Batch: 160	Train Loss: 1.4208	Accuracy: 0.500
# Batch: 180	Train Loss: 2.8313	Accuracy: 0.000
# Batch: 200	Train Loss: 3.0986	Accuracy: 0.000
# Batch: 220	Train Loss: 1.2311	Accuracy: 0.500
# Batch: 240	Train Loss: 2.6831	Accuracy: 0.000
# Batch: 260	Train Loss: 3.0098	Accuracy: 0.000
# Batch: 280	Train Loss: 2.2922	Accuracy: 0.500
# Batch: 300	Train Loss: 2.6977	Accuracy: 0.500
# Batch: 320	Train Loss: 1.8784	Accuracy: 0.500
# Batch: 340	Train Loss: 1.9053	Accuracy: 0.750
# Batch: 360	Train Loss: 1.8345	Accuracy: 0.500
# Batch: 380	Train Loss: 1.4347	Accuracy: 0.750
# Batch: 400	Train Loss: 0.8333	Accuracy: 0.750
# Batch: 420	Train Loss: 1.6006	Accuracy: 0.750
# Batch: 440	Train Loss: 1.1202	Accuracy: 0.500
# Batch: 460	Train Loss: 1.7660	Accuracy: 0.250
# Batch: 480	Train Loss: 2.1094	Accuracy: 0.250
# Batch: 500	Train Loss: 2.0525	Accuracy: 0.000
# Batch: 520	Train Loss: 2.2102	Accuracy: 0.250
# Batch: 540	Train Loss: 0.8870	Accuracy: 0.750
# Batch: 560	Train Loss: 2.1816	Accuracy: 0.500
# Batch: 580	Train Loss: 2.0660	Accuracy: 0.250
# Batch: 600	Train Loss: 1.6490	Accuracy: 0.500
# Batch: 620	Train Loss: 0.9417	Accuracy: 0.750
# Batch: 640	Train Loss: 2.1309	Accuracy: 0.250
# Batch: 660	Train Loss: 1.6079	Accuracy: 0.250
# Batch: 680	Train Loss: 0.9733	Accuracy: 0.500
# Batch: 700	Train Loss: 2.3114	Accuracy: 0.500
# Batch: 720	Train Loss: 3.1869	Accuracy: 0.250
# Batch: 740	Train Loss: 1.4889	Accuracy: 0.250
# Batch: 760	Train Loss: 1.0124	Accuracy: 1.000
# Batch: 780	Train Loss: 0.5175	Accuracy: 0.750
# Batch: 800	Train Loss: 1.7130	Accuracy: 0.500
# Batch: 820	Train Loss: 2.7478	Accuracy: 0.000
# Batch: 840	Train Loss: 2.2060	Accuracy: 0.250
# Batch: 860	Train Loss: 1.8802	Accuracy: 0.500
# Batch: 880	Train Loss: 1.8664	Accuracy: 0.500
# Batch: 900	Train Loss: 1.6985	Accuracy: 0.250
# Batch: 920	Train Loss: 1.0861	Accuracy: 0.750
# Batch: 940	Train Loss: 1.8830	Accuracy: 0.250
# Batch: 960	Train Loss: 2.8265	Accuracy: 0.250
# Batch: 980	Train Loss: 1.4413	Accuracy: 0.500
# Batch: 1000	Train Loss: 1.6943	Accuracy: 0.500
# Batch: 1020	Train Loss: 2.0280	Accuracy: 0.500
# Batch: 1040	Train Loss: 1.6256	Accuracy: 0.250
# Epoch: 0
# Train Loss: 1.961930 Acc: 0.3687
# Elapsed 111.16s, 111.16 s/epoch, 0.11 s/batch, ets 2112.07s
#
# Test set: Average loss: 1.4178, Accuracy: 583/1042 (56%)
#
# Model Improved. Saving the Model...
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 1068	Train Loss: 2.6319	Accuracy: 0.250
# Batch: 1088	Train Loss: 0.9726	Accuracy: 0.750
# Batch: 1108	Train Loss: 2.0589	Accuracy: 0.250
# Batch: 1128	Train Loss: 1.1869	Accuracy: 0.750
# Batch: 1148	Train Loss: 0.8321	Accuracy: 1.000
# Batch: 1168	Train Loss: 0.2308	Accuracy: 1.000
# Batch: 1188	Train Loss: 1.0840	Accuracy: 0.750
# Batch: 1208	Train Loss: 1.4602	Accuracy: 0.500
# Batch: 1228	Train Loss: 2.0290	Accuracy: 0.500
# Batch: 1248	Train Loss: 1.2191	Accuracy: 0.250
# Batch: 1268	Train Loss: 2.3133	Accuracy: 0.000
# Batch: 1288	Train Loss: 0.6488	Accuracy: 1.000
# Batch: 1308	Train Loss: 3.2621	Accuracy: 0.250
# Batch: 1328	Train Loss: 1.6298	Accuracy: 0.500
# Batch: 1348	Train Loss: 0.5018	Accuracy: 0.750
# Batch: 1368	Train Loss: 1.8745	Accuracy: 0.500
# Batch: 1388	Train Loss: 1.6185	Accuracy: 0.500
# Batch: 1408	Train Loss: 2.6140	Accuracy: 0.250
# Batch: 1428	Train Loss: 1.9325	Accuracy: 0.500
# Batch: 1448	Train Loss: 0.8383	Accuracy: 1.000
# Batch: 1468	Train Loss: 0.5642	Accuracy: 0.750
# Batch: 1488	Train Loss: 1.2721	Accuracy: 0.750
# Batch: 1508	Train Loss: 3.0668	Accuracy: 0.250
# Batch: 1528	Train Loss: 1.4142	Accuracy: 0.500
# Batch: 1548	Train Loss: 1.1277	Accuracy: 0.750
# Batch: 1568	Train Loss: 1.1705	Accuracy: 0.750
# Batch: 1588	Train Loss: 2.3528	Accuracy: 0.000
# Batch: 1608	Train Loss: 2.1887	Accuracy: 0.250
# Batch: 1628	Train Loss: 2.0110	Accuracy: 0.250
# Batch: 1648	Train Loss: 0.9664	Accuracy: 0.750
# Batch: 1668	Train Loss: 1.1079	Accuracy: 0.500
# Batch: 1688	Train Loss: 2.1496	Accuracy: 0.250
# Batch: 1708	Train Loss: 1.4255	Accuracy: 0.500
# Batch: 1728	Train Loss: 0.7071	Accuracy: 1.000
# Batch: 1748	Train Loss: 4.1517	Accuracy: 0.250
# Batch: 1768	Train Loss: 2.2337	Accuracy: 0.000
# Batch: 1788	Train Loss: 1.4619	Accuracy: 0.500
# Batch: 1808	Train Loss: 1.7784	Accuracy: 0.250
# Batch: 1828	Train Loss: 2.8662	Accuracy: 0.250
# Batch: 1848	Train Loss: 2.3542	Accuracy: 0.500
# Batch: 1868	Train Loss: 0.4400	Accuracy: 0.750
# Batch: 1888	Train Loss: 2.3922	Accuracy: 0.250
# Batch: 1908	Train Loss: 3.3532	Accuracy: 0.250
# Batch: 1928	Train Loss: 2.1224	Accuracy: 0.250
# Batch: 1948	Train Loss: 0.7392	Accuracy: 0.750
# Batch: 1968	Train Loss: 1.3620	Accuracy: 0.500
# Batch: 1988	Train Loss: 1.3944	Accuracy: 0.250
# Batch: 2008	Train Loss: 1.0737	Accuracy: 0.750
# Batch: 2028	Train Loss: 2.3136	Accuracy: 0.250
# Batch: 2048	Train Loss: 0.9195	Accuracy: 0.750
# Batch: 2068	Train Loss: 2.4889	Accuracy: 0.000
# Batch: 2088	Train Loss: 2.2381	Accuracy: 0.250
# Epoch: 1
# Train Loss: 1.550969 Acc: 0.4967
# Elapsed 248.89s, 124.44 s/epoch, 0.12 s/batch, ets 2239.99s
#
# Test set: Average loss: 1.3693, Accuracy: 631/1042 (61%)
#
# Model Improved. Saving the Model...
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 2117	Train Loss: 2.2986	Accuracy: 0.000
# Batch: 2137	Train Loss: 1.3228	Accuracy: 0.750
# Batch: 2157	Train Loss: 2.8911	Accuracy: 0.250
# Batch: 2177	Train Loss: 2.4226	Accuracy: 0.250
# Batch: 2197	Train Loss: 0.8360	Accuracy: 0.750
# Batch: 2217	Train Loss: 0.6146	Accuracy: 0.750
# Batch: 2237	Train Loss: 1.4531	Accuracy: 0.750
# Batch: 2257	Train Loss: 1.2929	Accuracy: 0.500
# Batch: 2277	Train Loss: 1.4738	Accuracy: 0.500
# Batch: 2297	Train Loss: 1.3781	Accuracy: 0.750
# Batch: 2317	Train Loss: 0.7433	Accuracy: 1.000
# Batch: 2337	Train Loss: 1.5210	Accuracy: 0.750
# Batch: 2357	Train Loss: 0.6629	Accuracy: 1.000
# Batch: 2377	Train Loss: 0.9140	Accuracy: 0.750
# Batch: 2397	Train Loss: 1.9391	Accuracy: 0.250
# Batch: 2417	Train Loss: 1.2323	Accuracy: 0.500
# Batch: 2437	Train Loss: 1.5392	Accuracy: 0.500
# Batch: 2457	Train Loss: 1.9127	Accuracy: 0.500
# Batch: 2477	Train Loss: 2.1427	Accuracy: 0.500
# Batch: 2497	Train Loss: 0.4818	Accuracy: 1.000
# Batch: 2517	Train Loss: 1.2414	Accuracy: 0.750
# Batch: 2537	Train Loss: 0.3904	Accuracy: 0.750
# Batch: 2557	Train Loss: 1.7289	Accuracy: 0.500
# Batch: 2577	Train Loss: 1.1639	Accuracy: 0.500
# Batch: 2597	Train Loss: 2.0034	Accuracy: 0.250
# Batch: 2617	Train Loss: 1.6995	Accuracy: 0.750
# Batch: 2637	Train Loss: 1.2918	Accuracy: 0.500
# Batch: 2657	Train Loss: 0.4604	Accuracy: 1.000
# Batch: 2677	Train Loss: 1.5280	Accuracy: 0.500
# Batch: 2697	Train Loss: 1.3928	Accuracy: 0.250
# Batch: 2717	Train Loss: 1.3593	Accuracy: 0.750
# Batch: 2737	Train Loss: 0.9312	Accuracy: 0.750
# Batch: 2757	Train Loss: 1.4296	Accuracy: 0.500
# Batch: 2777	Train Loss: 0.9931	Accuracy: 0.750
# Batch: 2797	Train Loss: 2.1759	Accuracy: 0.000
# Batch: 2817	Train Loss: 3.1218	Accuracy: 0.250
# Batch: 2837	Train Loss: 0.7853	Accuracy: 0.500
# Batch: 2857	Train Loss: 1.2831	Accuracy: 0.500
# Batch: 2877	Train Loss: 1.6503	Accuracy: 0.750
# Batch: 2897	Train Loss: 1.3042	Accuracy: 0.250
# Batch: 2917	Train Loss: 1.0930	Accuracy: 0.750
# Batch: 2937	Train Loss: 1.2699	Accuracy: 0.500
# Batch: 2957	Train Loss: 2.0915	Accuracy: 0.750
# Batch: 2977	Train Loss: 1.5281	Accuracy: 0.500
# Batch: 2997	Train Loss: 1.3274	Accuracy: 0.500
# Batch: 3017	Train Loss: 1.2813	Accuracy: 0.500
# Batch: 3037	Train Loss: 0.7773	Accuracy: 0.750
# Batch: 3057	Train Loss: 1.2234	Accuracy: 0.500
# Batch: 3077	Train Loss: 0.5921	Accuracy: 1.000
# Batch: 3097	Train Loss: 0.3562	Accuracy: 1.000
# Batch: 3117	Train Loss: 2.0222	Accuracy: 0.500
# Batch: 3137	Train Loss: 2.2281	Accuracy: 0.250
# Epoch: 2
# Train Loss: 1.433726 Acc: 0.5446
# Elapsed 386.70s, 128.90 s/epoch, 0.12 s/batch, ets 2191.32s
#
# Test set: Average loss: 1.2771, Accuracy: 629/1042 (60%)
#
# Model Improved. Saving the Model...
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 3165	Train Loss: 1.3303	Accuracy: 0.750
# Batch: 3185	Train Loss: 2.8142	Accuracy: 0.250
# Batch: 3205	Train Loss: 0.5564	Accuracy: 0.750
# Batch: 3225	Train Loss: 0.6556	Accuracy: 0.750
# Batch: 3245	Train Loss: 1.9340	Accuracy: 0.500
# Batch: 3265	Train Loss: 1.3453	Accuracy: 0.750
# Batch: 3285	Train Loss: 0.9173	Accuracy: 0.750
# Batch: 3305	Train Loss: 1.1233	Accuracy: 0.500
# Batch: 3325	Train Loss: 0.5345	Accuracy: 1.000
# Batch: 3345	Train Loss: 0.5440	Accuracy: 0.750
# Batch: 3365	Train Loss: 1.1276	Accuracy: 0.750
# Batch: 3385	Train Loss: 1.2934	Accuracy: 0.250
# Batch: 3405	Train Loss: 2.5084	Accuracy: 0.000
# Batch: 3425	Train Loss: 2.1549	Accuracy: 0.500
# Batch: 3445	Train Loss: 0.5533	Accuracy: 0.750
# Batch: 3465	Train Loss: 1.1527	Accuracy: 0.500
# Batch: 3485	Train Loss: 1.9440	Accuracy: 0.250
# Batch: 3505	Train Loss: 2.3905	Accuracy: 0.500
# Batch: 3525	Train Loss: 1.0880	Accuracy: 0.250
# Batch: 3545	Train Loss: 0.8286	Accuracy: 0.750
# Batch: 3565	Train Loss: 0.3701	Accuracy: 1.000
# Batch: 3585	Train Loss: 1.1111	Accuracy: 0.500
# Batch: 3605	Train Loss: 2.7074	Accuracy: 0.250
# Batch: 3625	Train Loss: 1.2967	Accuracy: 0.500
# Batch: 3645	Train Loss: 1.3786	Accuracy: 0.750
# Batch: 3665	Train Loss: 0.6230	Accuracy: 1.000
# Batch: 3685	Train Loss: 0.6116	Accuracy: 0.750
# Batch: 3705	Train Loss: 3.2212	Accuracy: 0.250
# Batch: 3725	Train Loss: 1.7266	Accuracy: 0.250
# Batch: 3745	Train Loss: 0.4676	Accuracy: 0.750
# Batch: 3765	Train Loss: 1.6083	Accuracy: 0.500
# Batch: 3785	Train Loss: 1.4442	Accuracy: 0.500
# Batch: 3805	Train Loss: 1.4893	Accuracy: 0.500
# Batch: 3825	Train Loss: 2.2600	Accuracy: 0.250
# Batch: 3845	Train Loss: 1.7619	Accuracy: 0.750
# Batch: 3865	Train Loss: 0.3511	Accuracy: 1.000
# Batch: 3885	Train Loss: 0.7125	Accuracy: 0.750
# Batch: 3905	Train Loss: 2.1301	Accuracy: 0.250
# Batch: 3925	Train Loss: 1.7364	Accuracy: 0.500
# Batch: 3945	Train Loss: 0.3667	Accuracy: 0.750
# Batch: 3965	Train Loss: 1.1927	Accuracy: 0.500
# Batch: 3985	Train Loss: 2.7785	Accuracy: 0.250
# Batch: 4005	Train Loss: 1.6333	Accuracy: 0.500
# Batch: 4025	Train Loss: 1.6046	Accuracy: 0.500
# Batch: 4045	Train Loss: 2.0527	Accuracy: 0.250
# Batch: 4065	Train Loss: 3.4706	Accuracy: 0.250
# Batch: 4085	Train Loss: 2.1766	Accuracy: 0.500
# Batch: 4105	Train Loss: 1.1349	Accuracy: 0.500
# Batch: 4125	Train Loss: 1.8180	Accuracy: 0.250
# Batch: 4145	Train Loss: 1.0228	Accuracy: 0.750
# Batch: 4165	Train Loss: 0.2569	Accuracy: 1.000
# Batch: 4185	Train Loss: 2.5116	Accuracy: 0.500
# Epoch: 3
# Train Loss: 1.314205 Acc: 0.5789
# Elapsed 524.58s, 131.15 s/epoch, 0.13 s/batch, ets 2098.33s
#
# Test set: Average loss: 1.3613, Accuracy: 627/1042 (60%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 4214	Train Loss: 2.1134	Accuracy: 0.500
# Batch: 4234	Train Loss: 0.4961	Accuracy: 0.750
# Batch: 4254	Train Loss: 1.5060	Accuracy: 0.500
# Batch: 4274	Train Loss: 1.4221	Accuracy: 0.750
# Batch: 4294	Train Loss: 1.6992	Accuracy: 0.500
# Batch: 4314	Train Loss: 1.1468	Accuracy: 0.500
# Batch: 4334	Train Loss: 0.9863	Accuracy: 0.500
# Batch: 4354	Train Loss: 0.6265	Accuracy: 1.000
# Batch: 4374	Train Loss: 1.8373	Accuracy: 0.250
# Batch: 4394	Train Loss: 1.5121	Accuracy: 0.500
# Batch: 4414	Train Loss: 0.7942	Accuracy: 0.750
# Batch: 4434	Train Loss: 0.2494	Accuracy: 1.000
# Batch: 4454	Train Loss: 0.5176	Accuracy: 0.750
# Batch: 4474	Train Loss: 1.1576	Accuracy: 0.750
# Batch: 4494	Train Loss: 1.0411	Accuracy: 0.500
# Batch: 4514	Train Loss: 1.0476	Accuracy: 0.750
# Batch: 4534	Train Loss: 1.3717	Accuracy: 0.250
# Batch: 4554	Train Loss: 2.1203	Accuracy: 0.500
# Batch: 4574	Train Loss: 0.9451	Accuracy: 0.750
# Batch: 4594	Train Loss: 1.0053	Accuracy: 0.750
# Batch: 4614	Train Loss: 0.2198	Accuracy: 1.000
# Batch: 4634	Train Loss: 0.7921	Accuracy: 0.750
# Batch: 4654	Train Loss: 0.7071	Accuracy: 0.750
# Batch: 4674	Train Loss: 1.0767	Accuracy: 0.750
# Batch: 4694	Train Loss: 0.9561	Accuracy: 0.750
# Batch: 4714	Train Loss: 0.9809	Accuracy: 0.750
# Batch: 4734	Train Loss: 1.5050	Accuracy: 0.500
# Batch: 4754	Train Loss: 0.5805	Accuracy: 0.750
# Batch: 4774	Train Loss: 2.9205	Accuracy: 0.250
# Batch: 4794	Train Loss: 1.1591	Accuracy: 0.750
# Batch: 4814	Train Loss: 0.9638	Accuracy: 0.750
# Batch: 4834	Train Loss: 0.5053	Accuracy: 0.750
# Batch: 4854	Train Loss: 1.1499	Accuracy: 0.750
# Batch: 4874	Train Loss: 1.3526	Accuracy: 0.750
# Batch: 4894	Train Loss: 1.3835	Accuracy: 0.500
# Batch: 4914	Train Loss: 0.9279	Accuracy: 0.750
# Batch: 4934	Train Loss: 0.7990	Accuracy: 0.750
# Batch: 4954	Train Loss: 0.4550	Accuracy: 1.000
# Batch: 4974	Train Loss: 1.2455	Accuracy: 0.500
# Batch: 4994	Train Loss: 2.5330	Accuracy: 0.250
# Batch: 5014	Train Loss: 1.8520	Accuracy: 0.250
# Batch: 5034	Train Loss: 0.5163	Accuracy: 1.000
# Batch: 5054	Train Loss: 0.5301	Accuracy: 0.750
# Batch: 5074	Train Loss: 0.4702	Accuracy: 1.000
# Batch: 5094	Train Loss: 1.0839	Accuracy: 0.500
# Batch: 5114	Train Loss: 0.6382	Accuracy: 0.750
# Batch: 5134	Train Loss: 0.4691	Accuracy: 0.750
# Batch: 5154	Train Loss: 2.2383	Accuracy: 0.250
# Batch: 5174	Train Loss: 1.4322	Accuracy: 0.250
# Batch: 5194	Train Loss: 0.6578	Accuracy: 0.750
# Batch: 5214	Train Loss: 2.5770	Accuracy: 0.250
# Batch: 5234	Train Loss: 0.6329	Accuracy: 0.750
# Epoch: 4
# Train Loss: 1.221014 Acc: 0.6168
# Elapsed 662.38s, 132.48 s/epoch, 0.13 s/batch, ets 1987.13s
#
# Test set: Average loss: 1.3478, Accuracy: 644/1042 (62%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 5262	Train Loss: 1.1425	Accuracy: 0.750
# Batch: 5282	Train Loss: 0.9560	Accuracy: 0.250
# Batch: 5302	Train Loss: 0.6745	Accuracy: 0.750
# Batch: 5322	Train Loss: 1.0933	Accuracy: 0.750
# Batch: 5342	Train Loss: 0.3052	Accuracy: 1.000
# Batch: 5362	Train Loss: 2.3880	Accuracy: 0.250
# Batch: 5382	Train Loss: 0.7368	Accuracy: 0.500
# Batch: 5402	Train Loss: 0.9244	Accuracy: 0.750
# Batch: 5422	Train Loss: 1.2089	Accuracy: 0.500
# Batch: 5442	Train Loss: 1.6007	Accuracy: 0.500
# Batch: 5462	Train Loss: 2.4255	Accuracy: 0.500
# Batch: 5482	Train Loss: 2.6805	Accuracy: 0.500
# Batch: 5502	Train Loss: 0.6953	Accuracy: 0.750
# Batch: 5522	Train Loss: 0.7173	Accuracy: 0.750
# Batch: 5542	Train Loss: 0.6401	Accuracy: 0.750
# Batch: 5562	Train Loss: 1.1180	Accuracy: 0.500
# Batch: 5582	Train Loss: 0.3465	Accuracy: 1.000
# Batch: 5602	Train Loss: 0.9757	Accuracy: 0.500
# Batch: 5622	Train Loss: 1.5601	Accuracy: 0.500
# Batch: 5642	Train Loss: 0.9253	Accuracy: 0.500
# Batch: 5662	Train Loss: 0.1311	Accuracy: 1.000
# Batch: 5682	Train Loss: 1.0371	Accuracy: 0.500
# Batch: 5702	Train Loss: 1.2040	Accuracy: 0.250
# Batch: 5722	Train Loss: 1.1070	Accuracy: 0.750
# Batch: 5742	Train Loss: 1.1021	Accuracy: 0.750
# Batch: 5762	Train Loss: 0.5681	Accuracy: 1.000
# Batch: 5782	Train Loss: 1.0149	Accuracy: 0.500
# Batch: 5802	Train Loss: 0.8175	Accuracy: 0.500
# Batch: 5822	Train Loss: 1.5135	Accuracy: 0.500
# Batch: 5842	Train Loss: 0.2037	Accuracy: 1.000
# Batch: 5862	Train Loss: 0.7933	Accuracy: 0.500
# Batch: 5882	Train Loss: 0.2272	Accuracy: 1.000
# Batch: 5902	Train Loss: 1.1067	Accuracy: 0.500
# Batch: 5922	Train Loss: 1.4487	Accuracy: 0.750
# Batch: 5942	Train Loss: 0.3700	Accuracy: 1.000
# Batch: 5962	Train Loss: 0.7899	Accuracy: 0.750
# Batch: 5982	Train Loss: 0.8521	Accuracy: 0.500
# Batch: 6002	Train Loss: 1.4875	Accuracy: 0.750
# Batch: 6022	Train Loss: 2.5485	Accuracy: 0.250
# Batch: 6042	Train Loss: 0.4526	Accuracy: 0.750
# Batch: 6062	Train Loss: 1.1870	Accuracy: 0.500
# Batch: 6082	Train Loss: 0.3138	Accuracy: 1.000
# Batch: 6102	Train Loss: 0.8452	Accuracy: 0.500
# Batch: 6122	Train Loss: 1.4796	Accuracy: 0.500
# Batch: 6142	Train Loss: 0.3769	Accuracy: 0.750
# Batch: 6162	Train Loss: 0.8206	Accuracy: 0.750
# Batch: 6182	Train Loss: 1.0907	Accuracy: 0.500
# Batch: 6202	Train Loss: 0.2370	Accuracy: 1.000
# Batch: 6222	Train Loss: 0.3253	Accuracy: 1.000
# Batch: 6242	Train Loss: 1.4900	Accuracy: 0.500
# Batch: 6262	Train Loss: 1.0630	Accuracy: 0.250
# Batch: 6282	Train Loss: 1.0297	Accuracy: 0.500
# Epoch: 5
# Train Loss: 1.122599 Acc: 0.6404
# Elapsed 799.93s, 133.32 s/epoch, 0.13 s/batch, ets 1866.51s
#
# Test set: Average loss: 1.3496, Accuracy: 643/1042 (62%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 6311	Train Loss: 0.9621	Accuracy: 0.500
# Batch: 6331	Train Loss: 1.7558	Accuracy: 0.250
# Batch: 6351	Train Loss: 1.8006	Accuracy: 0.250
# Batch: 6371	Train Loss: 0.5963	Accuracy: 0.750
# Batch: 6391	Train Loss: 1.3174	Accuracy: 0.500
# Batch: 6411	Train Loss: 0.2490	Accuracy: 1.000
# Batch: 6431	Train Loss: 0.6227	Accuracy: 0.750
# Batch: 6451	Train Loss: 0.6717	Accuracy: 0.750
# Batch: 6471	Train Loss: 1.6275	Accuracy: 0.500
# Batch: 6491	Train Loss: 0.3115	Accuracy: 1.000
# Batch: 6511	Train Loss: 1.4353	Accuracy: 0.500
# Batch: 6531	Train Loss: 1.5214	Accuracy: 0.500
# Batch: 6551	Train Loss: 0.5633	Accuracy: 0.750
# Batch: 6571	Train Loss: 0.1211	Accuracy: 1.000
# Batch: 6591	Train Loss: 1.9529	Accuracy: 0.500
# Batch: 6611	Train Loss: 1.0586	Accuracy: 0.500
# Batch: 6631	Train Loss: 2.7909	Accuracy: 0.000
# Batch: 6651	Train Loss: 0.4767	Accuracy: 1.000
# Batch: 6671	Train Loss: 1.0381	Accuracy: 0.750
# Batch: 6691	Train Loss: 0.3732	Accuracy: 1.000
# Batch: 6711	Train Loss: 1.2586	Accuracy: 0.750
# Batch: 6731	Train Loss: 1.2751	Accuracy: 0.500
# Batch: 6751	Train Loss: 1.6745	Accuracy: 0.750
# Batch: 6771	Train Loss: 0.9803	Accuracy: 0.750
# Batch: 6791	Train Loss: 1.0874	Accuracy: 0.500
# Batch: 6811	Train Loss: 1.8297	Accuracy: 0.500
# Batch: 6831	Train Loss: 2.1534	Accuracy: 0.500
# Batch: 6851	Train Loss: 0.8398	Accuracy: 0.750
# Batch: 6871	Train Loss: 0.3204	Accuracy: 1.000
# Batch: 6891	Train Loss: 0.4348	Accuracy: 0.750
# Batch: 6911	Train Loss: 0.5610	Accuracy: 0.750
# Batch: 6931	Train Loss: 1.3323	Accuracy: 0.750
# Batch: 6951	Train Loss: 1.0056	Accuracy: 0.750
# Batch: 6971	Train Loss: 0.1345	Accuracy: 1.000
# Batch: 6991	Train Loss: 0.3984	Accuracy: 1.000
# Batch: 7011	Train Loss: 1.1053	Accuracy: 0.500
# Batch: 7031	Train Loss: 0.2777	Accuracy: 1.000
# Batch: 7051	Train Loss: 1.9161	Accuracy: 0.500
# Batch: 7071	Train Loss: 1.3093	Accuracy: 0.500
# Batch: 7091	Train Loss: 0.9723	Accuracy: 0.500
# Batch: 7111	Train Loss: 1.4324	Accuracy: 0.500
# Batch: 7131	Train Loss: 0.1224	Accuracy: 1.000
# Batch: 7151	Train Loss: 1.3740	Accuracy: 0.250
# Batch: 7171	Train Loss: 0.4673	Accuracy: 0.750
# Batch: 7191	Train Loss: 0.8869	Accuracy: 0.500
# Batch: 7211	Train Loss: 1.1864	Accuracy: 0.500
# Batch: 7231	Train Loss: 1.8121	Accuracy: 0.250
# Batch: 7251	Train Loss: 0.6390	Accuracy: 0.750
# Batch: 7271	Train Loss: 1.2224	Accuracy: 0.750
# Batch: 7291	Train Loss: 1.7181	Accuracy: 0.500
# Batch: 7311	Train Loss: 0.9648	Accuracy: 0.750
# Batch: 7331	Train Loss: 1.5012	Accuracy: 0.500
# Epoch: 6
# Train Loss: 1.042785 Acc: 0.6587
# Elapsed 937.73s, 133.96 s/epoch, 0.13 s/batch, ets 1741.49s
#
# Test set: Average loss: 1.4662, Accuracy: 638/1042 (61%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 7359	Train Loss: 1.1002	Accuracy: 0.750
# Batch: 7379	Train Loss: 0.8988	Accuracy: 0.500
# Batch: 7399	Train Loss: 0.6180	Accuracy: 1.000
# Batch: 7419	Train Loss: 1.0409	Accuracy: 0.500
# Batch: 7439	Train Loss: 0.8064	Accuracy: 0.500
# Batch: 7459	Train Loss: 1.8750	Accuracy: 0.500
# Batch: 7479	Train Loss: 0.8504	Accuracy: 0.750
# Batch: 7499	Train Loss: 0.0983	Accuracy: 1.000
# Batch: 7519	Train Loss: 1.5878	Accuracy: 0.250
# Batch: 7539	Train Loss: 1.0146	Accuracy: 0.500
# Batch: 7559	Train Loss: 0.2994	Accuracy: 1.000
# Batch: 7579	Train Loss: 0.1185	Accuracy: 1.000
# Batch: 7599	Train Loss: 1.4315	Accuracy: 0.500
# Batch: 7619	Train Loss: 1.5934	Accuracy: 0.500
# Batch: 7639	Train Loss: 2.1070	Accuracy: 0.500
# Batch: 7659	Train Loss: 0.4764	Accuracy: 1.000
# Batch: 7679	Train Loss: 0.4277	Accuracy: 1.000
# Batch: 7699	Train Loss: 0.9364	Accuracy: 0.750
# Batch: 7719	Train Loss: 1.1647	Accuracy: 0.750
# Batch: 7739	Train Loss: 1.5135	Accuracy: 0.500
# Batch: 7759	Train Loss: 0.3144	Accuracy: 1.000
# Batch: 7779	Train Loss: 0.4695	Accuracy: 0.750
# Batch: 7799	Train Loss: 1.5209	Accuracy: 0.500
# Batch: 7819	Train Loss: 0.3927	Accuracy: 1.000
# Batch: 7839	Train Loss: 0.7587	Accuracy: 0.750
# Batch: 7859	Train Loss: 0.1209	Accuracy: 1.000
# Batch: 7879	Train Loss: 0.1150	Accuracy: 1.000
# Batch: 7899	Train Loss: 1.4756	Accuracy: 0.500
# Batch: 7919	Train Loss: 0.2571	Accuracy: 0.750
# Batch: 7939	Train Loss: 0.7225	Accuracy: 0.750
# Batch: 7959	Train Loss: 0.2942	Accuracy: 1.000
# Batch: 7979	Train Loss: 1.9210	Accuracy: 0.500
# Batch: 7999	Train Loss: 0.6050	Accuracy: 1.000
# Batch: 8019	Train Loss: 0.9124	Accuracy: 0.750
# Batch: 8039	Train Loss: 0.4620	Accuracy: 0.750
# Batch: 8059	Train Loss: 0.6310	Accuracy: 0.750
# Batch: 8079	Train Loss: 1.5772	Accuracy: 0.250
# Batch: 8099	Train Loss: 0.0668	Accuracy: 1.000
# Batch: 8119	Train Loss: 2.2846	Accuracy: 0.500
# Batch: 8139	Train Loss: 2.4697	Accuracy: 0.250
# Batch: 8159	Train Loss: 0.0567	Accuracy: 1.000
# Batch: 8179	Train Loss: 1.3142	Accuracy: 0.500
# Batch: 8199	Train Loss: 0.3110	Accuracy: 1.000
# Batch: 8219	Train Loss: 0.2401	Accuracy: 0.750
# Batch: 8239	Train Loss: 1.0180	Accuracy: 0.750
# Batch: 8259	Train Loss: 2.9517	Accuracy: 0.250
# Batch: 8279	Train Loss: 0.9100	Accuracy: 0.750
# Batch: 8299	Train Loss: 0.6325	Accuracy: 1.000
# Batch: 8319	Train Loss: 2.3219	Accuracy: 0.500
# Batch: 8339	Train Loss: 0.3079	Accuracy: 1.000
# Batch: 8359	Train Loss: 2.0442	Accuracy: 0.500
# Batch: 8379	Train Loss: 0.2686	Accuracy: 1.000
# Epoch: 7
# Train Loss: 0.943235 Acc: 0.6909
# Elapsed 1075.62s, 134.45 s/epoch, 0.13 s/batch, ets 1613.44s
#
# Test set: Average loss: 1.4583, Accuracy: 673/1042 (65%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 8408	Train Loss: 1.6345	Accuracy: 0.500
# Batch: 8428	Train Loss: 1.2092	Accuracy: 0.250
# Batch: 8448	Train Loss: 0.3981	Accuracy: 1.000
# Batch: 8468	Train Loss: 0.4022	Accuracy: 1.000
# Batch: 8488	Train Loss: 0.4155	Accuracy: 1.000
# Batch: 8508	Train Loss: 0.5248	Accuracy: 0.750
# Batch: 8528	Train Loss: 0.2289	Accuracy: 1.000
# Batch: 8548	Train Loss: 1.3407	Accuracy: 0.500
# Batch: 8568	Train Loss: 1.5078	Accuracy: 0.750
# Batch: 8588	Train Loss: 0.4236	Accuracy: 0.750
# Batch: 8608	Train Loss: 0.5709	Accuracy: 0.750
# Batch: 8628	Train Loss: 0.9223	Accuracy: 0.750
# Batch: 8648	Train Loss: 1.6076	Accuracy: 0.500
# Batch: 8668	Train Loss: 0.2289	Accuracy: 1.000
# Batch: 8688	Train Loss: 0.7768	Accuracy: 0.500
# Batch: 8708	Train Loss: 0.0666	Accuracy: 1.000
# Batch: 8728	Train Loss: 0.7965	Accuracy: 0.750
# Batch: 8748	Train Loss: 0.7957	Accuracy: 0.750
# Batch: 8768	Train Loss: 0.6799	Accuracy: 0.750
# Batch: 8788	Train Loss: 0.6464	Accuracy: 0.750
# Batch: 8808	Train Loss: 1.3576	Accuracy: 0.500
# Batch: 8828	Train Loss: 0.2471	Accuracy: 1.000
# Batch: 8848	Train Loss: 0.8450	Accuracy: 0.500
# Batch: 8868	Train Loss: 0.4602	Accuracy: 1.000
# Batch: 8888	Train Loss: 0.1030	Accuracy: 1.000
# Batch: 8908	Train Loss: 0.7219	Accuracy: 0.750
# Batch: 8928	Train Loss: 0.7788	Accuracy: 0.750
# Batch: 8948	Train Loss: 0.1415	Accuracy: 1.000
# Batch: 8968	Train Loss: 1.2288	Accuracy: 0.750
# Batch: 8988	Train Loss: 0.2872	Accuracy: 0.750
# Batch: 9008	Train Loss: 0.3999	Accuracy: 1.000
# Batch: 9028	Train Loss: 0.3467	Accuracy: 1.000
# Batch: 9048	Train Loss: 0.1202	Accuracy: 1.000
# Batch: 9068	Train Loss: 0.6963	Accuracy: 0.750
# Batch: 9088	Train Loss: 1.5782	Accuracy: 0.500
# Batch: 9108	Train Loss: 2.0884	Accuracy: 0.500
# Batch: 9128	Train Loss: 0.3775	Accuracy: 1.000
# Batch: 9148	Train Loss: 0.3175	Accuracy: 0.750
# Batch: 9168	Train Loss: 0.4573	Accuracy: 0.750
# Batch: 9188	Train Loss: 0.7724	Accuracy: 0.500
# Batch: 9208	Train Loss: 1.0063	Accuracy: 0.500
# Batch: 9228	Train Loss: 0.0944	Accuracy: 1.000
# Batch: 9248	Train Loss: 0.8764	Accuracy: 0.500
# Batch: 9268	Train Loss: 1.1443	Accuracy: 0.750
# Batch: 9288	Train Loss: 0.3573	Accuracy: 0.750
# Batch: 9308	Train Loss: 0.3251	Accuracy: 0.750
# Batch: 9328	Train Loss: 1.3720	Accuracy: 0.500
# Batch: 9348	Train Loss: 0.7297	Accuracy: 0.750
# Batch: 9368	Train Loss: 0.5013	Accuracy: 0.750
# Batch: 9388	Train Loss: 0.3193	Accuracy: 1.000
# Batch: 9408	Train Loss: 1.1466	Accuracy: 0.500
# Batch: 9428	Train Loss: 0.6875	Accuracy: 0.750
# Epoch: 8
# Train Loss: 0.905414 Acc: 0.7069
# Elapsed 1212.46s, 134.72 s/epoch, 0.13 s/batch, ets 1481.89s
#
# Test set: Average loss: 1.6549, Accuracy: 614/1042 (59%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 9456	Train Loss: 0.2638	Accuracy: 1.000
# Batch: 9476	Train Loss: 0.2469	Accuracy: 1.000
# Batch: 9496	Train Loss: 0.7215	Accuracy: 0.750
# Batch: 9516	Train Loss: 1.4958	Accuracy: 0.750
# Batch: 9536	Train Loss: 1.2604	Accuracy: 0.750
# Batch: 9556	Train Loss: 0.5932	Accuracy: 0.750
# Batch: 9576	Train Loss: 0.2063	Accuracy: 1.000
# Batch: 9596	Train Loss: 1.1454	Accuracy: 0.750
# Batch: 9616	Train Loss: 0.9118	Accuracy: 0.500
# Batch: 9636	Train Loss: 0.2900	Accuracy: 1.000
# Batch: 9656	Train Loss: 0.0637	Accuracy: 1.000
# Batch: 9676	Train Loss: 0.0469	Accuracy: 1.000
# Batch: 9696	Train Loss: 0.8603	Accuracy: 0.500
# Batch: 9716	Train Loss: 0.0462	Accuracy: 1.000
# Batch: 9736	Train Loss: 0.4471	Accuracy: 1.000
# Batch: 9756	Train Loss: 0.7136	Accuracy: 0.750
# Batch: 9776	Train Loss: 0.4662	Accuracy: 0.750
# Batch: 9796	Train Loss: 0.1268	Accuracy: 1.000
# Batch: 9816	Train Loss: 0.2799	Accuracy: 0.750
# Batch: 9836	Train Loss: 1.1730	Accuracy: 0.500
# Batch: 9856	Train Loss: 2.1416	Accuracy: 0.250
# Batch: 9876	Train Loss: 3.0843	Accuracy: 0.000
# Batch: 9896	Train Loss: 0.5080	Accuracy: 1.000
# Batch: 9916	Train Loss: 2.1812	Accuracy: 0.250
# Batch: 9936	Train Loss: 0.2395	Accuracy: 1.000
# Batch: 9956	Train Loss: 0.3511	Accuracy: 0.750
# Batch: 9976	Train Loss: 0.5070	Accuracy: 1.000
# Batch: 9996	Train Loss: 0.1432	Accuracy: 1.000
# Batch: 10016	Train Loss: 0.1720	Accuracy: 1.000
# Batch: 10036	Train Loss: 0.4974	Accuracy: 0.750
# Batch: 10056	Train Loss: 1.2184	Accuracy: 0.750
# Batch: 10076	Train Loss: 1.5686	Accuracy: 0.500
# Batch: 10096	Train Loss: 1.3837	Accuracy: 0.500
# Batch: 10116	Train Loss: 0.8706	Accuracy: 0.500
# Batch: 10136	Train Loss: 0.5384	Accuracy: 1.000
# Batch: 10156	Train Loss: 0.3932	Accuracy: 1.000
# Batch: 10176	Train Loss: 0.9041	Accuracy: 0.750
# Batch: 10196	Train Loss: 0.3856	Accuracy: 0.750
# Batch: 10216	Train Loss: 0.2152	Accuracy: 1.000
# Batch: 10236	Train Loss: 0.5434	Accuracy: 0.750
# Batch: 10256	Train Loss: 0.7331	Accuracy: 0.500
# Batch: 10276	Train Loss: 0.0139	Accuracy: 1.000
# Batch: 10296	Train Loss: 0.7425	Accuracy: 0.750
# Batch: 10316	Train Loss: 1.7481	Accuracy: 0.250
# Batch: 10336	Train Loss: 0.9208	Accuracy: 0.750
# Batch: 10356	Train Loss: 0.2092	Accuracy: 1.000
# Batch: 10376	Train Loss: 0.5048	Accuracy: 0.750
# Batch: 10396	Train Loss: 0.6481	Accuracy: 0.750
# Batch: 10416	Train Loss: 2.0328	Accuracy: 0.500
# Batch: 10436	Train Loss: 1.1224	Accuracy: 0.750
# Batch: 10456	Train Loss: 1.1589	Accuracy: 0.750
# Batch: 10476	Train Loss: 0.9300	Accuracy: 0.750
# Epoch: 9
# Train Loss: 0.824009 Acc: 0.7328
# Elapsed 1349.58s, 134.96 s/epoch, 0.13 s/batch, ets 1349.58s
#
# Test set: Average loss: 1.5506, Accuracy: 648/1042 (62%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 10505	Train Loss: 0.5659	Accuracy: 0.750
# Batch: 10525	Train Loss: 0.9832	Accuracy: 0.500
# Batch: 10545	Train Loss: 0.3529	Accuracy: 0.750
# Batch: 10565	Train Loss: 1.5322	Accuracy: 0.500
# Batch: 10585	Train Loss: 1.0258	Accuracy: 0.750
# Batch: 10605	Train Loss: 0.4143	Accuracy: 1.000
# Batch: 10625	Train Loss: 1.0217	Accuracy: 0.750
# Batch: 10645	Train Loss: 0.5608	Accuracy: 0.750
# Batch: 10665	Train Loss: 0.5843	Accuracy: 0.750
# Batch: 10685	Train Loss: 0.6179	Accuracy: 0.750
# Batch: 10705	Train Loss: 0.7487	Accuracy: 0.750
# Batch: 10725	Train Loss: 0.9714	Accuracy: 0.750
# Batch: 10745	Train Loss: 0.5578	Accuracy: 0.750
# Batch: 10765	Train Loss: 1.0589	Accuracy: 0.750
# Batch: 10785	Train Loss: 2.2269	Accuracy: 0.250
# Batch: 10805	Train Loss: 0.4317	Accuracy: 1.000
# Batch: 10825	Train Loss: 0.4733	Accuracy: 0.750
# Batch: 10845	Train Loss: 0.8226	Accuracy: 0.750
# Batch: 10865	Train Loss: 1.3733	Accuracy: 0.750
# Batch: 10885	Train Loss: 0.8460	Accuracy: 0.750
# Batch: 10905	Train Loss: 0.2621	Accuracy: 1.000
# Batch: 10925	Train Loss: 1.5243	Accuracy: 0.750
# Batch: 10945	Train Loss: 0.9691	Accuracy: 0.500
# Batch: 10965	Train Loss: 1.0210	Accuracy: 0.500
# Batch: 10985	Train Loss: 0.8085	Accuracy: 0.500
# Batch: 11005	Train Loss: 0.6265	Accuracy: 0.500
# Batch: 11025	Train Loss: 0.6889	Accuracy: 0.750
# Batch: 11045	Train Loss: 0.3852	Accuracy: 1.000
# Batch: 11065	Train Loss: 0.6277	Accuracy: 0.750
# Batch: 11085	Train Loss: 1.7827	Accuracy: 0.750
# Batch: 11105	Train Loss: 1.6299	Accuracy: 0.500
# Batch: 11125	Train Loss: 1.4791	Accuracy: 0.750
# Batch: 11145	Train Loss: 0.3341	Accuracy: 0.750
# Batch: 11165	Train Loss: 1.2703	Accuracy: 0.750
# Batch: 11185	Train Loss: 0.1009	Accuracy: 1.000
# Batch: 11205	Train Loss: 0.3439	Accuracy: 1.000
# Batch: 11225	Train Loss: 0.9150	Accuracy: 0.750
# Batch: 11245	Train Loss: 0.5889	Accuracy: 0.750
# Batch: 11265	Train Loss: 1.8435	Accuracy: 0.500
# Batch: 11285	Train Loss: 0.4291	Accuracy: 1.000
# Batch: 11305	Train Loss: 0.2503	Accuracy: 1.000
# Batch: 11325	Train Loss: 1.6260	Accuracy: 0.500
# Batch: 11345	Train Loss: 0.0783	Accuracy: 1.000
# Batch: 11365	Train Loss: 0.1622	Accuracy: 1.000
# Batch: 11385	Train Loss: 0.3328	Accuracy: 1.000
# Batch: 11405	Train Loss: 1.1326	Accuracy: 0.750
# Batch: 11425	Train Loss: 0.7632	Accuracy: 0.750
# Batch: 11445	Train Loss: 0.8949	Accuracy: 0.750
# Batch: 11465	Train Loss: 0.2849	Accuracy: 1.000
# Batch: 11485	Train Loss: 0.8317	Accuracy: 0.750
# Batch: 11505	Train Loss: 0.3378	Accuracy: 1.000
# Batch: 11525	Train Loss: 1.6125	Accuracy: 0.750
# Epoch: 10
# Train Loss: 0.761831 Acc: 0.7576
# Elapsed 1486.64s, 135.15 s/epoch, 0.13 s/batch, ets 1216.34s
#
# Test set: Average loss: 1.7452, Accuracy: 634/1042 (61%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 11553	Train Loss: 0.1301	Accuracy: 1.000
# Batch: 11573	Train Loss: 0.7381	Accuracy: 0.750
# Batch: 11593	Train Loss: 0.1018	Accuracy: 1.000
# Batch: 11613	Train Loss: 0.5252	Accuracy: 0.750
# Batch: 11633	Train Loss: 0.0522	Accuracy: 1.000
# Batch: 11653	Train Loss: 0.2145	Accuracy: 1.000
# Batch: 11673	Train Loss: 0.0788	Accuracy: 1.000
# Batch: 11693	Train Loss: 0.2499	Accuracy: 1.000
# Batch: 11713	Train Loss: 0.3684	Accuracy: 0.750
# Batch: 11733	Train Loss: 0.5617	Accuracy: 0.750
# Batch: 11753	Train Loss: 0.2565	Accuracy: 1.000
# Batch: 11773	Train Loss: 0.0414	Accuracy: 1.000
# Batch: 11793	Train Loss: 0.3330	Accuracy: 1.000
# Batch: 11813	Train Loss: 0.1970	Accuracy: 1.000
# Batch: 11833	Train Loss: 0.3648	Accuracy: 0.750
# Batch: 11853	Train Loss: 3.0540	Accuracy: 0.250
# Batch: 11873	Train Loss: 1.6159	Accuracy: 0.250
# Batch: 11893	Train Loss: 0.5180	Accuracy: 0.750
# Batch: 11913	Train Loss: 0.2162	Accuracy: 1.000
# Batch: 11933	Train Loss: 1.8649	Accuracy: 0.500
# Batch: 11953	Train Loss: 0.3154	Accuracy: 1.000
# Batch: 11973	Train Loss: 0.1473	Accuracy: 1.000
# Batch: 11993	Train Loss: 0.0550	Accuracy: 1.000
# Batch: 12013	Train Loss: 0.6411	Accuracy: 0.750
# Batch: 12033	Train Loss: 0.6462	Accuracy: 0.750
# Batch: 12053	Train Loss: 0.1310	Accuracy: 1.000
# Batch: 12073	Train Loss: 1.4725	Accuracy: 0.750
# Batch: 12093	Train Loss: 1.2800	Accuracy: 0.500
# Batch: 12113	Train Loss: 0.2649	Accuracy: 1.000
# Batch: 12133	Train Loss: 0.5158	Accuracy: 0.750
# Batch: 12153	Train Loss: 0.2718	Accuracy: 1.000
# Batch: 12173	Train Loss: 0.3727	Accuracy: 1.000
# Batch: 12193	Train Loss: 1.3871	Accuracy: 0.750
# Batch: 12213	Train Loss: 0.1554	Accuracy: 1.000
# Batch: 12233	Train Loss: 0.6920	Accuracy: 0.500
# Batch: 12253	Train Loss: 0.1100	Accuracy: 1.000
# Batch: 12273	Train Loss: 1.1465	Accuracy: 0.500
# Batch: 12293	Train Loss: 0.4369	Accuracy: 0.750
# Batch: 12313	Train Loss: 1.4251	Accuracy: 0.500
# Batch: 12333	Train Loss: 0.0913	Accuracy: 1.000
# Batch: 12353	Train Loss: 1.7242	Accuracy: 0.750
# Batch: 12373	Train Loss: 0.2014	Accuracy: 1.000
# Batch: 12393	Train Loss: 1.6647	Accuracy: 0.750
# Batch: 12413	Train Loss: 1.4766	Accuracy: 0.750
# Batch: 12433	Train Loss: 0.0943	Accuracy: 1.000
# Batch: 12453	Train Loss: 0.0228	Accuracy: 1.000
# Batch: 12473	Train Loss: 1.1132	Accuracy: 0.500
# Batch: 12493	Train Loss: 0.3381	Accuracy: 1.000
# Batch: 12513	Train Loss: 0.3321	Accuracy: 0.750
# Batch: 12533	Train Loss: 1.1072	Accuracy: 0.750
# Batch: 12553	Train Loss: 0.7511	Accuracy: 0.500
# Batch: 12573	Train Loss: 0.8500	Accuracy: 0.750
# Epoch: 11
# Train Loss: 0.704497 Acc: 0.7741
# Elapsed 1624.39s, 135.37 s/epoch, 0.13 s/batch, ets 1082.93s
#
# Test set: Average loss: 1.7253, Accuracy: 630/1042 (60%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 12602	Train Loss: 0.3267	Accuracy: 1.000
# Batch: 12622	Train Loss: 0.0633	Accuracy: 1.000
# Batch: 12642	Train Loss: 0.5005	Accuracy: 0.750
# Batch: 12662	Train Loss: 0.3102	Accuracy: 1.000
# Batch: 12682	Train Loss: 0.4211	Accuracy: 1.000
# Batch: 12702	Train Loss: 0.3575	Accuracy: 0.750
# Batch: 12722	Train Loss: 0.4626	Accuracy: 0.750
# Batch: 12742	Train Loss: 0.7396	Accuracy: 0.500
# Batch: 12762	Train Loss: 0.6931	Accuracy: 0.750
# Batch: 12782	Train Loss: 3.0803	Accuracy: 0.250
# Batch: 12802	Train Loss: 0.5294	Accuracy: 1.000
# Batch: 12822	Train Loss: 0.3462	Accuracy: 0.750
# Batch: 12842	Train Loss: 0.7695	Accuracy: 0.750
# Batch: 12862	Train Loss: 0.1205	Accuracy: 1.000
# Batch: 12882	Train Loss: 1.1419	Accuracy: 0.750
# Batch: 12902	Train Loss: 0.9614	Accuracy: 0.750
# Batch: 12922	Train Loss: 1.1857	Accuracy: 0.750
# Batch: 12942	Train Loss: 0.0582	Accuracy: 1.000
# Batch: 12962	Train Loss: 0.0490	Accuracy: 1.000
# Batch: 12982	Train Loss: 0.9497	Accuracy: 0.500
# Batch: 13002	Train Loss: 0.7601	Accuracy: 0.500
# Batch: 13022	Train Loss: 0.6831	Accuracy: 0.750
# Batch: 13042	Train Loss: 0.2717	Accuracy: 0.750
# Batch: 13062	Train Loss: 0.7481	Accuracy: 0.500
# Batch: 13082	Train Loss: 0.5970	Accuracy: 0.750
# Batch: 13102	Train Loss: 0.1808	Accuracy: 1.000
# Batch: 13122	Train Loss: 0.1584	Accuracy: 1.000
# Batch: 13142	Train Loss: 0.0559	Accuracy: 1.000
# Batch: 13162	Train Loss: 0.5705	Accuracy: 0.750
# Batch: 13182	Train Loss: 0.9020	Accuracy: 0.750
# Batch: 13202	Train Loss: 0.1030	Accuracy: 1.000
# Batch: 13222	Train Loss: 0.1425	Accuracy: 1.000
# Batch: 13242	Train Loss: 0.0348	Accuracy: 1.000
# Batch: 13262	Train Loss: 0.1705	Accuracy: 1.000
# Batch: 13282	Train Loss: 2.6180	Accuracy: 0.250
# Batch: 13302	Train Loss: 0.8221	Accuracy: 0.750
# Batch: 13322	Train Loss: 0.1130	Accuracy: 1.000
# Batch: 13342	Train Loss: 0.0151	Accuracy: 1.000
# Batch: 13362	Train Loss: 0.5004	Accuracy: 0.750
# Batch: 13382	Train Loss: 0.2420	Accuracy: 1.000
# Batch: 13402	Train Loss: 1.4273	Accuracy: 0.500
# Batch: 13422	Train Loss: 0.8766	Accuracy: 0.750
# Batch: 13442	Train Loss: 0.5936	Accuracy: 0.750
# Batch: 13462	Train Loss: 0.0884	Accuracy: 1.000
# Batch: 13482	Train Loss: 0.2528	Accuracy: 1.000
# Batch: 13502	Train Loss: 0.2270	Accuracy: 1.000
# Batch: 13522	Train Loss: 0.9773	Accuracy: 0.750
# Batch: 13542	Train Loss: 1.3868	Accuracy: 0.500
# Batch: 13562	Train Loss: 0.8008	Accuracy: 0.750
# Batch: 13582	Train Loss: 0.4805	Accuracy: 1.000
# Batch: 13602	Train Loss: 0.7654	Accuracy: 0.500
# Batch: 13622	Train Loss: 0.4268	Accuracy: 1.000
# Epoch: 12
# Train Loss: 0.646038 Acc: 0.7948
# Elapsed 1760.07s, 135.39 s/epoch, 0.13 s/batch, ets 947.73s
#
# Test set: Average loss: 1.8936, Accuracy: 609/1042 (58%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 13650	Train Loss: 0.5272	Accuracy: 0.750
# Batch: 13670	Train Loss: 0.2408	Accuracy: 1.000
# Batch: 13690	Train Loss: 0.3643	Accuracy: 0.750
# Batch: 13710	Train Loss: 0.0365	Accuracy: 1.000
# Batch: 13730	Train Loss: 0.1413	Accuracy: 1.000
# Batch: 13750	Train Loss: 0.1198	Accuracy: 1.000
# Batch: 13770	Train Loss: 1.8450	Accuracy: 0.500
# Batch: 13790	Train Loss: 1.4367	Accuracy: 0.500
# Batch: 13810	Train Loss: 0.0726	Accuracy: 1.000
# Batch: 13830	Train Loss: 0.1493	Accuracy: 1.000
# Batch: 13850	Train Loss: 0.1317	Accuracy: 1.000
# Batch: 13870	Train Loss: 0.2784	Accuracy: 0.750
# Batch: 13890	Train Loss: 1.4926	Accuracy: 0.250
# Batch: 13910	Train Loss: 0.6909	Accuracy: 0.750
# Batch: 13930	Train Loss: 2.1317	Accuracy: 0.500
# Batch: 13950	Train Loss: 0.0967	Accuracy: 1.000
# Batch: 13970	Train Loss: 1.6649	Accuracy: 0.750
# Batch: 13990	Train Loss: 0.3769	Accuracy: 0.750
# Batch: 14010	Train Loss: 1.2029	Accuracy: 0.500
# Batch: 14030	Train Loss: 0.5067	Accuracy: 0.750
# Batch: 14050	Train Loss: 2.1974	Accuracy: 0.250
# Batch: 14070	Train Loss: 1.0100	Accuracy: 0.750
# Batch: 14090	Train Loss: 1.0840	Accuracy: 0.500
# Batch: 14110	Train Loss: 0.4763	Accuracy: 0.750
# Batch: 14130	Train Loss: 0.9979	Accuracy: 0.500
# Batch: 14150	Train Loss: 0.2366	Accuracy: 1.000
# Batch: 14170	Train Loss: 0.1859	Accuracy: 1.000
# Batch: 14190	Train Loss: 0.1595	Accuracy: 1.000
# Batch: 14210	Train Loss: 0.1884	Accuracy: 1.000
# Batch: 14230	Train Loss: 0.1653	Accuracy: 1.000
# Batch: 14250	Train Loss: 0.5117	Accuracy: 0.750
# Batch: 14270	Train Loss: 0.2112	Accuracy: 1.000
# Batch: 14290	Train Loss: 0.0724	Accuracy: 1.000
# Batch: 14310	Train Loss: 0.3716	Accuracy: 0.750
# Batch: 14330	Train Loss: 2.5193	Accuracy: 0.250
# Batch: 14350	Train Loss: 0.3043	Accuracy: 1.000
# Batch: 14370	Train Loss: 0.2601	Accuracy: 0.750
# Batch: 14390	Train Loss: 0.0479	Accuracy: 1.000
# Batch: 14410	Train Loss: 0.2582	Accuracy: 1.000
# Batch: 14430	Train Loss: 0.2399	Accuracy: 1.000
# Batch: 14450	Train Loss: 0.7157	Accuracy: 0.750
# Batch: 14470	Train Loss: 0.2832	Accuracy: 1.000
# Batch: 14490	Train Loss: 0.0512	Accuracy: 1.000
# Batch: 14510	Train Loss: 1.1545	Accuracy: 0.500
# Batch: 14530	Train Loss: 0.2679	Accuracy: 0.750
# Batch: 14550	Train Loss: 0.6984	Accuracy: 0.750
# Batch: 14570	Train Loss: 0.6896	Accuracy: 0.750
# Batch: 14590	Train Loss: 0.4983	Accuracy: 0.750
# Batch: 14610	Train Loss: 0.2324	Accuracy: 0.750
# Batch: 14630	Train Loss: 1.3893	Accuracy: 0.500
# Batch: 14650	Train Loss: 0.3473	Accuracy: 1.000
# Batch: 14670	Train Loss: 0.0894	Accuracy: 1.000
# Epoch: 13
# Train Loss: 0.598623 Acc: 0.8096
# Elapsed 1894.50s, 135.32 s/epoch, 0.13 s/batch, ets 811.93s
#
# Test set: Average loss: 1.7787, Accuracy: 636/1042 (61%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 14699	Train Loss: 0.2961	Accuracy: 1.000
# Batch: 14719	Train Loss: 0.0852	Accuracy: 1.000
# Batch: 14739	Train Loss: 0.0532	Accuracy: 1.000
# Batch: 14759	Train Loss: 1.0484	Accuracy: 0.500
# Batch: 14779	Train Loss: 0.0786	Accuracy: 1.000
# Batch: 14799	Train Loss: 0.0615	Accuracy: 1.000
# Batch: 14819	Train Loss: 0.1215	Accuracy: 1.000
# Batch: 14839	Train Loss: 0.8285	Accuracy: 0.750
# Batch: 14859	Train Loss: 0.8517	Accuracy: 0.750
# Batch: 14879	Train Loss: 0.6792	Accuracy: 0.500
# Batch: 14899	Train Loss: 1.4539	Accuracy: 0.250
# Batch: 14919	Train Loss: 0.0340	Accuracy: 1.000
# Batch: 14939	Train Loss: 0.0516	Accuracy: 1.000
# Batch: 14959	Train Loss: 0.6992	Accuracy: 0.750
# Batch: 14979	Train Loss: 0.0648	Accuracy: 1.000
# Batch: 14999	Train Loss: 0.5455	Accuracy: 1.000
# Batch: 15019	Train Loss: 0.2247	Accuracy: 1.000
# Batch: 15039	Train Loss: 0.1499	Accuracy: 1.000
# Batch: 15059	Train Loss: 1.1827	Accuracy: 0.750
# Batch: 15079	Train Loss: 1.5139	Accuracy: 0.500
# Batch: 15099	Train Loss: 0.2819	Accuracy: 0.750
# Batch: 15119	Train Loss: 0.3679	Accuracy: 0.750
# Batch: 15139	Train Loss: 0.9885	Accuracy: 0.750
# Batch: 15159	Train Loss: 0.1693	Accuracy: 1.000
# Batch: 15179	Train Loss: 0.8190	Accuracy: 0.750
# Batch: 15199	Train Loss: 1.4136	Accuracy: 0.500
# Batch: 15219	Train Loss: 0.6027	Accuracy: 0.750
# Batch: 15239	Train Loss: 0.1554	Accuracy: 1.000
# Batch: 15259	Train Loss: 0.2782	Accuracy: 0.750
# Batch: 15279	Train Loss: 0.3920	Accuracy: 1.000
# Batch: 15299	Train Loss: 0.7109	Accuracy: 0.750
# Batch: 15319	Train Loss: 0.1603	Accuracy: 1.000
# Batch: 15339	Train Loss: 0.9642	Accuracy: 0.750
# Batch: 15359	Train Loss: 0.0860	Accuracy: 1.000
# Batch: 15379	Train Loss: 1.6745	Accuracy: 0.500
# Batch: 15399	Train Loss: 0.9696	Accuracy: 0.750
# Batch: 15419	Train Loss: 0.3628	Accuracy: 1.000
# Batch: 15439	Train Loss: 0.6233	Accuracy: 0.750
# Batch: 15459	Train Loss: 1.9202	Accuracy: 0.500
# Batch: 15479	Train Loss: 0.8718	Accuracy: 0.500
# Batch: 15499	Train Loss: 0.0177	Accuracy: 1.000
# Batch: 15519	Train Loss: 0.6307	Accuracy: 0.750
# Batch: 15539	Train Loss: 0.2680	Accuracy: 1.000
# Batch: 15559	Train Loss: 0.2347	Accuracy: 1.000
# Batch: 15579	Train Loss: 0.0946	Accuracy: 1.000
# Batch: 15599	Train Loss: 0.4387	Accuracy: 0.750
# Batch: 15619	Train Loss: 0.0885	Accuracy: 1.000
# Batch: 15639	Train Loss: 0.0883	Accuracy: 1.000
# Batch: 15659	Train Loss: 0.1161	Accuracy: 1.000
# Batch: 15679	Train Loss: 0.0687	Accuracy: 1.000
# Batch: 15699	Train Loss: 0.1412	Accuracy: 1.000
# Batch: 15719	Train Loss: 0.5405	Accuracy: 0.750
# Epoch: 14
# Train Loss: 0.566142 Acc: 0.8213
# Elapsed 2023.57s, 134.90 s/epoch, 0.13 s/batch, ets 674.52s
#
# Test set: Average loss: 1.7846, Accuracy: 654/1042 (63%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 15747	Train Loss: 0.7958	Accuracy: 0.750
# Batch: 15767	Train Loss: 0.0713	Accuracy: 1.000
# Batch: 15787	Train Loss: 0.0540	Accuracy: 1.000
# Batch: 15807	Train Loss: 0.2859	Accuracy: 0.750
# Batch: 15827	Train Loss: 0.1188	Accuracy: 1.000
# Batch: 15847	Train Loss: 1.1177	Accuracy: 0.500
# Batch: 15867	Train Loss: 0.1903	Accuracy: 1.000
# Batch: 15887	Train Loss: 0.4235	Accuracy: 1.000
# Batch: 15907	Train Loss: 0.3119	Accuracy: 1.000
# Batch: 15927	Train Loss: 2.3002	Accuracy: 0.500
# Batch: 15947	Train Loss: 0.3363	Accuracy: 0.750
# Batch: 15967	Train Loss: 0.4718	Accuracy: 0.750
# Batch: 15987	Train Loss: 0.0494	Accuracy: 1.000
# Batch: 16007	Train Loss: 0.1024	Accuracy: 1.000
# Batch: 16027	Train Loss: 0.0964	Accuracy: 1.000
# Batch: 16047	Train Loss: 0.3494	Accuracy: 1.000
# Batch: 16067	Train Loss: 0.0053	Accuracy: 1.000
# Batch: 16087	Train Loss: 0.0145	Accuracy: 1.000
# Batch: 16107	Train Loss: 1.1206	Accuracy: 0.250
# Batch: 16127	Train Loss: 0.9742	Accuracy: 0.500
# Batch: 16147	Train Loss: 0.0861	Accuracy: 1.000
# Batch: 16167	Train Loss: 0.6343	Accuracy: 0.750
# Batch: 16187	Train Loss: 0.0736	Accuracy: 1.000
# Batch: 16207	Train Loss: 0.5791	Accuracy: 0.750
# Batch: 16227	Train Loss: 0.2216	Accuracy: 1.000
# Batch: 16247	Train Loss: 1.1621	Accuracy: 0.750
# Batch: 16267	Train Loss: 0.0196	Accuracy: 1.000
# Batch: 16287	Train Loss: 0.4296	Accuracy: 0.750
# Batch: 16307	Train Loss: 0.4346	Accuracy: 1.000
# Batch: 16327	Train Loss: 0.9561	Accuracy: 0.750
# Batch: 16347	Train Loss: 0.2146	Accuracy: 1.000
# Batch: 16367	Train Loss: 0.4763	Accuracy: 0.750
# Batch: 16387	Train Loss: 0.0299	Accuracy: 1.000
# Batch: 16407	Train Loss: 0.3566	Accuracy: 0.750
# Batch: 16427	Train Loss: 0.1155	Accuracy: 1.000
# Batch: 16447	Train Loss: 2.4728	Accuracy: 0.250
# Batch: 16467	Train Loss: 0.2049	Accuracy: 1.000
# Batch: 16487	Train Loss: 0.4596	Accuracy: 0.750
# Batch: 16507	Train Loss: 0.8084	Accuracy: 0.500
# Batch: 16527	Train Loss: 0.8736	Accuracy: 0.750
# Batch: 16547	Train Loss: 0.4873	Accuracy: 0.750
# Batch: 16567	Train Loss: 0.5860	Accuracy: 0.750
# Batch: 16587	Train Loss: 1.0866	Accuracy: 0.500
# Batch: 16607	Train Loss: 0.1589	Accuracy: 1.000
# Batch: 16627	Train Loss: 0.8885	Accuracy: 0.750
# Batch: 16647	Train Loss: 0.8819	Accuracy: 0.750
# Batch: 16667	Train Loss: 0.0107	Accuracy: 1.000
# Batch: 16687	Train Loss: 0.6473	Accuracy: 0.750
# Batch: 16707	Train Loss: 1.1938	Accuracy: 0.500
# Batch: 16727	Train Loss: 0.5321	Accuracy: 0.750
# Batch: 16747	Train Loss: 0.3900	Accuracy: 1.000
# Batch: 16767	Train Loss: 0.0560	Accuracy: 1.000
# Epoch: 15
# Train Loss: 0.541128 Acc: 0.8272
# Elapsed 2150.62s, 134.41 s/epoch, 0.13 s/batch, ets 537.65s
#
# Test set: Average loss: 1.9101, Accuracy: 638/1042 (61%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 16796	Train Loss: 0.3332	Accuracy: 0.750
# Batch: 16816	Train Loss: 0.3869	Accuracy: 0.750
# Batch: 16836	Train Loss: 0.2412	Accuracy: 1.000
# Batch: 16856	Train Loss: 0.2610	Accuracy: 1.000
# Batch: 16876	Train Loss: 0.8898	Accuracy: 0.750
# Batch: 16896	Train Loss: 0.1509	Accuracy: 1.000
# Batch: 16916	Train Loss: 0.8846	Accuracy: 0.750
# Batch: 16936	Train Loss: 0.0098	Accuracy: 1.000
# Batch: 16956	Train Loss: 0.0718	Accuracy: 1.000
# Batch: 16976	Train Loss: 1.6609	Accuracy: 0.500
# Batch: 16996	Train Loss: 0.1507	Accuracy: 1.000
# Batch: 17016	Train Loss: 0.4532	Accuracy: 1.000
# Batch: 17036	Train Loss: 0.5477	Accuracy: 0.750
# Batch: 17056	Train Loss: 0.2785	Accuracy: 0.750
# Batch: 17076	Train Loss: 0.2100	Accuracy: 1.000
# Batch: 17096	Train Loss: 0.4270	Accuracy: 0.750
# Batch: 17116	Train Loss: 1.0441	Accuracy: 0.750
# Batch: 17136	Train Loss: 0.2521	Accuracy: 1.000
# Batch: 17156	Train Loss: 0.2601	Accuracy: 1.000
# Batch: 17176	Train Loss: 0.2132	Accuracy: 1.000
# Batch: 17196	Train Loss: 0.0168	Accuracy: 1.000
# Batch: 17216	Train Loss: 0.0305	Accuracy: 1.000
# Batch: 17236	Train Loss: 0.6974	Accuracy: 0.750
# Batch: 17256	Train Loss: 1.4351	Accuracy: 0.500
# Batch: 17276	Train Loss: 0.2744	Accuracy: 1.000
# Batch: 17296	Train Loss: 0.1184	Accuracy: 1.000
# Batch: 17316	Train Loss: 0.3188	Accuracy: 1.000
# Batch: 17336	Train Loss: 0.4153	Accuracy: 0.750
# Batch: 17356	Train Loss: 1.1189	Accuracy: 0.750
# Batch: 17376	Train Loss: 0.4778	Accuracy: 0.750
# Batch: 17396	Train Loss: 0.1289	Accuracy: 1.000
# Batch: 17416	Train Loss: 0.5104	Accuracy: 0.750
# Batch: 17436	Train Loss: 0.8029	Accuracy: 0.750
# Batch: 17456	Train Loss: 0.0778	Accuracy: 1.000
# Batch: 17476	Train Loss: 2.7171	Accuracy: 0.500
# Batch: 17496	Train Loss: 1.6687	Accuracy: 0.750
# Batch: 17516	Train Loss: 0.0863	Accuracy: 1.000
# Batch: 17536	Train Loss: 1.1494	Accuracy: 0.750
# Batch: 17556	Train Loss: 0.5879	Accuracy: 0.750
# Batch: 17576	Train Loss: 0.1300	Accuracy: 1.000
# Batch: 17596	Train Loss: 0.3108	Accuracy: 1.000
# Batch: 17616	Train Loss: 0.9419	Accuracy: 0.750
# Batch: 17636	Train Loss: 1.2698	Accuracy: 0.750
# Batch: 17656	Train Loss: 1.9105	Accuracy: 0.250
# Batch: 17676	Train Loss: 0.0742	Accuracy: 1.000
# Batch: 17696	Train Loss: 0.9168	Accuracy: 0.750
# Batch: 17716	Train Loss: 0.5533	Accuracy: 0.750
# Batch: 17736	Train Loss: 1.2219	Accuracy: 0.750
# Batch: 17756	Train Loss: 0.5548	Accuracy: 0.750
# Batch: 17776	Train Loss: 0.1120	Accuracy: 1.000
# Batch: 17796	Train Loss: 0.5216	Accuracy: 0.750
# Batch: 17816	Train Loss: 0.0708	Accuracy: 1.000
# Epoch: 16
# Train Loss: 0.486252 Acc: 0.8460
# Elapsed 2277.31s, 133.96 s/epoch, 0.13 s/batch, ets 401.88s
#
# Test set: Average loss: 1.8495, Accuracy: 618/1042 (59%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 17844	Train Loss: 0.1595	Accuracy: 1.000
# Batch: 17864	Train Loss: 0.3990	Accuracy: 0.750
# Batch: 17884	Train Loss: 0.1463	Accuracy: 1.000
# Batch: 17904	Train Loss: 0.0565	Accuracy: 1.000
# Batch: 17924	Train Loss: 0.0082	Accuracy: 1.000
# Batch: 17944	Train Loss: 0.2591	Accuracy: 1.000
# Batch: 17964	Train Loss: 0.0913	Accuracy: 1.000
# Batch: 17984	Train Loss: 0.1751	Accuracy: 1.000
# Batch: 18004	Train Loss: 0.0547	Accuracy: 1.000
# Batch: 18024	Train Loss: 0.1003	Accuracy: 1.000
# Batch: 18044	Train Loss: 0.2116	Accuracy: 1.000
# Batch: 18064	Train Loss: 0.1907	Accuracy: 1.000
# Batch: 18084	Train Loss: 0.0773	Accuracy: 1.000
# Batch: 18104	Train Loss: 0.1237	Accuracy: 1.000
# Batch: 18124	Train Loss: 0.1959	Accuracy: 1.000
# Batch: 18144	Train Loss: 0.0526	Accuracy: 1.000
# Batch: 18164	Train Loss: 0.4060	Accuracy: 0.750
# Batch: 18184	Train Loss: 0.5788	Accuracy: 0.500
# Batch: 18204	Train Loss: 1.1063	Accuracy: 0.500
# Batch: 18224	Train Loss: 0.0515	Accuracy: 1.000
# Batch: 18244	Train Loss: 0.0307	Accuracy: 1.000
# Batch: 18264	Train Loss: 0.8847	Accuracy: 0.750
# Batch: 18284	Train Loss: 1.4224	Accuracy: 0.750
# Batch: 18304	Train Loss: 0.0968	Accuracy: 1.000
# Batch: 18324	Train Loss: 0.2232	Accuracy: 1.000
# Batch: 18344	Train Loss: 0.0042	Accuracy: 1.000
# Batch: 18364	Train Loss: 1.3321	Accuracy: 0.250
# Batch: 18384	Train Loss: 0.2939	Accuracy: 0.750
# Batch: 18404	Train Loss: 0.7644	Accuracy: 0.500
# Batch: 18424	Train Loss: 0.0882	Accuracy: 1.000
# Batch: 18444	Train Loss: 0.0844	Accuracy: 1.000
# Batch: 18464	Train Loss: 0.0786	Accuracy: 1.000
# Batch: 18484	Train Loss: 0.0288	Accuracy: 1.000
# Batch: 18504	Train Loss: 0.1213	Accuracy: 1.000
# Batch: 18524	Train Loss: 0.3702	Accuracy: 0.750
# Batch: 18544	Train Loss: 0.3457	Accuracy: 0.750
# Batch: 18564	Train Loss: 0.1655	Accuracy: 1.000
# Batch: 18584	Train Loss: 0.1939	Accuracy: 1.000
# Batch: 18604	Train Loss: 0.6192	Accuracy: 0.500
# Batch: 18624	Train Loss: 0.0654	Accuracy: 1.000
# Batch: 18644	Train Loss: 0.2226	Accuracy: 0.750
# Batch: 18664	Train Loss: 0.1744	Accuracy: 1.000
# Batch: 18684	Train Loss: 0.9590	Accuracy: 0.750
# Batch: 18704	Train Loss: 0.2544	Accuracy: 1.000
# Batch: 18724	Train Loss: 0.1477	Accuracy: 1.000
# Batch: 18744	Train Loss: 1.2428	Accuracy: 0.250
# Batch: 18764	Train Loss: 0.7752	Accuracy: 0.750
# Batch: 18784	Train Loss: 0.2979	Accuracy: 1.000
# Batch: 18804	Train Loss: 0.0827	Accuracy: 1.000
# Batch: 18824	Train Loss: 0.3546	Accuracy: 0.750
# Batch: 18844	Train Loss: 0.8271	Accuracy: 0.750
# Batch: 18864	Train Loss: 0.3406	Accuracy: 0.750
# Epoch: 17
# Train Loss: 0.438454 Acc: 0.8582
# Elapsed 2404.42s, 133.58 s/epoch, 0.13 s/batch, ets 267.16s
#
# Test set: Average loss: 1.9377, Accuracy: 627/1042 (60%)
#
# Bad Epochs:0
# last LR = [0.001]
# Batch: 18893	Train Loss: 0.0379	Accuracy: 1.000
# Batch: 18913	Train Loss: 0.0733	Accuracy: 1.000
# Batch: 18933	Train Loss: 0.2183	Accuracy: 1.000
# Batch: 18953	Train Loss: 1.5966	Accuracy: 0.250
# Batch: 18973	Train Loss: 0.1325	Accuracy: 1.000
# Batch: 18993	Train Loss: 0.0356	Accuracy: 1.000
# Batch: 19013	Train Loss: 0.0508	Accuracy: 1.000
# Batch: 19033	Train Loss: 0.3267	Accuracy: 0.750
# Batch: 19053	Train Loss: 0.0336	Accuracy: 1.000
# Batch: 19073	Train Loss: 1.3019	Accuracy: 0.750
# Batch: 19093	Train Loss: 0.1741	Accuracy: 1.000
# Batch: 19113	Train Loss: 0.2332	Accuracy: 0.750
# Batch: 19133	Train Loss: 0.1874	Accuracy: 1.000
# Batch: 19153	Train Loss: 1.0466	Accuracy: 0.750
# Batch: 19173	Train Loss: 0.0625	Accuracy: 1.000
# Batch: 19193	Train Loss: 0.0660	Accuracy: 1.000
# Batch: 19213	Train Loss: 0.1826	Accuracy: 1.000
# Batch: 19233	Train Loss: 0.6378	Accuracy: 0.750
# Batch: 19253	Train Loss: 0.3637	Accuracy: 0.750
# Batch: 19273	Train Loss: 0.1272	Accuracy: 1.000
# Batch: 19293	Train Loss: 0.1976	Accuracy: 1.000
# Batch: 19313	Train Loss: 0.1379	Accuracy: 1.000
# Batch: 19333	Train Loss: 0.7822	Accuracy: 0.750
# Batch: 19353	Train Loss: 0.0373	Accuracy: 1.000
# Batch: 19373	Train Loss: 0.0156	Accuracy: 1.000
# Batch: 19393	Train Loss: 0.0049	Accuracy: 1.000
# Batch: 19413	Train Loss: 0.0505	Accuracy: 1.000
# Batch: 19433	Train Loss: 0.2691	Accuracy: 1.000
# Batch: 19453	Train Loss: 0.0937	Accuracy: 1.000
# Batch: 19473	Train Loss: 0.0932	Accuracy: 1.000
# Batch: 19493	Train Loss: 0.0084	Accuracy: 1.000
# Batch: 19513	Train Loss: 0.7699	Accuracy: 0.750
# Batch: 19533	Train Loss: 0.4304	Accuracy: 0.500
# Batch: 19553	Train Loss: 0.1372	Accuracy: 1.000
# Batch: 19573	Train Loss: 1.3409	Accuracy: 0.750
# Batch: 19593	Train Loss: 0.2577	Accuracy: 1.000
# Batch: 19613	Train Loss: 1.0393	Accuracy: 0.750
# Batch: 19633	Train Loss: 0.2084	Accuracy: 1.000
# Batch: 19653	Train Loss: 1.5282	Accuracy: 0.750
# Batch: 19673	Train Loss: 0.0240	Accuracy: 1.000
# Batch: 19693	Train Loss: 0.3102	Accuracy: 1.000
# Batch: 19713	Train Loss: 0.6624	Accuracy: 0.750
# Batch: 19733	Train Loss: 2.9186	Accuracy: 0.250
# Batch: 19753	Train Loss: 0.1673	Accuracy: 1.000
# Batch: 19773	Train Loss: 0.1355	Accuracy: 1.000
# Batch: 19793	Train Loss: 0.2863	Accuracy: 0.750
# Batch: 19813	Train Loss: 0.0109	Accuracy: 1.000
# Batch: 19833	Train Loss: 0.3497	Accuracy: 1.000
# Batch: 19853	Train Loss: 0.1614	Accuracy: 1.000
# Batch: 19873	Train Loss: 0.6454	Accuracy: 0.750
# Batch: 19893	Train Loss: 0.0667	Accuracy: 1.000
# Batch: 19913	Train Loss: 0.0601	Accuracy: 1.000
# Epoch: 18
# Train Loss: 0.441425 Acc: 0.8625
# Elapsed 2531.08s, 133.21 s/epoch, 0.13 s/batch, ets 133.21s
#
# Test set: Average loss: 2.0613, Accuracy: 625/1042 (60%)
#
# Bad Epochs:1
# last LR = [0.001]
# Batch: 19941	Train Loss: 0.2505	Accuracy: 1.000
# Batch: 19961	Train Loss: 0.3637	Accuracy: 0.750
# Batch: 19981	Train Loss: 0.6162	Accuracy: 0.750
# Batch: 20001	Train Loss: 0.6772	Accuracy: 0.750
# Batch: 20021	Train Loss: 0.3850	Accuracy: 1.000
# Batch: 20041	Train Loss: 0.7523	Accuracy: 0.500
# Batch: 20061	Train Loss: 0.0775	Accuracy: 1.000
# Batch: 20081	Train Loss: 0.2764	Accuracy: 1.000
# Batch: 20101	Train Loss: 0.0188	Accuracy: 1.000
# Batch: 20121	Train Loss: 0.1225	Accuracy: 1.000
# Batch: 20141	Train Loss: 0.2698	Accuracy: 1.000
# Batch: 20161	Train Loss: 0.3979	Accuracy: 0.750
# Batch: 20181	Train Loss: 0.1122	Accuracy: 1.000
# Batch: 20201	Train Loss: 1.3733	Accuracy: 0.500
# Batch: 20221	Train Loss: 0.4611	Accuracy: 0.750
# Batch: 20241	Train Loss: 0.0114	Accuracy: 1.000
# Batch: 20261	Train Loss: 0.5016	Accuracy: 0.750
# Batch: 20281	Train Loss: 1.0294	Accuracy: 0.750
# Batch: 20301	Train Loss: 0.7085	Accuracy: 0.750
# Batch: 20321	Train Loss: 0.7168	Accuracy: 0.750
# Batch: 20341	Train Loss: 0.3029	Accuracy: 1.000
# Batch: 20361	Train Loss: 0.6101	Accuracy: 0.500
# Batch: 20381	Train Loss: 0.3172	Accuracy: 1.000
# Batch: 20401	Train Loss: 0.1984	Accuracy: 1.000
# Batch: 20421	Train Loss: 1.2065	Accuracy: 0.750
# Batch: 20441	Train Loss: 0.0075	Accuracy: 1.000
# Batch: 20461	Train Loss: 0.1588	Accuracy: 1.000
# Batch: 20481	Train Loss: 0.0037	Accuracy: 1.000
# Batch: 20501	Train Loss: 0.1986	Accuracy: 1.000
# Batch: 20521	Train Loss: 0.5943	Accuracy: 0.750
# Batch: 20541	Train Loss: 1.0973	Accuracy: 0.500
# Batch: 20561	Train Loss: 1.1282	Accuracy: 0.250
# Batch: 20581	Train Loss: 1.4049	Accuracy: 0.750
# Batch: 20601	Train Loss: 0.1845	Accuracy: 1.000
# Batch: 20621	Train Loss: 0.1244	Accuracy: 1.000
# Batch: 20641	Train Loss: 1.4221	Accuracy: 0.500
# Batch: 20661	Train Loss: 1.1916	Accuracy: 0.750
# Batch: 20681	Train Loss: 0.2325	Accuracy: 1.000
# Batch: 20701	Train Loss: 0.0089	Accuracy: 1.000
# Batch: 20721	Train Loss: 0.1752	Accuracy: 1.000
# Batch: 20741	Train Loss: 0.1258	Accuracy: 1.000
# Batch: 20761	Train Loss: 0.7554	Accuracy: 0.750
# Batch: 20781	Train Loss: 0.1494	Accuracy: 1.000
# Batch: 20801	Train Loss: 0.1187	Accuracy: 1.000
# Batch: 20821	Train Loss: 0.0245	Accuracy: 1.000
# Batch: 20841	Train Loss: 0.5100	Accuracy: 0.750
# Batch: 20861	Train Loss: 1.4825	Accuracy: 0.250
# Batch: 20881	Train Loss: 0.1264	Accuracy: 1.000
# Batch: 20901	Train Loss: 0.2921	Accuracy: 1.000
# Batch: 20921	Train Loss: 0.0417	Accuracy: 1.000
# Batch: 20941	Train Loss: 0.0887	Accuracy: 1.000
# Batch: 20961	Train Loss: 0.1469	Accuracy: 1.000
# Epoch: 19
# Train Loss: 0.442952 Acc: 0.8620
# Elapsed 2657.00s, 132.85 s/epoch, 0.13 s/batch, ets 0.00s
#
# Test set: Average loss: 1.9275, Accuracy: 634/1042 (61%)
#
# Bad Epochs:2
# last LR = [0.001]
# Total time: 2681.54, Best Loss: 1.277

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')
